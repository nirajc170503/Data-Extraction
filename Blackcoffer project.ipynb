# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import os

# %%
input_file = 'Input.xlsx'
df = pd.read_excel(input_file)

# %%
df
# Out:
#              URL_ID                                                URL
# 0   blackassign0001  https://insights.blackcoffer.com/rising-it-cit...
# 1   blackassign0002  https://insights.blackcoffer.com/rising-it-cit...
# 2   blackassign0003  https://insights.blackcoffer.com/internet-dema...
# 3   blackassign0004  https://insights.blackcoffer.com/rise-of-cyber...
# 4   blackassign0005  https://insights.blackcoffer.com/ott-platform-...
# ..              ...                                                ...
# 95  blackassign0096  https://insights.blackcoffer.com/what-is-the-r...
# 96  blackassign0097  https://insights.blackcoffer.com/impact-of-cov...
# 97  blackassign0098  https://insights.blackcoffer.com/contribution-...
# 98  blackassign0099  https://insights.blackcoffer.com/how-covid-19-...
# 99  blackassign0100  https://insights.blackcoffer.com/how-will-covi...
#
# [100 rows x 2 columns]

# %% [markdown]
# ## Extracting the article Title & Text

# %%
def extract_article(url):
    try:
        response = requests.get(url)
        if response.status_code == 404:
            print(f"Error 404: Page not found - {url}")
            return None, None
        
        soup = BeautifulSoup(response.content, 'html.parser')
        article_title = soup.find('title').get_text()

        match1 = soup.find('div', class_='td-post-content tagdiv-type')
        match2 = soup.find('div', class_='td_block_wrap tdb_single_content tdi_130 td-pb-border-top td_block_template_1 td-post-content tagdiv-type')

        article_text = ''
        if match1:
            article_text += match1.get_text(strip=True) + '\n'
        if match2:
            article_text += match2.get_text(strip=True)

        return article_title, article_text
    
    except Exception as e:
        print(f"Error extracting article from {url}: {e}")
        return None, None

# Create a directory to save the extracted text files
output_dir = 'extracted_texts7'
os.makedirs(output_dir, exist_ok=True)

# Extract and save article text
for index, row in df.iterrows():
    url_id = row['URL_ID']
    url = row['URL']
    article_title, article_text = extract_article(url)
    if article_text is not None and article_title is not None:
        with open(os.path.join(output_dir, f'{url_id}.txt'), 'w', encoding='utf-8') as f:
            f.write(article_title + '\n\n')
            f.write(article_text)
    else:
        # Create a text file with the 404 error message
        with open(os.path.join(output_dir, f'{url_id}.txt'), 'w', encoding='utf-8') as f:
            f.write("error 404" )
            

print("Extraction completed.")
# Out:
# Error 404: Page not found - https://insights.blackcoffer.com/how-neural-networks-can-be-applied-in-various-areas-in-the-future/
# Error 404: Page not found - https://insights.blackcoffer.com/covid-19-environmental-impact-for-the-future/
# Extraction completed.

# %% [markdown]
# # Text Analysis

# %%
import nltk
import re
from nltk.tokenize import word_tokenize
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Amruta\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
current_dir = os.getcwd()
print(current_dir)
folder_name = "extracted_texts7"
print(folder_name)
# Out:
# C:\Users\Amruta\Desktop\Blackcoffer NLP Project
# extracted_texts7

# %%
folder_path = os.path.join(current_dir,folder_name)
print(folder_path)
# Out:
# C:\Users\Amruta\Desktop\Blackcoffer NLP Project\extracted_texts7

# %%
text_files = os.listdir(folder_path)
text_files
# Out:
# ['blackassign0001.txt',
#  'blackassign0002.txt',
#  'blackassign0003.txt',
#  'blackassign0004.txt',
#  'blackassign0005.txt',
#  'blackassign0006.txt',
#  'blackassign0007.txt',
#  'blackassign0008.txt',
#  'blackassign0009.txt',
#  'blackassign0010.txt',
#  'blackassign0011.txt',
#  'blackassign0012.txt',
#  'blackassign0013.txt',
#  'blackassign0014.txt',
#  'blackassign0015.txt',
#  'blackassign0016.txt',
#  'blackassign0017.txt',
#  'blackassign0018.txt',
#  'blackassign0019.txt',
#  'blackassign0020.txt',
#  'blackassign0021.txt',
#  'blackassign0022.txt',
#  'blackassign0023.txt',
#  'blackassign0024.txt',
#  'blackassign0025.txt',
#  'blackassign0026.txt',
#  'blackassign0027.txt',
#  'blackassign0028.txt',
#  'blackassign0029.txt',
#  'blackassign0030.txt',
#  'blackassign0031.txt',
#  'blackassign0032.txt',
#  'blackassign0033.txt',
#  'blackassign0034.txt',
#  'blackassign0035.txt',
#  'blackassign0036.txt',
#  'blackassign0037.txt',
#  'blackassign0038.txt',
#  'blackassign0039.txt',
#  'blackassign0040.txt',
#  'blackassign0041.txt',
#  'blackassign0042.txt',
#  'blackassign0043.txt',
#  'blackassign0044.txt',
#  'blackassign0045.txt',
#  'blackassign0046.txt',
#  'blackassign0047.txt',
#  'blackassign0048.txt',
#  'blackassign0049.txt',
#  'blackassign0050.txt',
#  'blackassign0051.txt',
#  'blackassign0052.txt',
#  'blackassign0053.txt',
#  'blackassign0054.txt',
#  'blackassign0055.txt',
#  'blackassign0056.txt',
#  'blackassign0057.txt',
#  'blackassign0058.txt',
#  'blackassign0059.txt',
#  'blackassign0060.txt',
#  'blackassign0061.txt',
#  'blackassign0062.txt',
#  'blackassign0063.txt',
#  'blackassign0064.txt',
#  'blackassign0065.txt',
#  'blackassign0066.txt',
#  'blackassign0067.txt',
#  'blackassign0068.txt',
#  'blackassign0069.txt',
#  'blackassign0070.txt',
#  'blackassign0071.txt',
#  'blackassign0072.txt',
#  'blackassign0073.txt',
#  'blackassign0074.txt',
#  'blackassign0075.txt',
#  'blackassign0076.txt',
#  'blackassign0077.txt',
#  'blackassign0078.txt',
#  'blackassign0079.txt',
#  'blackassign0080.txt',
#  'blackassign0081.txt',
#  'blackassign0082.txt',
#  'blackassign0083.txt',
#  'blackassign0084.txt',
#  'blackassign0085.txt',
#  'blackassign0086.txt',
#  'blackassign0087.txt',
#  'blackassign0088.txt',
#  'blackassign0089.txt',
#  'blackassign0090.txt',
#  'blackassign0091.txt',
#  'blackassign0092.txt',
#  'blackassign0093.txt',
#  'blackassign0094.txt',
#  'blackassign0095.txt',
#  'blackassign0096.txt',
#  'blackassign0097.txt',
#  'blackassign0098.txt',
#  'blackassign0099.txt',
#  'blackassign0100.txt']

# %% [markdown]
# ## 1.1Cleaning using Stop Words Lists

# %%
# creating dictionary with filename as keys and list of tokens as values

# %%
token_dict = {}

for file in text_files:
    with open(os.path.join(folder_path, file),'r',encoding='utf-8') as  f:
        
        tokens = word_tokenize(f.read())
        tokens = [word for word in tokens if word.isalpha()]
        tokens = [word.lower() for word in tokens]
        token_dict[file] = tokens
        
token_dict
# Out:
# {'blackassign0001.txt': ['rising',
#   'it',
#   'cities',
#   'and',
#   'its',
#   'impact',
#   'on',
#   'the',
#   'economy',
#   'environment',
#   'infrastructure',
#   'and',
#   'city',
#   'life',
#   'by',
#   'the',
#   'year',
#   'blackcoffer',
#   'insights',
#   'we',
#   'have',
#   'seen',
#   'a',
#   'huge',
#   'development',
#   'and',
#   'dependence',
#   'of',
#   'people',
#   'on',
#   'technology',
#   'in',
#   'recent',
#   'years',
#   'we',
#   'have',
#   'also',
#   'seen',
#   'the',
#   'development',
#   'of',
#   'ai',
#   'and',
#   'chatgpt',
#   'in',
#   'recent',
#   'years',
#   'so',
#   'it',
#   'is',
#   'a',
#   'normal',
#   'thing',
#   'that',
#   'we',
#   'will',
#   'become',
#   'fully',
#   'dependent',
#   'on',
#   'technology',
#   'by',
#   'information',
#   'technology',
#   'will',
#   'be',
#   'a',
#   'major',
#   'power',
#   'for',
#   'all',
#   'the',
#   'developing',
#   'nations',
#   'as',
#   'a',
#   'member',
#   'of',
#   'a',
#   'developing',
#   'nation',
#   'india',
#   'is',
#   'rapidly',
#   'growing',
#   'its',
#   'it',
#   'base',
#   'it',
#   'has',
#   'also',
#   'grown',
#   'some',
#   'it',
#   'cities',
#   'which',
#   'will',
#   'be',
#   'the',
#   'major',
#   'control',
#   'centres',
#   'for',
#   'information',
#   'technology',
#   'by',
#   'it',
#   'citiesnoida',
#   'in',
#   'uttar',
#   'pradesh',
#   'near',
#   'new',
#   'delhi',
#   'is',
#   'an',
#   'emerging',
#   'it',
#   'sector',
#   'now',
#   'many',
#   'large',
#   'companies',
#   'like',
#   'google',
#   'microsoft',
#   'ibm',
#   'infosys',
#   'and',
#   'others',
#   'have',
#   'set',
#   'up',
#   'their',
#   'companies',
#   'here',
#   'noida',
#   'has',
#   'a',
#   'market',
#   'base',
#   'of',
#   'billions',
#   'of',
#   'dollars',
#   'and',
#   'is',
#   'doing',
#   'a',
#   'great',
#   'job',
#   'of',
#   'boosting',
#   'the',
#   'national',
#   'economy',
#   'the',
#   'establishment',
#   'of',
#   'so',
#   'many',
#   'software',
#   'companies',
#   'has',
#   'made',
#   'noida',
#   'an',
#   'information',
#   'technology',
#   'in',
#   'haryana',
#   'is',
#   'also',
#   'an',
#   'emerging',
#   'it',
#   'hub',
#   'many',
#   'large',
#   'companies',
#   'like',
#   'google',
#   'microsoft',
#   'ibm',
#   'infosys',
#   'and',
#   'others',
#   'have',
#   'set',
#   'up',
#   'their',
#   'companies',
#   'here',
#   'gurgaon',
#   'has',
#   'a',
#   'market',
#   'base',
#   'of',
#   'billions',
#   'of',
#   'dollars',
#   'and',
#   'is',
#   'doing',
#   'a',
#   'great',
#   'job',
#   'of',
#   'boosting',
#   'the',
#   'national',
#   'is',
#   'called',
#   'as',
#   'the',
#   'it',
#   'hub',
#   'of',
#   'india',
#   'it',
#   'is',
#   'also',
#   'a',
#   'smart',
#   'city',
#   'many',
#   'large',
#   'companies',
#   'like',
#   'google',
#   'microsoft',
#   'ibm',
#   'infosys',
#   'and',
#   'others',
#   'have',
#   'set',
#   'up',
#   'their',
#   'companies',
#   'here',
#   'bengaluru',
#   'has',
#   'a',
#   'market',
#   'base',
#   'of',
#   'billions',
#   'of',
#   'dollars',
#   'and',
#   'is',
#   'doing',
#   'a',
#   'great',
#   'job',
#   'of',
#   'boosting',
#   'the',
#   'national',
#   'in',
#   'west',
#   'bengal',
#   'is',
#   'an',
#   'emerging',
#   'major',
#   'it',
#   'hub',
#   'the',
#   'new',
#   'kolkata',
#   'saltlake',
#   'sector',
#   'new',
#   'town',
#   'rajarhat',
#   'area',
#   'of',
#   'kolkata',
#   'is',
#   'a',
#   'major',
#   'it',
#   'hub',
#   'the',
#   'government',
#   'is',
#   'giving',
#   'the',
#   'software',
#   'companies',
#   'land',
#   'at',
#   'almost',
#   'free',
#   'of',
#   'cost',
#   'to',
#   'set',
#   'up',
#   'the',
#   'companies',
#   'there',
#   'many',
#   'large',
#   'companies',
#   'like',
#   'google',
#   'microsoft',
#   'ibm',
#   'infosys',
#   'and',
#   'others',
#   'have',
#   'set',
#   'up',
#   'their',
#   'companies',
#   'here',
#   'kolkata',
#   'has',
#   'a',
#   'market',
#   'base',
#   'of',
#   'billions',
#   'of',
#   'dollars',
#   'and',
#   'is',
#   'doing',
#   'a',
#   'great',
#   'job',
#   'of',
#   'boosting',
#   'the',
#   'national',
#   'on',
#   'economythere',
#   'is',
#   'a',
#   'huge',
#   'impact',
#   'of',
#   'the',
#   'rising',
#   'it',
#   'cities',
#   'on',
#   'our',
#   'economy',
#   'some',
#   'of',
#   'the',
#   'effects',
#   'rising',
#   'it',
#   'cities',
#   'will',
#   'greatly',
#   'help',
#   'to',
#   'boost',
#   'our',
#   'economy',
#   'these',
#   'will',
#   'create',
#   'a',
#   'huge',
#   'demand',
#   'for',
#   'raw',
#   'materials',
#   'the',
#   'products',
#   'when',
#   'ready',
#   'will',
#   'be',
#   'a',
#   'huge',
#   'demand',
#   'for',
#   'the',
#   'people',
#   'supply',
#   'means',
#   'the',
#   'fulfilment',
#   'of',
#   'demand',
#   'in',
#   'a',
#   'large',
#   'and',
#   'highly',
#   'populous',
#   'country',
#   'like',
#   'india',
#   'there',
#   'is',
#   'always',
#   'a',
#   'demand',
#   'for',
#   'finished',
#   'products',
#   'if',
#   'more',
#   'it',
#   'cities',
#   'do',
#   'not',
#   'develop',
#   'the',
#   'companies',
#   'can',
#   'not',
#   'fulfil',
#   'the',
#   'needs',
#   'and',
#   'desires',
#   'of',
#   'the',
#   'people',
#   'of',
#   'a',
#   'populous',
#   'country',
#   'like',
#   'india',
#   'as',
#   'it',
#   'cities',
#   'develop',
#   'more',
#   'it',
#   'companies',
#   'will',
#   'come',
#   'which',
#   'will',
#   'supply',
#   'more',
#   'and',
#   'more',
#   'finished',
#   'it',
#   'products',
#   'to',
#   'our',
#   'a',
#   'marketis',
#   'a',
#   'place',
#   'where',
#   'different',
#   'economic',
#   'agents',
#   'like',
#   'buyers',
#   'and',
#   'sellers',
#   'interact',
#   'with',
#   'one',
#   'another',
#   'in',
#   'a',
#   'populous',
#   'country',
#   'like',
#   'india',
#   'there',
#   'is',
#   'a',
#   'huge',
#   'market',
#   'as',
#   'it',
#   'cities',
#   'will',
#   'grow',
#   'more',
#   'and',
#   'more',
#   'it',
#   'companies',
#   'will',
#   'come',
#   'from',
#   'across',
#   'the',
#   'world',
#   'and',
#   'more',
#   'will',
#   'the',
#   'competition',
#   'in',
#   'the',
#   'market',
#   'increase',
#   'this',
#   'will',
#   'help',
#   'consumers',
#   'as',
#   'they',
#   'will',
#   'get',
#   'more',
#   'and',
#   'more',
#   'differentiated',
#   'products',
#   'and',
#   'the',
#   'market',
#   'will',
#   'also',
#   'run',
#   'smoothly',
#   'a',
#   'competitive',
#   'market',
#   'is',
#   'always',
#   'good',
#   'and',
#   'healthy',
#   'we',
#   'can',
#   'safely',
#   'assume',
#   'that',
#   'our',
#   'oligopoly',
#   'market',
#   'will',
#   'surely',
#   'tend',
#   'to',
#   'reach',
#   'a',
#   'perfectly',
#   'competitive',
#   'market',
#   'by',
#   'the',
#   'year',
#   'the',
#   'market',
#   'increases',
#   'more',
#   'revenue',
#   'will',
#   'be',
#   'generated',
#   'now',
#   'at',
#   'present',
#   'the',
#   'it',
#   'revenue',
#   'of',
#   'india',
#   'is',
#   'million',
#   'dollars',
#   'million',
#   'dollars',
#   'more',
#   'than',
#   'the',
#   'financial',
#   'year',
#   'if',
#   'it',
#   'cities',
#   'grow',
#   'then',
#   'more',
#   'companies',
#   'will',
#   'invest',
#   'which',
#   'leads',
#   'to',
#   'an',
#   'increase',
#   'in',
#   'the',
#   'it',
#   'market',
#   'which',
#   'in',
#   'turn',
#   'generates',
#   'more',
#   'revenue',
#   'in',
#   'india',
#   'we',
#   'can',
#   'expect',
#   'that',
#   'the',
#   'it',
#   'revenue',
#   'of',
#   'india',
#   'will',
#   'cross',
#   'or',
#   'nearly',
#   'tend',
#   'to',
#   'reach',
#   'billion',
#   'dollars',
#   'by',
#   'on',
#   'environmentthe',
#   'rising',
#   'it',
#   'cities',
#   'will',
#   'create',
#   'a',
#   'huge',
#   'impact',
#   'on',
#   'the',
#   'environment',
#   'the',
#   'maximum',
#   'of',
#   'which',
#   'will',
#   'be',
#   'harmful',
#   'effects',
#   'the',
#   'impact',
#   'of',
#   'rising',
#   'it',
#   'cities',
#   'on',
#   'the',
#   'environment',
#   'will',
#   'be',
#   'cutting',
#   'of',
#   'trees',
#   'in',
#   'huge',
#   'numbers',
#   'to',
#   'make',
#   'the',
#   'building',
#   'of',
#   'the',
#   'it',
#   'companies',
#   'which',
#   'will',
#   'cause',
#   'great',
#   'harm',
#   'to',
#   'the',
#   'environment',
#   'the',
#   'cutting',
#   'of',
#   'trees',
#   'on',
#   'a',
#   'large',
#   'scale',
#   'will',
#   'also',
#   'cause',
#   'mass',
#   'degradation',
#   'of',
#   'carbon',
#   'footprint',
#   'it',
#   'companies',
#   'will',
#   'generate',
#   'more',
#   'carbon',
#   'footprint',
#   'in',
#   'the',
#   'atmosphere',
#   'south',
#   'asian',
#   'countries',
#   'including',
#   'india',
#   'are',
#   'known',
#   'for',
#   'their',
#   'lower',
#   'carbon',
#   'footprint',
#   'but',
#   'if',
#   'the',
#   'it',
#   'sector',
#   'grows',
#   'this',
#   'way',
#   'then',
#   'we',
#   'will',
#   'also',
#   'be',
#   'at',
#   'the',
#   'same',
#   'pace',
#   'of',
#   'generation',
#   'of',
#   'carbon',
#   'footprint',
#   'by',
#   'of',
#   'birds',
#   'cell',
#   'phone',
#   'and',
#   'mobile',
#   'towers',
#   'by',
#   'the',
#   'telecom',
#   'companies',
#   'caused',
#   'the',
#   'death',
#   'of',
#   'birds',
#   'which',
#   'caused',
#   'a',
#   'great',
#   'imbalance',
#   'in',
#   'the',
#   'ecosystem',
#   'the',
#   'number',
#   'of',
#   'sparrows',
#   'has',
#   'been',
#   'reduced',
#   'due',
#   'to',
#   'this',
#   'phenomenon',
#   'if',
#   'this',
#   'goes',
#   'on',
#   'we',
#   'can',
#   'see',
#   'the',
#   'extinction',
#   'of',
#   'many',
#   'bird',
#   'species',
#   'by',
#   'on',
#   'infrastructurethere',
#   'are',
#   'many',
#   'contributions',
#   'of',
#   'the',
#   'it',
#   'cities',
#   'on',
#   'infrastructure',
#   'they',
#   'rising',
#   'it',
#   'cities',
#   'need',
#   'an',
#   'excellent',
#   'transport',
#   'system',
#   'for',
#   'the',
#   'supply',
#   'of',
#   'raw',
#   'materials',
#   'and',
#   'delivery',
#   'of',
#   'the',
#   'finished',
#   'products',
#   'into',
#   'the',
#   'market',
#   'so',
#   'the',
#   'transportation',
#   'system',
#   'develops',
#   'in',
#   'that',
#   'area',
#   'so',
#   'we',
#   'have',
#   'an',
#   'excellent',
#   'transport',
#   'system',
#   'by',
#   'for',
#   'apublic',
#   'transport',
#   'system',
#   'there',
#   'is',
#   'a',
#   'need',
#   'for',
#   'a',
#   'public',
#   'transport',
#   'system',
#   'in',
#   'the',
#   'it',
#   'cities',
#   'as',
#   'the',
#   'it',
#   'cities',
#   'are',
#   'a',
#   'source',
#   'of',
#   'employment',
#   'and',
#   'a',
#   'huge',
#   'population',
#   'reside',
#   'in',
#   'these',
#   'areas',
#   'there',
#   'is',
#   'an',
#   'adequate',
#   'need',
#   'for',
#   'public',
#   'transport',
#   'systems',
#   'like',
#   'buses',
#   'taxis',
#   'etc',
#   'we',
#   'hope',
#   'that',
#   'it',
#   'will',
#   'be',
#   'improved',
#   'by',
#   'supply',
#   'a',
#   'huge',
#   'number',
#   'of',
#   'people',
#   'reside',
#   'in',
#   'the',
#   'it',
#   'cities',
#   'there',
#   'is',
#   'a',
#   'need',
#   'for',
#   'adequate',
#   'water',
#   'supply',
#   'to',
#   'fulfil',
#   'the',
#   'needs',
#   'of',
#   'people',
#   'as',
#   'well',
#   'as',
#   'for',
#   'industries',
#   'this',
#   'will',
#   'help',
#   'us',
#   'to',
#   'find',
#   'many',
#   'new',
#   'methods',
#   'of',
#   'water',
#   'supply',
#   'and',
#   'conservation',
#   'by',
#   'supply',
#   'is',
#   'the',
#   'lifeline',
#   'of',
#   'the',
#   'sector',
#   'without',
#   'an',
#   'electric',
#   'supply',
#   'no',
#   'machines',
#   'will',
#   'run',
#   'and',
#   'not',
#   'even',
#   'the',
#   'it',
#   'cities',
#   'will',
#   'flourish',
#   'if',
#   'the',
#   'it',
#   'cities',
#   'flourish',
#   'this',
#   'way',
#   'we',
#   'going',
#   'to',
#   'have',
#   'an',
#   'excellent',
#   'electric',
#   'supply',
#   'by',
#   'a',
#   'large',
#   'number',
#   'of',
#   'people',
#   'reside',
#   'in',
#   'it',
#   'cities',
#   'there',
#   'is',
#   'a',
#   'need',
#   'for',
#   'proper',
#   'health',
#   'infrastructure',
#   'and',
#   ...],
#  'blackassign0002.txt': ['rising',
#   'it',
#   'cities',
#   'and',
#   'their',
#   'impact',
#   'on',
#   'the',
#   'economy',
#   'environment',
#   'infrastructure',
#   'and',
#   'city',
#   'life',
#   'in',
#   'future',
#   'blackcoffer',
#   'insights',
#   'throughout',
#   'history',
#   'from',
#   'the',
#   'industrial',
#   'revolution',
#   'in',
#   'the',
#   'century',
#   'through',
#   'the',
#   'development',
#   'of',
#   'the',
#   'internet',
#   'technology',
#   'has',
#   'been',
#   'the',
#   'primary',
#   'driver',
#   'of',
#   'societal',
#   'change',
#   'it',
#   'has',
#   'aided',
#   'in',
#   'turning',
#   'cities',
#   'into',
#   'smart',
#   'urban',
#   'centers',
#   'that',
#   'provide',
#   'more',
#   'opportunities',
#   'and',
#   'improvements',
#   'in',
#   'quality',
#   'of',
#   'life',
#   'it',
#   'continues',
#   'to',
#   'play',
#   'a',
#   'crucial',
#   'role',
#   'in',
#   'altering',
#   'the',
#   'world',
#   'cities',
#   'are',
#   'acting',
#   'as',
#   'engines',
#   'of',
#   'economic',
#   'growth',
#   'and',
#   'modernization',
#   'as',
#   'they',
#   'become',
#   'more',
#   'technologically',
#   'advanced',
#   'considerably',
#   'accelerating',
#   'the',
#   'trajectory',
#   'ofglobal',
#   'development',
#   'technology',
#   'has',
#   'had',
#   'nothing',
#   'short',
#   'of',
#   'revolutionary',
#   'effects',
#   'on',
#   'indian',
#   'cities',
#   'ushering',
#   'in',
#   'a',
#   'new',
#   'era',
#   'of',
#   'change',
#   'and',
#   'advancement',
#   'india',
#   'smetropolitan',
#   'centershave',
#   'embraced',
#   'technology',
#   'in',
#   'ways',
#   'that',
#   'are',
#   'transforming',
#   'the',
#   'fundamental',
#   'fabric',
#   'of',
#   'urban',
#   'life',
#   'from',
#   'infrastructure',
#   'to',
#   'governance',
#   'and',
#   'beyond',
#   'as',
#   'the',
#   'world',
#   'rushes',
#   'into',
#   'the',
#   'digital',
#   's',
#   'cities',
#   'must',
#   'play',
#   'a',
#   'crucial',
#   'part',
#   'if',
#   'the',
#   'nation',
#   'is',
#   'to',
#   'develop',
#   'into',
#   'a',
#   'worldwide',
#   'economic',
#   'powerhouse',
#   'one',
#   'of',
#   'the',
#   'world',
#   's',
#   'economies',
#   'with',
#   'the',
#   'greatest',
#   'growth',
#   'rates',
#   'india',
#   'aims',
#   'to',
#   'reach',
#   'us',
#   'trillion',
#   'ingdpby',
#   'and',
#   'us',
#   'trillion',
#   'by',
#   'the',
#   'year',
#   'it',
#   'will',
#   'celebrate',
#   'years',
#   'of',
#   'independence',
#   'the',
#   'idea',
#   'of',
#   'smart',
#   'cities',
#   'is',
#   'one',
#   'of',
#   'technology',
#   's',
#   'most',
#   'obvious',
#   'effects',
#   'indian',
#   'cities',
#   'are',
#   'progressively',
#   'implementing',
#   'technologies',
#   'to',
#   'build',
#   'effective',
#   'linked',
#   'urban',
#   'landscapes',
#   'to',
#   'improve',
#   'the',
#   'quality',
#   'of',
#   'life',
#   'for',
#   'people',
#   'smart',
#   'cities',
#   'use',
#   'data',
#   'analytics',
#   'theinternet',
#   'of',
#   'things',
#   'iot',
#   'traffic',
#   'management',
#   'solutions',
#   'for',
#   'instance',
#   'improve',
#   'traffic',
#   'flow',
#   'while',
#   'lowering',
#   'congestion',
#   'and',
#   'air',
#   'pollution',
#   'garbage',
#   'collection',
#   'improves',
#   'waste',
#   'management',
#   'resulting',
#   'in',
#   'cleaner',
#   'and',
#   'healthier',
#   'become',
#   'a',
#   'major',
#   'player',
#   'in',
#   'the',
#   'world',
#   'economy',
#   'however',
#   'several',
#   'steps',
#   'are',
#   'being',
#   'followed',
#   'a',
#   'crucial',
#   'one',
#   'relates',
#   'to',
#   'india',
#   's',
#   'ongoing',
#   'urbanization',
#   'development',
#   'between',
#   'and',
#   'the',
#   'population',
#   'of',
#   'indian',
#   'cities',
#   'is',
#   'predicted',
#   'to',
#   'have',
#   'expanded',
#   'from',
#   'million',
#   'to',
#   'million',
#   'nearly',
#   'a',
#   'fourfold',
#   'nation',
#   'which',
#   'already',
#   'has',
#   'the',
#   'urban',
#   'population',
#   'in',
#   'the',
#   'world',
#   'is',
#   'predicted',
#   'to',
#   'have',
#   'a',
#   'urban',
#   'population',
#   'share',
#   'by',
#   'after',
#   'adding',
#   'million',
#   'residents',
#   'to',
#   'its',
#   'cities',
#   'are',
#   'the',
#   'centers',
#   'of',
#   'economic',
#   'growth',
#   'and',
#   'innovation',
#   'because',
#   'they',
#   'are',
#   'home',
#   'to',
#   'innovative',
#   'businesses',
#   'employment',
#   'and',
#   'important',
#   'institutions',
#   'kolkata',
#   'delhi',
#   'mumbai',
#   'chennai',
#   'cities',
#   'foster',
#   'increased',
#   'productivity',
#   'through',
#   'several',
#   'routes',
#   'generally',
#   'known',
#   'asagglomeration',
#   'economies',
#   'by',
#   'permitting',
#   'close',
#   'contact',
#   'between',
#   'businesses',
#   'and',
#   'employees',
#   'the',
#   'theory',
#   's',
#   'main',
#   'consequence',
#   'is',
#   'that',
#   'businesses',
#   'in',
#   'bigger',
#   'denser',
#   'cities',
#   'should',
#   'be',
#   'more',
#   'productive',
#   'in',
#   'the',
#   'year',
#   'urbanization',
#   'has',
#   'had',
#   'a',
#   'significant',
#   'impact',
#   'on',
#   'both',
#   'india',
#   'and',
#   'the',
#   'rest',
#   'of',
#   'the',
#   'world',
#   'india',
#   'now',
#   'boasts',
#   'the',
#   'economy',
#   'in',
#   'the',
#   'world',
#   'only',
#   'behind',
#   'china',
#   'and',
#   'the',
#   'united',
#   'states',
#   'in',
#   'this',
#   'new',
#   'period',
#   'china',
#   'has',
#   'already',
#   'exceeded',
#   'the',
#   'usa',
#   'in',
#   'terms',
#   'of',
#   'economic',
#   'size',
#   'while',
#   'india',
#   'has',
#   'surpassed',
#   'japan',
#   'to',
#   'claim',
#   'a',
#   'higher',
#   'place',
#   'although',
#   'india',
#   'has',
#   'million',
#   'people',
#   'living',
#   'in',
#   'urbanized',
#   'cities',
#   'china',
#   'has',
#   'a',
#   'stunning',
#   'one',
#   'billion',
#   'people',
#   'living',
#   'in',
#   'urbanized',
#   'has',
#   'both',
#   'advantages',
#   'and',
#   'disadvantages',
#   'including',
#   'financial',
#   'expenditures',
#   'although',
#   'city',
#   'growth',
#   'can',
#   'result',
#   'in',
#   'better',
#   'possibilities',
#   'and',
#   'a',
#   'higher',
#   'standard',
#   'of',
#   'living',
#   'it',
#   'also',
#   'presents',
#   'difficulties',
#   'and',
#   'issues',
#   'rapid',
#   'urbanization',
#   'has',
#   'the',
#   'potential',
#   'to',
#   'deplete',
#   'resources',
#   'harm',
#   'the',
#   'environment',
#   'and',
#   'worsensocioeconomicinequities',
#   'depending',
#   'on',
#   'how',
#   'well',
#   'these',
#   'problems',
#   'are',
#   'solved',
#   'urbanization',
#   'will',
#   'either',
#   'have',
#   'a',
#   'favorable',
#   'or',
#   'negative',
#   'overall',
#   'more',
#   'than',
#   'half',
#   'of',
#   'the',
#   'world',
#   's',
#   'population',
#   'now',
#   'living',
#   'in',
#   'cities',
#   'urbanization',
#   'has',
#   'emerged',
#   'as',
#   'a',
#   'major',
#   'force',
#   'for',
#   'development',
#   'but',
#   'it',
#   'also',
#   'presents',
#   'fresh',
#   'difficulties',
#   'and',
#   'chances',
#   'reshaping',
#   'the',
#   'planet',
#   'and',
#   'our',
#   'way',
#   'of',
#   'life',
#   'in',
#   'unexpected',
#   'ways',
#   'a',
#   'future',
#   'whereartificial',
#   'intelligence',
#   'ai',
#   'is',
#   'increasingly',
#   'pervasive',
#   'and',
#   'has',
#   'an',
#   'impact',
#   'on',
#   'many',
#   'parts',
#   'of',
#   'our',
#   'daily',
#   'lives',
#   'has',
#   'been',
#   'ushered',
#   'in',
#   'by',
#   'this',
#   'shift',
#   'urbanization',
#   'has',
#   'improved',
#   'living',
#   'conditions',
#   'and',
#   'economic',
#   'opportunities',
#   'but',
#   'it',
#   'also',
#   'calls',
#   'for',
#   'careful',
#   'management',
#   'and',
#   'sustainable',
#   'practices',
#   'to',
#   'guarantee',
#   'a',
#   'bright',
#   'and',
#   'prosperous',
#   'future',
#   'for',
#   'to',
#   'this',
#   'a',
#   'nation',
#   's',
#   'population',
#   'and',
#   'demography',
#   'can',
#   'contribute',
#   'significantly',
#   'to',
#   'its',
#   'growth',
#   'india',
#   's',
#   'rapidly',
#   'rising',
#   'population',
#   'will',
#   'be',
#   'in',
#   'its',
#   'favor',
#   'and',
#   'the',
#   'nation',
#   'is',
#   'expected',
#   'to',
#   'host',
#   'some',
#   'of',
#   'the',
#   'cities',
#   'in',
#   'the',
#   'world',
#   'in',
#   'the',
#   'years',
#   'to',
#   'come',
#   'the',
#   'west',
#   'is',
#   'also',
#   'taken',
#   'aback',
#   'by',
#   'the',
#   'annual',
#   'gdp',
#   'growth',
#   'rate',
#   'of',
#   'the',
#   'cities',
#   'that',
#   'are',
#   'predicted',
#   'to',
#   'top',
#   'the',
#   'charts',
#   'aside',
#   'from',
#   'a',
#   'few',
#   'towns',
#   'in',
#   'southeast',
#   'asia',
#   'all',
#   'of',
#   'the',
#   'cities',
#   'are',
#   'now',
#   'from',
#   'the',
#   'asian',
#   'bloc',
#   'which',
#   'is',
#   'primarily',
#   'controlled',
#   'by',
#   'india',
#   'and',
#   'china',
#   'bangalore',
#   'which',
#   'has',
#   'had',
#   'an',
#   'enormous',
#   'percent',
#   'gdp',
#   'growth',
#   'is',
#   'in',
#   'first',
#   'place',
#   'followed',
#   'by',
#   'dhaka',
#   'mumbai',
#   'and',
#   'delhi',
#   'bangalore',
#   's',
#   'startup',
#   'culture',
#   'and',
#   'enormous',
#   'skill',
#   'pool',
#   'set',
#   'it',
#   'apart',
#   'from',
#   'other',
#   'cities',
#   'bangalore',
#   'itself',
#   'is',
#   'probably',
#   'going',
#   'to',
#   'bethe',
#   'future',
#   'silicon',
#   'valleyof',
#   'asia',
#   'and',
#   'the',
#   'entire',
#   'world',
#   'it',
#   'currently',
#   'creates',
#   'a',
#   'tremendous',
#   'number',
#   'of',
#   'startups',
#   'it',
#   'has',
#   'the',
#   'potential',
#   'to',
#   'rank',
#   'among',
#   'the',
#   'world',
#   's',
#   'most',
#   'urbanized',
#   'cities',
#   'these',
#   'cities',
#   'will',
#   'outpace',
#   'the',
#   'global',
#   'average',
#   'yearly',
#   'gdp',
#   'growth',
#   'rate',
#   'which',
#   'is',
#   'expected',
#   'to',
#   'be',
#   'about',
#   'by',
#   'a',
#   'sizeable',
#   'nations',
#   'will',
#   'expand',
#   'and',
#   'cities',
#   'will',
#   'modernize',
#   'to',
#   'meet',
#   'societal',
#   'demands',
#   'urban',
#   'city',
#   'growth',
#   'has',
#   'mostly',
#   'been',
#   'attributed',
#   'to',
#   'migration',
#   'however',
#   'the',
#   'future',
#   'will',
#   'be',
#   'better',
#   'for',
#   'us',
#   'and',
#   'our',
#   'offspring',
#   'if',
#   'we',
#   'can',
#   'maintain',
#   'a',
#   'balance',
#   'between',
#   'the',
#   'environment',
#   'and',
#   'sustainable',
#   'growth',
#   'we',
#   'are',
#   'being',
#   'impacted',
#   'by',
#   'climate',
#   'change',
#   'which',
#   'is',
#   'real',
#   'in',
#   'large',
#   'areas',
#   'the',
#   'effects',
#   'of',
#   'climate',
#   'change',
#   'will',
#   'harm',
#   'the',
#   'environment',
#   'through',
#   'prolonged',
#   'heat',
#   'waves',
#   'more',
#   'irregular',
#   'rainfall',
#   'drought',
#   'and',
#   'we',
#   'can',
#   'see',
#   'in',
#   'pakistan',
#   'china',
#   'and',
#   'europe',
#   'europe',
#   'as',
#   'a',
#   'whole',
#   'has',
#   'seen',
#   'heat',
#   'waves',
#   'that',
#   'have',
#   'disrupted',
#   'society',
#   'and',
#   'china',
#   'is',
#   'currently',
#   'dealing',
#   'with',
#   'extreme',
#   'heat',
#   'waves',
#   'that',
#   'are',
#   'drying',
#   'up',
#   'the',
#   'rivers',
#   'and',
#   'making',
#   'it',
#   'impossible',
#   'to',
#   'produce',
#   'hydroelectricity',
#   'in',
#   'pakistan',
#   'there',
#   'were',
#   'an',
#   'unusually',
#   'high',
#   'number',
#   'of',
#   'floods',
#   'out',
#   'of',
#   'districts',
#   'are',
#   'underwater',
#   'representing',
#   'a',
#   'loss',
#   'of',
#   'roughly',
#   'agrarian',
#   'and',
#   'pastoralist',
#   'types',
#   'of',
#   'society',
#   'which',
#   'heavily',
#   'rely',
#   'on',
#   'the',
#   'environment',
#   'are',
#   'severely',
#   'impacted',
#   'by',
#   'these',
#   'effects',
#   'migration',
#   'is',
#   'projected',
#   'to',
#   'rise',
#   'as',
#   'livelihoods',
#   'all',
#   'around',
#   'the',
#   'world',
#   'are',
#   'affected',
#   'more',
#   'and',
#   'more',
#   'by',
#   'climate',
#   'broader',
#   'prospects',
#   'of',
#   'regional',
#   'environments',
#   'are',
#   'likewise',
#   'impacted',
#   'by',
#   'urbanization',
#   'large',
#   'increases',
#   'in',
#   'the',
#   'amount',
#   'of',
#   'air',
#   'pollution',
#   'precipitation',
#   'and',
#   'the',
#   'frequency',
#   'of',
#   'days',
#   'with',
#   'thunderstorms',
#   'are',
#   'also',
#   'observed',
#   'in',
#   'areas',
#   'that',
#   'are',
#   'downwind',
#   'from',
#   'large',
#   ...],
#  'blackassign0003.txt': ['internet',
#   'demand',
#   'evolution',
#   'communication',
#   'impact',
#   'and',
#   'alternative',
#   'pathways',
#   'blackcoffer',
#   'insights',
#   'introductionin',
#   'the',
#   'span',
#   'of',
#   'just',
#   'a',
#   'few',
#   'decades',
#   'the',
#   'internet',
#   'has',
#   'undergone',
#   'an',
#   'astounding',
#   'transformation',
#   'becoming',
#   'an',
#   'integral',
#   'part',
#   'of',
#   'our',
#   'lives',
#   'as',
#   'we',
#   'approach',
#   'the',
#   'year',
#   'the',
#   'demand',
#   'for',
#   'internet',
#   'connectivity',
#   'continues',
#   'to',
#   'surge',
#   'promising',
#   'to',
#   'revolutionize',
#   'the',
#   'way',
#   'we',
#   'communicate',
#   'and',
#   'interact',
#   'with',
#   'the',
#   'world',
#   'it',
#   'also',
#   'has',
#   'transformed',
#   'from',
#   'a',
#   'limited',
#   'communication',
#   'tool',
#   'to',
#   'an',
#   'global',
#   'network',
#   'that',
#   'shapes',
#   'our',
#   'daily',
#   'lives',
#   'as',
#   'we',
#   'hurtle',
#   'toward',
#   'the',
#   'year',
#   'the',
#   'trajectory',
#   'of',
#   'internet',
#   'demand',
#   'and',
#   'its',
#   'profound',
#   'impact',
#   'on',
#   'communication',
#   'is',
#   'poised',
#   'to',
#   'reshape',
#   'the',
#   'very',
#   'foundations',
#   'of',
#   'how',
#   'we',
#   'connect',
#   'and',
#   'interact',
#   'this',
#   'article',
#   'delves',
#   'into',
#   'the',
#   'intricate',
#   'interplay',
#   'between',
#   'internet',
#   'demand',
#   'communication',
#   'dynamics',
#   'and',
#   'the',
#   'alternative',
#   'pathways',
#   'that',
#   'could',
#   'define',
#   'our',
#   'internet',
#   's',
#   'unstoppable',
#   'risethe',
#   'proliferation',
#   'of',
#   'smartphones',
#   'the',
#   'internet',
#   'of',
#   'things',
#   'iot',
#   'and',
#   'the',
#   'increasing',
#   'reliance',
#   'on',
#   'digital',
#   'services',
#   'have',
#   'driven',
#   'an',
#   'exponential',
#   'increase',
#   'in',
#   'internet',
#   'demand',
#   'this',
#   'surge',
#   'is',
#   'fueled',
#   'by',
#   'a',
#   'growing',
#   'need',
#   'for',
#   'faster',
#   'data',
#   'speeds',
#   'seamless',
#   'connectivity',
#   'and',
#   'access',
#   'to',
#   'information',
#   'and',
#   'services',
#   'as',
#   'the',
#   'digital',
#   'divide',
#   'narrows',
#   'more',
#   'individuals',
#   'and',
#   'communities',
#   'are',
#   'becoming',
#   'dependent',
#   'on',
#   'the',
#   'internet',
#   'for',
#   'education',
#   'healthcare',
#   'commerce',
#   'and',
#   'social',
#   'interactions',
#   'the',
#   'exponential',
#   'growth',
#   'of',
#   'internet',
#   'demand',
#   'has',
#   'been',
#   'a',
#   'defining',
#   'hallmark',
#   'of',
#   'the',
#   'digital',
#   'age',
#   'from',
#   'basic',
#   'web',
#   'browsing',
#   'to',
#   'streaming',
#   'content',
#   'and',
#   'remote',
#   'collaborations',
#   'the',
#   'demands',
#   'placed',
#   'on',
#   'internet',
#   'infrastructure',
#   'have',
#   'surged',
#   'astronomically',
#   'this',
#   'demand',
#   'is',
#   'catalyzed',
#   'by',
#   'the',
#   'proliferation',
#   'of',
#   'smart',
#   'devices',
#   'the',
#   'internet',
#   'of',
#   'things',
#   'iot',
#   'and',
#   'the',
#   'insatiable',
#   'appetite',
#   'for',
#   'seamless',
#   'on',
#   'communicationsby',
#   'the',
#   'impact',
#   'of',
#   'rising',
#   'internet',
#   'demand',
#   'on',
#   'communication',
#   'will',
#   'be',
#   'the',
#   'most',
#   'notable',
#   'transformation',
#   'will',
#   'likely',
#   'occur',
#   'in',
#   'the',
#   'realm',
#   'of',
#   'connectivity',
#   'the',
#   'continued',
#   'development',
#   'of',
#   'technology',
#   'and',
#   'potentially',
#   'newer',
#   'innovations',
#   'will',
#   'enable',
#   'data',
#   'transfers',
#   'virtually',
#   'eliminating',
#   'lag',
#   'and',
#   'latency',
#   'this',
#   'will',
#   'redefine',
#   'remote',
#   'collaboration',
#   'gaming',
#   'experiences',
#   'and',
#   'communication',
#   'applications',
#   'moreover',
#   'the',
#   'surge',
#   'in',
#   'internet',
#   'demand',
#   'will',
#   'catalyze',
#   'the',
#   'evolution',
#   'of',
#   'virtual',
#   'and',
#   'augmented',
#   'reality',
#   'communication',
#   'these',
#   'technologies',
#   'will',
#   'enable',
#   'individuals',
#   'to',
#   'interact',
#   'as',
#   'if',
#   'they',
#   'were',
#   'physically',
#   'present',
#   'transcending',
#   'geographical',
#   'boundaries',
#   'and',
#   'enabling',
#   'immersive',
#   'experiences',
#   'teleconferencing',
#   'education',
#   'and',
#   'even',
#   'social',
#   'gatherings',
#   'could',
#   'become',
#   'more',
#   'engaging',
#   'and',
#   'interactive',
#   'as',
#   'the',
#   'internet',
#   'demand',
#   'continues',
#   'to',
#   'rise',
#   'the',
#   'realm',
#   'of',
#   'communication',
#   'is',
#   'set',
#   'for',
#   'a',
#   'monumental',
#   'transformation',
#   'connectivity',
#   'driven',
#   'by',
#   'advancements',
#   'in',
#   'and',
#   'beyond',
#   'will',
#   'render',
#   'buffering',
#   'and',
#   'lag',
#   'virtually',
#   'obsolete',
#   'this',
#   'will',
#   'revolutionize',
#   'virtual',
#   'experiences',
#   'remote',
#   'work',
#   'and',
#   'digital',
#   'entertainment',
#   'fostering',
#   'a',
#   'sense',
#   'of',
#   'immediacy',
#   'and',
#   'presence',
#   'previously',
#   'unimaginable',
#   'the',
#   'integration',
#   'of',
#   'augmented',
#   'and',
#   'virtual',
#   'reality',
#   'will',
#   'further',
#   'reshape',
#   'communication',
#   'dynamics',
#   'from',
#   'immersive',
#   'virtual',
#   'meetings',
#   'to',
#   'interactive',
#   'entertainment',
#   'experiences',
#   'will',
#   'bridge',
#   'physical',
#   'distances',
#   'and',
#   'offer',
#   'an',
#   'entirely',
#   'new',
#   'dimension',
#   'of',
#   'and',
#   'strain',
#   'on',
#   'infrastructurehowever',
#   'the',
#   'exponential',
#   'increase',
#   'in',
#   'internet',
#   'demand',
#   'brings',
#   'its',
#   'own',
#   'set',
#   'of',
#   'challenges',
#   'the',
#   'existing',
#   'network',
#   'infrastructure',
#   'may',
#   'struggle',
#   'to',
#   'keep',
#   'up',
#   'with',
#   'the',
#   'bandwidth',
#   'requirements',
#   'leading',
#   'to',
#   'congestion',
#   'and',
#   'reduced',
#   'quality',
#   'of',
#   'service',
#   'this',
#   'could',
#   'result',
#   'in',
#   'a',
#   'digital',
#   'divide',
#   'between',
#   'urban',
#   'and',
#   'rural',
#   'areas',
#   'as',
#   'well',
#   'as',
#   'underserved',
#   'communities',
#   'moreover',
#   'the',
#   'influx',
#   'of',
#   'data',
#   'traffic',
#   'raises',
#   'concerns',
#   'about',
#   'data',
#   'privacy',
#   'and',
#   'security',
#   'protecting',
#   'sensitive',
#   'information',
#   'from',
#   'cyber',
#   'threats',
#   'and',
#   'ensuring',
#   'the',
#   'integrity',
#   'of',
#   'personal',
#   'data',
#   'will',
#   'become',
#   'paramount',
#   'striking',
#   'a',
#   'balance',
#   'between',
#   'seamless',
#   'connectivity',
#   'and',
#   'robust',
#   'security',
#   'measures',
#   'will',
#   'be',
#   'a',
#   'complex',
#   'in',
#   'the',
#   'hyperconnected',
#   'landscapethe',
#   'surge',
#   'in',
#   'internet',
#   'demand',
#   'while',
#   'promising',
#   'comes',
#   'with',
#   'its',
#   'own',
#   'set',
#   'of',
#   'challenges',
#   'the',
#   'existing',
#   'network',
#   'infrastructure',
#   'may',
#   'struggle',
#   'to',
#   'accommodate',
#   'the',
#   'escalating',
#   'bandwidth',
#   'requirements',
#   'leading',
#   'to',
#   'congestion',
#   'and',
#   'inequitable',
#   'access',
#   'rural',
#   'areas',
#   'and',
#   'underserved',
#   'communities',
#   'could',
#   'face',
#   'connectivity',
#   'disparities',
#   'potentially',
#   'exacerbating',
#   'existing',
#   'digital',
#   'divides',
#   'moreover',
#   'the',
#   'influx',
#   'of',
#   'data',
#   'traffic',
#   'raises',
#   'concerns',
#   'about',
#   'data',
#   'privacy',
#   'security',
#   'breaches',
#   'and',
#   'the',
#   'responsible',
#   'use',
#   'of',
#   'emerging',
#   'technologies',
#   'the',
#   'hyperconnected',
#   'landscape',
#   'demands',
#   'robust',
#   'measures',
#   'to',
#   'protect',
#   'sensitive',
#   'information',
#   'and',
#   'ensure',
#   'ethical',
#   'alternativesas',
#   'the',
#   'demand',
#   'for',
#   'internet',
#   'connectivity',
#   'intensifies',
#   'alternative',
#   'communication',
#   'methods',
#   'are',
#   'emerging',
#   'as',
#   'potential',
#   'solutions',
#   'two',
#   'noteworthy',
#   'alternatives',
#   'are',
#   'decentralized',
#   'networks',
#   'and',
#   'mesh',
#   'networks',
#   'decentralized',
#   'networks',
#   'often',
#   'based',
#   'on',
#   'blockchain',
#   'technology',
#   'distribute',
#   'control',
#   'across',
#   'multiple',
#   'nodes',
#   'enhancing',
#   'security',
#   'and',
#   'reducing',
#   'the',
#   'risk',
#   'of',
#   'central',
#   'points',
#   'of',
#   'failure',
#   'mesh',
#   'networks',
#   'on',
#   'the',
#   'other',
#   'hand',
#   'operate',
#   'by',
#   'connecting',
#   'devices',
#   'directly',
#   'to',
#   'one',
#   'another',
#   'creating',
#   'a',
#   'network',
#   'without',
#   'the',
#   'need',
#   'for',
#   'traditional',
#   'centralized',
#   'infrastructure',
#   'this',
#   'approach',
#   'could',
#   'prove',
#   'invaluable',
#   'in',
#   'areas',
#   'with',
#   'limited',
#   'connectivity',
#   'or',
#   'during',
#   'emergencies',
#   'when',
#   'conventional',
#   'networks',
#   'are',
#   'disrupted',
#   'in',
#   'the',
#   'face',
#   'of',
#   'these',
#   'challenges',
#   'alternative',
#   'pathways',
#   'are',
#   'emerging',
#   'to',
#   'shape',
#   'the',
#   'hyperconnected',
#   'future',
#   'decentralized',
#   'networks',
#   'underpinned',
#   'by',
#   'blockchain',
#   'technology',
#   'offer',
#   'a',
#   'promising',
#   'solution',
#   'by',
#   'distributing',
#   'control',
#   'across',
#   'a',
#   'network',
#   'of',
#   'nodes',
#   'these',
#   'systems',
#   'enhance',
#   'security',
#   'and',
#   'resilience',
#   'reducing',
#   'vulnerabilities',
#   'associated',
#   'with',
#   'centralized',
#   'control',
#   'mesh',
#   'networks',
#   'another',
#   'alternative',
#   'challenge',
#   'the',
#   'conventional',
#   'communication',
#   'paradigm',
#   'by',
#   'establishing',
#   'direct',
#   'connections',
#   'these',
#   'networks',
#   'bypass',
#   'the',
#   'need',
#   'for',
#   'traditional',
#   'centralized',
#   'infrastructure',
#   'making',
#   'them',
#   'particularly',
#   'valuable',
#   'in',
#   'remote',
#   'or',
#   'forging',
#   'the',
#   'hyperconnected',
#   'path',
#   'aheadthe',
#   'year',
#   'holds',
#   'the',
#   'promise',
#   'of',
#   'a',
#   'world',
#   'with',
#   'the',
#   'surge',
#   'in',
#   'internet',
#   'demand',
#   'propelling',
#   'us',
#   'into',
#   'a',
#   'new',
#   'era',
#   'of',
#   'communication',
#   'the',
#   'impact',
#   'will',
#   'be',
#   'transformative',
#   'from',
#   'the',
#   'widespread',
#   'adoption',
#   'of',
#   'connectivity',
#   'to',
#   'the',
#   'integration',
#   'of',
#   'into',
#   'everyday',
#   'interactions',
#   'yet',
#   'as',
#   'we',
#   'navigate',
#   'this',
#   'digital',
#   'frontier',
#   'it',
#   's',
#   'crucial',
#   'to',
#   'address',
#   'the',
#   'challenges',
#   'of',
#   'strained',
#   'infrastructure',
#   'security',
#   'vulnerabilities',
#   'and',
#   'potential',
#   'inequalities',
#   'in',
#   'alternatives',
#   'such',
#   'as',
#   'decentralized',
#   'and',
#   'mesh',
#   'networks',
#   'showcase',
#   'our',
#   'capacity',
#   'to',
#   'innovate',
#   'and',
#   'adapt',
#   'in',
#   'the',
#   'face',
#   'of',
#   'growing',
#   'internet',
#   'demand',
#   'as',
#   'we',
#   'stride',
#   'toward',
#   'striking',
#   'the',
#   'right',
#   'balance',
#   'between',
#   'connectivity',
#   'security',
#   'and',
#   'accessibility',
#   'will',
#   'shape',
#   'the',
#   'future',
#   'of',
#   'global',
#   'we',
#   'navigate',
#   'the',
#   'hyperconnected',
#   'future',
#   'we',
#   'stand',
#   'at',
#   'a',
#   'pivotal',
#   'juncture',
#   'where',
#   'our',
#   'choices',
#   'will',
#   'shape',
#   'the',
#   'world',
#   'we',
#   'inhabit',
#   'the',
#   'rise',
#   'in',
#   'internet',
#   'demand',
#   'with',
#   'its',
#   'transformative',
#   'impact',
#   'on',
#   'communication',
#   'opens',
#   'the',
#   'door',
#   'to',
#   'unprecedented',
#   'possibilities',
#   'however',
#   'the',
#   'challenges',
#   'posed',
#   'by',
#   'strained',
#   'infrastructure',
#   'and',
#   'security',
#   'concerns',
#   'underscore',
#   'the',
#   'need',
#   'for',
#   'innovative',
#   'alternative',
#   'pathways',
#   'of',
#   'decentralized',
#   'networks',
#   'and',
#   'mesh',
#   'networks',
#   'exemplify',
#   'our',
#   'capacity',
#   'to',
#   'adapt',
#   'and',
#   'innovate',
#   'the',
#   'choices',
#   'we',
#   'make',
#   'today',
#   'will',
#   'reverberate',
#   'into',
#   'and',
#   'beyond',
#   'defining',
#   'the',
#   'contours',
#   'of',
#   'a',
#   'world',
#   'where',
#   'connectivity',
#   'accessibility',
#   'and',
#   'security',
#   'we',
#   'set',
#   'our',
#   'sights',
#   'on',
#   'the',
#   'hyperconnected',
#   'future',
#   'embracing',
#   'technology',
#   's',
#   'potential',
#   'while',
#   'upholding',
#   'ethical',
#   'values',
#   'will',
#   'be',
#   'key',
#   'to',
#   'creating',
#   'a',
#   'society',
#   'that',
#   'thrives',
#   'in',
#   'this',
#   'new',
#   'era',
#   'of',
#   'communication',
#   'the',
#   'journey',
#   ...],
#  'blackassign0004.txt': ['rise',
#   'of',
#   'cybercrime',
#   'and',
#   'its',
#   'effect',
#   'in',
#   'upcoming',
#   'future',
#   'blackcoffer',
#   'insights',
#   'the',
#   'way',
#   'we',
#   'live',
#   'work',
#   'and',
#   'communicate',
#   'has',
#   'unquestionably',
#   'changed',
#   'as',
#   'a',
#   'result',
#   'of',
#   'the',
#   'rapid',
#   'evolution',
#   'of',
#   'technology',
#   'however',
#   'as',
#   'we',
#   'gain',
#   'from',
#   'digitization',
#   'we',
#   'also',
#   'leave',
#   'ourselves',
#   'vulnerable',
#   'to',
#   'cybercrime',
#   'a',
#   'more',
#   'sinister',
#   'aspect',
#   'of',
#   'innovation',
#   'cybercrime',
#   'is',
#   'a',
#   'worrisome',
#   'issue',
#   'that',
#   'has',
#   'grown',
#   'over',
#   'time',
#   'and',
#   'by',
#   'the',
#   'year',
#   'its',
#   'impacts',
#   'are',
#   'expected',
#   'to',
#   'be',
#   'considerably',
#   'more',
#   'dangerous',
#   'this',
#   'article',
#   'examines',
#   'the',
#   'growing',
#   'problem',
#   'of',
#   'cybercrime',
#   'and',
#   'its',
#   'potentially',
#   'effects',
#   'looking',
#   'at',
#   'how',
#   'it',
#   'may',
#   'affect',
#   'people',
#   'businesses',
#   'and',
#   'even',
#   'which',
#   'frequently',
#   'involves',
#   'illicit',
#   'online',
#   'behaviour',
#   'includes',
#   'a',
#   'variety',
#   'of',
#   'offences',
#   'like',
#   'hacking',
#   'identity',
#   'theft',
#   'phishing',
#   'ransomware',
#   'attacks',
#   'and',
#   'more',
#   'the',
#   'digital',
#   'revolution',
#   'of',
#   'several',
#   'industries',
#   'including',
#   'finance',
#   'healthcare',
#   'and',
#   'critical',
#   'infrastructure',
#   'has',
#   'unintentionally',
#   'given',
#   'cybercriminals',
#   'a',
#   'larger',
#   'attack',
#   'surface',
#   'to',
#   'find',
#   'flaws',
#   'and',
#   'steal',
#   'sensitive',
#   'data',
#   'according',
#   'to',
#   'experts',
#   'cybercrime',
#   'will',
#   'have',
#   'increased',
#   'in',
#   'frequency',
#   'and',
#   'sophistication',
#   'by',
#   'cybercriminals',
#   'will',
#   'have',
#   'additional',
#   'opportunities',
#   'to',
#   'compromise',
#   'networks',
#   'and',
#   'steal',
#   'data',
#   'as',
#   'a',
#   'result',
#   'of',
#   'technology',
#   'like',
#   'artificial',
#   'intelligence',
#   'ai',
#   'quantum',
#   'computing',
#   'and',
#   'the',
#   'internet',
#   'of',
#   'things',
#   'iot',
#   'complexity',
#   'is',
#   'predicted',
#   'to',
#   'reach',
#   'previously',
#   'heights',
#   'by',
#   'the',
#   'most',
#   'robust',
#   'defences',
#   'will',
#   'be',
#   'breached',
#   'by',
#   'cybercriminals',
#   'using',
#   'technology',
#   'like',
#   'artificial',
#   'intelligence',
#   'machine',
#   'learning',
#   'and',
#   'quantum',
#   'computing',
#   'attacks',
#   'will',
#   'be',
#   'possible',
#   'with',
#   'greater',
#   'accuracy',
#   'speed',
#   'and',
#   'adaptability',
#   'thanks',
#   'to',
#   'these',
#   'advances',
#   'the',
#   'impacts',
#   'of',
#   'cybercrime',
#   'are',
#   'felt',
#   'throughout',
#   'the',
#   'entire',
#   'world',
#   'economy',
#   'and',
#   'go',
#   'far',
#   'beyond',
#   'the',
#   'digital',
#   'sphere',
#   'the',
#   'economic',
#   'effects',
#   'of',
#   'cyberattacks',
#   'may',
#   'be',
#   'devastating',
#   'by',
#   'supply',
#   'networks',
#   'financial',
#   'systems',
#   'and',
#   'critical',
#   'infrastructure',
#   'are',
#   'all',
#   'susceptible',
#   'to',
#   'breaches',
#   'that',
#   'might',
#   'lead',
#   'to',
#   'generalised',
#   'panic',
#   'and',
#   'financial',
#   'instability',
#   'because',
#   'of',
#   'this',
#   'connection',
#   'domino',
#   'effects',
#   'and',
#   'subsequent',
#   'economic',
#   'downturns',
#   'are',
#   'more',
#   'likely',
#   'to',
#   'on',
#   'the',
#   'economy',
#   'and',
#   'financial',
#   'disruption',
#   'the',
#   'economic',
#   'effects',
#   'of',
#   'cybercrime',
#   'are',
#   'expected',
#   'to',
#   'be',
#   'astonishing',
#   'as',
#   'its',
#   'spread',
#   'grows',
#   'trillions',
#   'of',
#   'dollars',
#   'in',
#   'revenue',
#   'could',
#   'be',
#   'lost',
#   'as',
#   'a',
#   'result',
#   'of',
#   'the',
#   'financial',
#   'disruption',
#   'brought',
#   'on',
#   'by',
#   'cyberattacks',
#   'on',
#   'organisations',
#   'and',
#   'governments',
#   'by',
#   'the',
#   'interconnection',
#   'of',
#   'the',
#   'world',
#   's',
#   'financial',
#   'institutions',
#   'will',
#   'make',
#   'it',
#   'simpler',
#   'for',
#   'hackers',
#   'to',
#   'wreak',
#   'economic',
#   'havoc',
#   'by',
#   'crashing',
#   'stock',
#   'markets',
#   'banking',
#   'networks',
#   'and',
#   'supply',
#   'theft',
#   'and',
#   'invasion',
#   'of',
#   'personal',
#   'privacy',
#   'as',
#   'hackers',
#   'take',
#   'advantage',
#   'of',
#   'people',
#   's',
#   'digital',
#   'footprints',
#   'they',
#   'will',
#   'become',
#   'more',
#   'exposed',
#   'to',
#   'identity',
#   'theft',
#   'and',
#   'breaches',
#   'of',
#   'their',
#   'privacy',
#   'identity',
#   'theft',
#   'is',
#   'anticipated',
#   'to',
#   'become',
#   'more',
#   'sophisticated',
#   'by',
#   'when',
#   'thieves',
#   'can',
#   'obtain',
#   'personal',
#   'data',
#   'from',
#   'numerous',
#   'sources',
#   'using',
#   'ai',
#   'and',
#   'machine',
#   'learning',
#   'sector',
#   's',
#   'exposure',
#   'due',
#   'to',
#   'the',
#   'sensitivity',
#   'of',
#   'patient',
#   'data',
#   'and',
#   'the',
#   'vital',
#   'role',
#   'it',
#   'plays',
#   'in',
#   'society',
#   'the',
#   'healthcare',
#   'industry',
#   'has',
#   'emerged',
#   'as',
#   'a',
#   'top',
#   'target',
#   'for',
#   'hackers',
#   'by',
#   'the',
#   'integration',
#   'of',
#   'medical',
#   'devices',
#   'with',
#   'digital',
#   'systems',
#   'may',
#   'reveal',
#   'weaknesses',
#   'that',
#   'would',
#   'make',
#   'it',
#   'possible',
#   'for',
#   'cybercriminals',
#   'to',
#   'alter',
#   'medical',
#   'records',
#   'steal',
#   'patient',
#   'treatments',
#   'or',
#   'even',
#   'compromise',
#   'personal',
#   'health',
#   'to',
#   'national',
#   'security',
#   'unprecedented',
#   'threats',
#   'to',
#   'national',
#   'security',
#   'are',
#   'posed',
#   'by',
#   'cyberattacks',
#   'on',
#   'vital',
#   'infrastructure',
#   'including',
#   'power',
#   'grids',
#   'transportation',
#   'networks',
#   'and',
#   'communication',
#   'networks',
#   'such',
#   'strikes',
#   'might',
#   'have',
#   'disastrous',
#   'effects',
#   'by',
#   'upsetting',
#   'entire',
#   'countries',
#   'and',
#   'unleashing',
#   'an',
#   'unprecedented',
#   'level',
#   'of',
#   'turmoil',
#   'national',
#   'security',
#   'is',
#   'no',
#   'longer',
#   'limited',
#   'to',
#   'conventional',
#   'military',
#   'threats',
#   'in',
#   'the',
#   'digital',
#   'age',
#   'the',
#   'field',
#   'of',
#   'cyberwarfare',
#   'will',
#   'have',
#   'grown',
#   'greatly',
#   'by',
#   'nations',
#   'might',
#   'become',
#   'embroiled',
#   'in',
#   'cyber',
#   'warfare',
#   'which',
#   'might',
#   'result',
#   'in',
#   'data',
#   'manipulation',
#   'espionage',
#   'and',
#   'even',
#   'virtual',
#   'sabotage',
#   'cyberattacks',
#   'have',
#   'the',
#   'potential',
#   'to',
#   'disrupt',
#   'political',
#   'landscapes',
#   'undermine',
#   'defence',
#   'systems',
#   'and',
#   'impair',
#   'military',
#   'of',
#   'critical',
#   'infrastructure',
#   'cyberattacks',
#   'on',
#   'vital',
#   'infrastructure',
#   'such',
#   'as',
#   'power',
#   'grids',
#   'transportation',
#   'networks',
#   'and',
#   'healthcare',
#   'institutions',
#   'may',
#   'increase',
#   'by',
#   'the',
#   'year',
#   'due',
#   'to',
#   'their',
#   'interconnectedness',
#   'with',
#   'the',
#   'internet',
#   'these',
#   'systems',
#   'are',
#   'more',
#   'vulnerable',
#   'to',
#   'prospective',
#   'hacks',
#   'which',
#   'might',
#   'hurt',
#   'entire',
#   'societies',
#   'these',
#   'assaults',
#   'could',
#   'jeopardise',
#   'crucial',
#   'services',
#   'healthcare',
#   'and',
#   'public',
#   'and',
#   'the',
#   'erosion',
#   'of',
#   'privacy',
#   'the',
#   'degradation',
#   'of',
#   'individual',
#   'privacy',
#   'worsens',
#   'as',
#   'technology',
#   'develops',
#   'by',
#   'a',
#   'complex',
#   'network',
#   'of',
#   'interconnected',
#   'gadgets',
#   'may',
#   'enable',
#   'new',
#   'levels',
#   'of',
#   'data',
#   'collection',
#   'and',
#   'surveillance',
#   'raising',
#   'questions',
#   'about',
#   'civil',
#   'liberties',
#   'and',
#   'individual',
#   'freedoms',
#   'governments',
#   'businesses',
#   'and',
#   'even',
#   'cybercriminals',
#   'could',
#   'make',
#   'use',
#   'of',
#   'this',
#   'circumstance',
#   'for',
#   'a',
#   'variety',
#   'of',
#   'reasons',
#   'including',
#   'social',
#   'engineering',
#   'and',
#   'relations',
#   'restructuring',
#   'beyond',
#   'national',
#   'borders',
#   'the',
#   'prevalence',
#   'of',
#   'cybercrime',
#   'can',
#   'alter',
#   'global',
#   'relations',
#   'states',
#   'might',
#   'interfere',
#   'with',
#   'elections',
#   'steal',
#   'intellectual',
#   'property',
#   'and',
#   'engage',
#   'in',
#   'cyber',
#   'espionage',
#   'all',
#   'of',
#   'which',
#   'would',
#   'exacerbate',
#   'an',
#   'already',
#   'tense',
#   'situation',
#   'by',
#   'sowing',
#   'distrust',
#   'and',
#   'uncertainty',
#   'as',
#   'countries',
#   'struggle',
#   'with',
#   'concerns',
#   'of',
#   'cyber',
#   'sovereignty',
#   'and',
#   'digital',
#   'security',
#   'diplomacy',
#   'may',
#   'transcend',
#   'beyond',
#   'traditional',
#   'channels',
#   'and',
#   'into',
#   'the',
#   'domain',
#   'of',
#   'cyber',
#   'by',
#   'the',
#   'government',
#   'and',
#   'the',
#   'law',
#   'to',
#   'prevent',
#   'cybercriminals',
#   'and',
#   'hold',
#   'them',
#   'accountable',
#   'governments',
#   'must',
#   'implement',
#   'strict',
#   'laws',
#   'and',
#   'regulatory',
#   'structures',
#   'cyber',
#   'rules',
#   'that',
#   'encourage',
#   'responsible',
#   'behaviour',
#   'in',
#   'cyberspace',
#   'must',
#   'be',
#   'established',
#   'through',
#   'international',
#   'collaboration',
#   'and',
#   'diplomatic',
#   'countermeasures',
#   'the',
#   'fight',
#   'for',
#   'digital',
#   'security',
#   'becomes',
#   'more',
#   'intense',
#   'as',
#   'criminality',
#   'increases',
#   'the',
#   'creation',
#   'of',
#   'countermeasures',
#   'will',
#   'be',
#   'essential',
#   'by',
#   'for',
#   'protecting',
#   'sensitive',
#   'data',
#   'and',
#   'crucial',
#   'systems',
#   'businesses',
#   'and',
#   'governments',
#   'will',
#   'make',
#   'significant',
#   'investments',
#   'in',
#   'cybersecurity',
#   'research',
#   'threat',
#   'detection',
#   'and',
#   'preventative',
#   'defence',
#   'systems',
#   'robust',
#   'cybersecurity',
#   'frameworks',
#   'will',
#   'develop',
#   'as',
#   'a',
#   'result',
#   'of',
#   'the',
#   'merging',
#   'of',
#   'human',
#   'expertise',
#   'with',
#   'machine',
#   'effects',
#   'and',
#   'mental',
#   'health',
#   'costs',
#   'the',
#   'development',
#   'of',
#   'cybercrime',
#   'is',
#   'expected',
#   'to',
#   'have',
#   'a',
#   'significant',
#   'social',
#   'impact',
#   'on',
#   'people',
#   's',
#   'personal',
#   'and',
#   'psychological',
#   'the',
#   'ongoing',
#   'risk',
#   'of',
#   'financial',
#   'loss',
#   'data',
#   'breaches',
#   'and',
#   'digital',
#   'manipulation',
#   'may',
#   'reduce',
#   'public',
#   'confidence',
#   'in',
#   'digital',
#   'systems',
#   'living',
#   'in',
#   'a',
#   'constantly',
#   'unstable',
#   'digital',
#   'environment',
#   'can',
#   'have',
#   'a',
#   'psychological',
#   'toll',
#   'that',
#   'heightens',
#   'stress',
#   'worry',
#   'and',
#   'a',
#   'lack',
#   'of',
#   'faith',
#   'in',
#   'technology',
#   's',
#   'the',
#   'development',
#   'of',
#   'cybercrime',
#   'and',
#   'its',
#   'probable',
#   'consequences',
#   'by',
#   'provides',
#   'a',
#   'gloomy',
#   'perspective',
#   'on',
#   'the',
#   'difficulties',
#   'that',
#   'lie',
#   'ahead',
#   'as',
#   'we',
#   'look',
#   'into',
#   'the',
#   'future',
#   'while',
#   'technological',
#   'development',
#   'has',
#   'revolutionised',
#   'our',
#   'way',
#   'of',
#   'life',
#   'it',
#   'has',
#   'also',
#   'ushered',
#   'in',
#   'a',
#   'new',
#   'period',
#   'of',
#   'criminal',
#   'activities',
#   'governments',
#   'corporations',
#   'and',
#   'individuals',
#   'must',
#   'work',
#   'together',
#   'to',
#   'combat',
#   'these',
#   'risks',
#   'through',
#   'thorough',
#   'cybersecurity',
#   'measures',
#   'global',
#   'collaboration',
#   'and',
#   'responsible',
#   'technological',
#   'development',
#   'we',
#   'can',
#   'work',
#   'to',
#   'guarantee',
#   'a',
#   'digital',
#   'future',
#   'that',
#   'supports',
#   'the',
#   'principles',
#   'of',
#   'privacy',
#   'trust',
#   'and',
#   'creativity',
#   'by',
#   'recognising',
#   'the',
#   'scope',
#   'of',
#   'the',
#   'threat',
#   'investing',
#   'in',
#   'defence',
#   'systems',
#   'and',
#   'encouraging',
#   'a',
#   'culture',
#   'of',
#   'cyber',
#   'alertness',
#   'the',
#   'battle',
#   'against',
#   'the',
#   'shadowy',
#   'side',
#   'of',
#   ...],
#  'blackassign0005.txt': ['ott',
#   'platform',
#   'and',
#   'its',
#   'impact',
#   'on',
#   'the',
#   'entertainment',
#   'industry',
#   'in',
#   'future',
#   'blackcoffer',
#   'insights',
#   'the',
#   'year',
#   'is',
#   'poised',
#   'to',
#   'witness',
#   'a',
#   'continued',
#   'revolution',
#   'in',
#   'the',
#   'world',
#   'of',
#   'entertainment',
#   'driven',
#   'by',
#   'the',
#   'meteoric',
#   'rise',
#   'of',
#   'ott',
#   'platforms',
#   'these',
#   'digital',
#   'content',
#   'hubs',
#   'have',
#   'already',
#   'reshaped',
#   'how',
#   'we',
#   'consume',
#   'media',
#   'today',
#   'and',
#   'their',
#   'impact',
#   'is',
#   'set',
#   'to',
#   'be',
#   'even',
#   'more',
#   'profound',
#   'in',
#   'the',
#   'coming',
#   'years',
#   'the',
#   'emergence',
#   'of',
#   'ott',
#   'platforms',
#   'and',
#   'their',
#   'effects',
#   'on',
#   'the',
#   'entertainment',
#   'industry',
#   'is',
#   'really',
#   'going',
#   'to',
#   'be',
#   'very',
#   'huge',
#   'one',
#   'entertainment',
#   'landscape',
#   'has',
#   'undergone',
#   'a',
#   'seismic',
#   'shift',
#   'with',
#   'the',
#   'rise',
#   'of',
#   'ott',
#   'platforms',
#   'and',
#   'by',
#   'the',
#   'year',
#   'their',
#   'influence',
#   'will',
#   'have',
#   'reshaped',
#   'the',
#   'industry',
#   'in',
#   'profound',
#   'ways',
#   'this',
#   'article',
#   'delves',
#   'into',
#   'the',
#   'trajectory',
#   'of',
#   'ott',
#   'platforms',
#   'and',
#   'their',
#   'effects',
#   'on',
#   'the',
#   'entertainment',
#   'ott',
#   'platforms',
#   'will',
#   'solidify',
#   'their',
#   'status',
#   'as',
#   'the',
#   'dominant',
#   'players',
#   'in',
#   'the',
#   'entertainment',
#   'realm',
#   'with',
#   'accessible',
#   'internet',
#   'connectivity',
#   'audiences',
#   'from',
#   'all',
#   'corners',
#   'of',
#   'the',
#   'globe',
#   'can',
#   'access',
#   'a',
#   'vast',
#   'array',
#   'of',
#   'content',
#   'transcending',
#   'the',
#   'geographical',
#   'platforms',
#   'have',
#   'democratized',
#   'content',
#   'creation',
#   'enabling',
#   'a',
#   'diverse',
#   'range',
#   'of',
#   'creators',
#   'to',
#   'showcase',
#   'their',
#   'work',
#   'this',
#   'will',
#   'lead',
#   'to',
#   'an',
#   'explosion',
#   'of',
#   'niche',
#   'content',
#   'catering',
#   'to',
#   'specific',
#   'interests',
#   'and',
#   'cultures',
#   'that',
# ...
#   'also',
#   'multiple',
#   'schemes',
#   'have',
#   'been',
#   'initiated',
#   'by',
#   'the',
#   'government',
#   'to',
#   'promote',
#   'online',
#   'payments',
#   'like',
#   'lucky',
#   'grahak',
#   'yojana',
#   'and',
#   'digi',
#   'dhan',
#   'vyapari',
#   'yojana',
#   'the',
#   'details',
#   'of',
#   'the',
#   'same',
#   'are',
#   'as',
#   'follows',
#   'lucky',
#   'garhak',
#   'yojanaa',
#   'daily',
#   'reward',
#   'of',
#   'rs',
#   'to',
#   'be',
#   'given',
#   'to',
#   'lucky',
#   'consumers',
#   'for',
#   'a',
#   'period',
#   'of',
#   'who',
#   'use',
#   'the',
#   'online',
#   'mode',
#   'of',
#   'payments',
#   'will',
#   'get',
#   'weekly',
#   'prizes',
#   'worth',
#   'rs',
#   'lakh',
#   'rs',
#   'and',
#   'rs',
#   'all',
#   'types',
#   'of',
#   'online',
#   'transactions',
#   'will',
#   'be',
#   'included',
#   'in',
#   'this',
#   'digi',
#   'dhan',
#   'vyapariprizes',
#   'for',
#   'merchants',
#   'for',
#   'all',
#   'digital',
#   'rs',
#   'and',
#   'rs',
#   'will',
#   'be',
#   'provided',
#   'frequently',
#   'used',
#   'apps',
#   'by',
#   'the',
#   'consumers',
#   'and',
#   'the',
#   'market',
#   'share',
#   'of',
#   'apps',
#   'are',
#   'as',
#   'follows',
#   'google',
#   'amazon',
#   'other',
#   'not',
#   'only',
#   'the',
#   'sellers',
#   'but',
#   'also',
#   'the',
#   'buyers',
#   'have',
#   'taken',
#   'a',
#   'step',
#   'forward',
#   'in',
#   'making',
#   'online',
#   'payments',
#   'and',
#   'have',
#   'been',
#   'exploring',
#   'the',
#   'various',
#   'offers',
#   'and',
#   'discounts',
#   'the',
#   'sellers',
#   'have',
#   'started',
#   'their',
#   'own',
#   'online',
#   'shops',
#   'and',
#   'made',
#   'online',
#   'payment',
#   'mandatory',
#   'in',
#   'highly',
#   'contaminated',
#   'zones',
#   'the',
#   'buyer',
#   'has',
#   'also',
#   'taken',
#   'advantage',
#   'of',
#   'home',
#   'deliveries',
#   'to',
#   'follow',
#   'social',
#   'distancing',
#   'to',
#   'add',
#   'to',
#   'the',
#   'advantage',
#   'of',
#   'buyers',
#   'and',
#   'sellers',
#   'kyc',
#   'is',
#   'no',
#   'more',
#   'a',
#   'necessity',
#   'to',
#   'make',
#   'money',
#   'has',
#   'been',
#   'an',
#   'increase',
#   'in',
#   'the',
#   'services',
#   'provided',
#   'by',
#   'banking',
#   'sectors',
#   'as',
#   'well',
#   'the',
#   'fm',
#   'nirmala',
#   'sitharaman',
#   'has',
#   'provided',
#   'the',
#   'directions',
#   'to',
#   'not',
#   'charge',
#   'for',
#   'cash',
#   'withdrawals',
#   'from',
#   'atm',
#   's',
#   'various',
#   'services',
#   'like',
#   'sending',
#   'and',
#   'receiving',
#   'money',
#   'blocking',
#   'cards',
#   'credit',
#   'card',
#   'payments',
#   'credit',
#   'card',
#   'pins',
#   'are',
#   'being',
#   'provided',
#   'options',
#   'like',
#   'paytm',
#   'have',
#   'been',
#   'open',
#   'up',
#   'for',
#   'investing',
#   'money',
#   'online',
#   'in',
#   'stocks',
#   'insurance',
#   'etc',
#   'even',
#   'online',
#   'shopping',
#   'apps',
#   'like',
#   'amazon',
#   'have',
#   'come',
#   'up',
#   'with',
#   'various',
#   'offers',
#   'for',
#   'their',
#   'technologies',
#   'and',
#   'high',
#   'competition',
#   'among',
#   'online',
#   'payment',
#   'apps',
#   'are',
#   'providing',
#   'benefits',
#   'to',
#   'buyers',
#   'and',
#   'sellers',
#   'as',
#   'well',
#   'sellers',
#   'have',
#   'been',
#   'able',
#   'to',
#   'increase',
#   'their',
#   'reach',
#   'with',
#   'online',
#   'shops',
#   'and',
#   'online',
#   'payment',
#   'stands',
#   'as',
#   'a',
#   'guarantee',
#   'for',
#   'them',
#   'buyers',
#   'have',
#   'been',
#   'in',
#   'the',
#   'most',
#   'advantageous',
#   'position',
#   'ever',
#   'after',
#   'the',
#   'digital',
#   'payment',
#   'has',
#   'come',
#   'into',
#   'the',
#   'market',
#   'they',
#   'are',
#   'being',
#   'provided',
#   'with',
#   'a',
#   'number',
#   'of',
#   'choices',
#   'to',
#   'choose',
#   'from',
#   'as',
#   'well',
#   'as',
#   'make',
#   'instant',
#   'payments',
#   'for',
#   'offers',
#   'this',
#   'all',
#   'sums',
#   'up',
#   'the',
#   'likeliness',
#   'of',
#   'digital',
#   'payment',
#   'in',
#   'the',
#   'market',
#   'so',
#   'yes',
#   'we',
#   'can',
#   'say',
#   'you',
#   'digital',
#   'payment',
#   'have',
#   'a',
#   'brillant',
#   'future',
#   'child',
#   'we',
#   'all',
#   'have',
#   'heard',
#   'this',
#   'statement',
#   'precaution',
#   'is',
#   'better',
#   'than',
#   'cure',
#   'and',
#   'here',
#   'is',
#   'the',
#   'time',
#   'to',
#   'follow',
#   'the',
#   'same',
#   'it',
#   'has',
#   'been',
#   'proven',
#   'as',
#   'a',
#   'fact',
#   'that',
#   'the',
#   'coronavirus',
#   'can',
#   'persist',
#   'on',
#   'paper',
#   'for',
#   'four',
#   'or',
#   'five',
#   'days',
#   'that',
#   'means',
#   'the',
#   'coronavirus',
#   'can',
#   'persist',
#   'on',
#   'the',
#   'paper',
#   'currency',
#   'for',
#   'four',
#   'or',
#   'five',
#   'days',
#   'thus',
#   'it',
#   'is',
#   'important',
#   'to',
#   'avoid',
#   'the',
#   'usage',
#   'of',
#   'paper',
#   'revolution',
#   'will',
#   'take',
#   'place',
#   'only',
#   'when',
#   'the',
#   'below',
#   'poverty',
#   'population',
#   'of',
#   'india',
#   'will',
#   'start',
#   'using',
#   'the',
#   'online',
#   'mode',
#   'of',
#   'payment',
#   'and',
#   'will',
#   'be',
#   'literate',
#   'enough',
#   'to',
#   'not',
#   'get',
#   'caught',
#   'in',
#   'any',
#   'insights',
#   'himanshi',
#   'kalota',
#   'shri',
#   'ram',
#   'college',
#   'of',
#   'commerce',
#   'delhi'],
#  'blackassign0100.txt': ['how',
#   'will',
#   'affect',
#   'the',
#   'world',
#   'of',
#   'work',
#   'blackcoffer',
#   'insights',
#   'as',
#   'business',
#   'close',
#   'to',
#   'help',
#   'prevent',
#   'transmission',
#   'of',
#   'financial',
#   'concerns',
#   'and',
#   'job',
#   'losses',
#   'are',
#   'one',
#   'of',
#   'the',
#   'first',
#   'human',
#   'impacts',
#   'of',
#   'the',
#   'virus',
#   'not',
#   'knowing',
#   'how',
#   'this',
#   'pandemic',
#   'will',
#   'play',
#   'out',
#   'also',
#   'affects',
#   'our',
#   'economic',
#   'physical',
#   'and',
#   'mental',
#   'despite',
#   'this',
#   'fear',
#   'businesses',
#   'and',
#   'communities',
#   'in',
#   'many',
#   'regions',
#   'have',
#   'shown',
#   'a',
#   'more',
#   'altruistic',
#   'response',
#   'in',
#   'the',
#   'face',
#   'of',
#   'crisis',
#   'actions',
#   'which',
#   'could',
#   'help',
#   'countries',
#   'preparing',
#   'for',
#   'is',
#   'in',
#   'decline',
#   'in',
#   'china',
#   'there',
#   'are',
#   'now',
#   'more',
#   'new',
#   'cases',
#   'every',
#   'day',
#   'in',
#   'europe',
#   'than',
#   'there',
#   'were',
#   'in',
#   'china',
#   'at',
#   'the',
#   'epidemic',
#   's',
#   'peak',
#   'and',
#   'italy',
#   'has',
#   'surpassed',
#   'it',
#   'as',
#   'the',
#   'country',
#   'with',
#   'the',
#   'most',
#   'deaths',
#   'from',
#   'the',
#   'virus',
#   'it',
#   'took',
#   'days',
#   'to',
#   'reach',
#   'the',
#   'first',
#   'confirmed',
#   'cases',
#   'worldwide',
#   'days',
#   'for',
#   'this',
#   'to',
#   'increase',
#   'to',
#   'just',
#   'four',
#   'to',
#   'reach',
#   'confirmed',
#   'cases',
#   'a',
#   'figure',
#   'now',
#   'human',
#   'consequencesin',
#   'recent',
#   'weeks',
#   'we',
#   'have',
#   'seen',
#   'the',
#   'significant',
#   'economic',
#   'impact',
#   'of',
#   'the',
#   'coronavirus',
#   'on',
#   'financial',
#   'markets',
#   'and',
#   'vulnerable',
#   'industries',
#   'such',
#   'as',
#   'manufacturing',
#   'tourism',
#   'hospitality',
#   'and',
#   'travel',
#   'travel',
#   'and',
#   'tourism',
#   'account',
#   'for',
#   'of',
#   'the',
#   'global',
#   'gdp',
#   'and',
#   'million',
#   'jobs',
#   'are',
#   'at',
#   'risk',
#   'tourism',
#   'travel',
#   'and',
#   'hospitality',
#   'companies',
#   'closing',
#   'down',
#   'affects',
#   'smes',
#   'globally',
#   'this',
#   'in',
#   'turn',
#   'affects',
#   'many',
#   'people',
#   'typically',
#   'the',
#   'least',
#   'and',
#   'those',
#   'or',
#   'working',
#   'in',
#   'informal',
#   'environments',
#   'in',
#   'the',
#   'gig',
#   'economy',
#   'or',
#   'in',
#   'work',
#   'with',
#   'contracts',
#   'some',
#   'governments',
#   'have',
#   'announced',
#   'economic',
#   'measures',
#   'to',
#   'safeguard',
#   'jobs',
#   'guarantee',
#   'wages',
#   'and',
#   'support',
#   'the',
#   'but',
#   'there',
#   'is',
#   'a',
#   'lack',
#   'of',
#   'clarity',
#   'in',
#   'many',
#   'countries',
#   'about',
#   'how',
#   'these',
#   'measures',
#   'will',
#   'be',
#   'implemented',
#   'and',
#   'how',
#   'people',
#   'will',
#   'manage',
#   'a',
#   'loss',
#   'of',
#   'income',
#   'in',
#   'the',
#   'these',
#   'statistics',
#   'lie',
#   'the',
#   'human',
#   'costs',
#   'of',
#   'the',
#   'pandemic',
#   'from',
#   'the',
#   'deaths',
#   'of',
#   'friends',
#   'and',
#   'family',
#   'to',
#   'the',
#   'physical',
#   'effects',
#   'of',
#   'infection',
#   'and',
#   'the',
#   'mental',
#   'trauma',
#   'and',
#   'fear',
#   'faced',
#   'by',
#   'almost',
#   'everyone',
#   'not',
#   'knowing',
#   'how',
#   'this',
#   'pandemic',
#   'will',
#   'play',
#   'out',
#   'affects',
#   'our',
#   'economic',
#   'physical',
#   'and',
#   'mental',
#   'against',
#   'a',
#   'backdrop',
#   'of',
#   'a',
#   'world',
#   'that',
#   'for',
#   'many',
#   'is',
#   'increasingly',
#   'anxious',
#   'unhappy',
#   'and',
#   'of',
#   'the',
#   'unknown',
#   'can',
#   'often',
#   'lead',
#   'to',
#   'feelings',
#   'of',
#   'panic',
#   'for',
#   'example',
#   'when',
#   'people',
#   'feel',
#   'they',
#   'are',
#   'being',
#   'denied',
#   'protection',
#   'or',
#   'treatment',
#   'or',
#   'that',
#   'they',
#   'may',
#   'run',
#   'out',
#   'of',
#   'necessities',
#   'which',
#   'can',
#   'lead',
#   'to',
#   'panic',
#   'stress',
#   'is',
#   'often',
#   'related',
#   'to',
#   'a',
#   'sense',
#   'of',
#   'a',
#   'lack',
#   'of',
#   'control',
#   'in',
#   'the',
#   'face',
#   'of',
#   'all',
#   'cases',
#   'lack',
#   'of',
#   'information',
#   'or',
#   'the',
#   'wrong',
#   'information',
#   'either',
#   'provided',
#   'inadvertently',
#   'or',
#   'maliciously',
#   'can',
#   'amplify',
#   'the',
#   'effects',
#   'there',
#   'is',
#   'a',
#   'huge',
#   'amount',
#   'of',
#   'misleading',
#   'information',
#   'circulating',
#   'online',
#   'about',
#   'from',
#   'fake',
#   'medical',
#   'information',
#   'to',
#   'speculation',
#   'about',
#   'government',
#   'responses',
#   'people',
#   'are',
#   'susceptible',
#   'to',
#   'social',
#   'media',
#   'posts',
#   'from',
#   'an',
#   'apparently',
#   'trustworthy',
#   'source',
#   'often',
#   'referred',
#   'to',
#   'as',
#   'an',
#   'uncle',
#   'with',
#   'a',
#   'masters',
#   'possibly',
#   'amplified',
#   'and',
#   'spread',
#   'by',
#   'copypasta',
#   'posts',
#   'which',
#   'share',
#   'information',
#   'by',
#   'copying',
#   'and',
#   'pasting',
#   'and',
#   'make',
#   'each',
#   'new',
#   'post',
#   'look',
#   'like',
#   'an',
#   'original',
#   'source',
#   'as',
#   'opposed',
#   'to',
#   'posts',
#   'that',
#   'are',
#   'liked',
#   'or',
#   'shared',
#   'or',
#   'retweeted',
#   'criminals',
#   'and',
#   'hackers',
#   'are',
#   'also',
#   'exploiting',
#   'this',
#   'situation',
#   'and',
#   'there',
#   'has',
#   'been',
#   'a',
#   'significant',
#   'rise',
#   'in',
#   'malicious',
#   'websites',
#   'with',
#   'more',
#   'than',
#   'new',
#   'domains',
#   'registered',
#   'since',
#   'january',
#   'hackers',
#   'are',
#   'selling',
#   'malware',
#   'and',
#   'hacking',
#   'tools',
#   'through',
#   'discount',
#   'codes',
#   'on',
#   'the',
#   'darknet',
#   'many',
#   'of',
#   'which',
#   'are',
#   'aimed',
#   'at',
#   'accessing',
#   'corporate',
#   'data',
#   'from',
#   'laptops',
#   'which',
#   'may',
#   'not',
#   'be',
#   'as',
#   'secure',
#   'as',
#   'outside',
#   'an',
#   'office',
#   'distancing',
#   'and',
#   'lockdowns',
#   'have',
#   'also',
#   'prompted',
#   'altruistic',
#   'behaviors',
#   'in',
#   'part',
#   'because',
#   'of',
#   'the',
#   'sense',
#   'that',
#   'we',
#   're',
#   'all',
#   'in',
#   'this',
#   'together',
#   'many',
#   'people',
#   'report',
#   'being',
#   'bored',
#   'or',
#   'concerned',
#   'about',
#   'putting',
#   'on',
#   'weight',
#   'others',
#   'have',
#   'discovered',
#   'a',
#   'slower',
#   'pace',
#   'of',
#   'life',
#   'and',
#   'by',
#   'not',
#   'going',
#   'out',
#   'and',
#   'socializing',
#   'have',
#   'found',
#   'more',
#   'time',
#   'for',
#   'family',
#   'others',
#   'and',
#   'even',
#   'their',
#   'downside',
#   'of',
#   'or',
#   'social',
#   'lockdown',
#   'are',
#   'symptoms',
#   'of',
#   'traumatic',
#   'stress',
#   'confusion',
#   'and',
#   'anger',
#   'all',
#   'of',
#   'which',
#   'are',
#   'exacerbated',
#   'by',
#   'fear',
#   'of',
#   'infection',
#   'having',
#   'limited',
#   'access',
#   'to',
#   'supplies',
#   'of',
#   'necessities',
#   'inadequate',
#   'information',
#   'or',
#   'the',
#   'experience',
#   'of',
#   'economic',
#   'loss',
#   'or',
#   'stigma',
#   'this',
#   'stress',
#   'and',
#   'anxiety',
#   'can',
#   'lead',
#   'to',
#   'increased',
#   'alcohol',
#   'consumption',
#   'as',
#   'well',
#   'as',
#   'an',
#   'increase',
#   'in',
#   'domestic',
#   'and',
#   'family',
#   'jingzhou',
#   'a',
#   'town',
#   'near',
#   'wuhan',
#   'in',
#   'hubei',
#   'province',
#   'reports',
#   'of',
#   'domestic',
#   'violence',
#   'during',
#   'the',
#   'lockdown',
#   'in',
#   'february',
#   'were',
#   'more',
#   'than',
#   'triple',
#   'the',
#   'number',
#   'reported',
#   'in',
#   'february',
#   'actions',
#   'from',
#   'the',
#   'business',
#   'communityhealth',
#   'measures',
#   'must',
#   'be',
#   'the',
#   'first',
#   'priority',
#   'for',
#   'governments',
#   'business',
#   'and',
#   'society',
#   'it',
#   'is',
#   'important',
#   'for',
#   'businesses',
#   'to',
#   'show',
#   'solidarity',
#   'and',
#   'work',
#   'together',
#   'to',
#   'protect',
#   'staff',
#   'local',
#   'communities',
#   'and',
#   'customers',
#   'as',
#   'well',
#   'as',
#   'keeping',
#   'supply',
#   'chains',
#   'manufacturing',
#   'and',
#   'logistics',
#   'to',
#   'research',
#   'my',
#   'employer',
#   'is',
#   'more',
#   'trusted',
#   'than',
#   'the',
#   'government',
#   'or',
#   'media',
#   'daily',
#   'updates',
#   'on',
#   'a',
#   'company',
#   'website',
#   'with',
#   'input',
#   'from',
#   'scientists',
#   'and',
#   'experts',
#   'are',
#   'recommended',
#   'to',
#   'counter',
#   'politicized',
#   'messages',
#   'in',
#   'the',
#   'media',
#   'and',
#   'from',
#   'governments',
#   'this',
#   'is',
#   'particularly',
#   'true',
#   'for',
#   'large',
#   'companies',
#   'that',
#   'have',
#   'the',
#   'capacity',
#   'to',
#   'do',
#   'about',
#   'what',
#   'businesses',
#   'are',
#   'doing',
#   'for',
#   'their',
#   'employees',
#   'and',
#   'in',
#   'their',
#   'communities',
#   'is',
#   'also',
#   'important',
#   'some',
#   'companies',
#   'are',
#   'helping',
#   'schoolchildren',
#   'from',
#   'vulnerable',
#   'families',
#   'who',
#   'can',
#   'no',
#   'longer',
#   'get',
#   'a',
#   'school',
#   'meal',
#   'others',
#   'are',
#   'providing',
#   'public',
#   'health',
#   'messages',
#   'about',
#   'effective',
#   'handwashing',
#   'even',
#   'ceos',
#   'can',
#   'show',
#   'they',
#   'are',
#   'working',
#   'from',
#   'home',
#   'and',
#   'while',
#   'still',
#   'being',
#   'effective',
#   'in',
#   'their',
#   'who',
#   'advice',
#   'there',
#   'is',
#   'a',
#   'need',
#   'for',
#   'the',
#   'business',
#   'community',
#   'to',
#   'move',
#   'from',
#   'general',
#   'support',
#   'to',
#   'specific',
#   'actions',
#   'and',
#   'focus',
#   'on',
#   'countries',
#   'access',
#   'to',
#   'critical',
#   'supplies',
#   'including',
#   'a',
#   'community',
#   'package',
#   'of',
#   'critical',
#   'items',
#   'a',
#   'list',
#   'of',
#   'items',
#   'that',
#   'all',
#   'countries',
#   'need',
#   'of',
#   'these',
#   'items',
#   'are',
#   'either',
#   'not',
#   'available',
#   'locally',
#   'or',
#   'available',
#   'stocks',
#   'are',
#   'too',
#   'limited',
#   'these',
#   'missing',
#   'items',
#   'fall',
#   'into',
#   'four',
#   'categories',
#   'hygiene',
#   'chlorine',
#   'hth',
#   'alcohol',
#   'based',
#   'hand',
#   'rub',
#   'liquid',
#   'soap',
#   'diagnostics',
#   'lab',
#   'screening',
#   'tests',
#   'lab',
#   'confirmation',
#   'tests',
#   'enzymes',
#   'rna',
#   'extraction',
#   'kits',
#   'ppe',
#   'gowns',
#   'scrubs',
#   'aprons',
#   'sterile',
#   'gloves',
#   'protective',
#   'goggles',
#   'face',
#   'shields',
#   'masks',
#   'or',
#   'case',
#   'management',
#   'equipment',
#   'oxygen',
#   'concentrators',
#   'oxygen',
#   'delivery',
#   'systems',
#   'mechanical',
#   'call',
#   'for',
#   'action',
#   'is',
#   'for',
#   'more',
#   'money',
#   'to',
#   'work',
#   'with',
#   'manufacturers',
#   'to',
#   'create',
#   'capacity',
#   'and',
#   'to',
#   'organize',
#   'purchasing',
#   'so',
#   'there',
#   'is',
#   'guaranteed',
#   'access',
#   'especially',
#   'for',
#   'poorer',
#   'countries',
#   'with',
#   'less',
#   'resilient',
#   'public',
#   'health',
#   'systems',
#   'the',
#   'concept',
#   'is',
#   'to',
#   'create',
#   'a',
#   'global',
#   'security',
#   'stockpile',
#   'of',
#   'supplies',
#   'and',
#   'equipment',
#   'an',
#   'effort',
#   'that',
#   'needs',
#   'emergency',
#   'financingaccess',
#   'to',
#   'and',
#   'increases',
#   'in',
#   'manufacturing',
#   'capacityaccess',
#   'to',
#   'national',
#   'and',
#   'supplier',
#   'stockpileswarehouses',
#   'and',
#   'distribution',
#   'capacityblackcoffer',
#   'insights',
#   'tiwari',
#   'gurukul',
#   'kangri',
#   'deemed',
#   'university',
#   'haridwar']}

# %%
len(token_dict)
# Out:
# 100

# %% [markdown]
# ### Stopwords

# %% [raw]
# The Stop Words Lists (found in the folder StopWords) are used to clean the text so that Sentiment Analysis can be performed by excluding the words found in Stop Words List.

# %%
stopword_folder = "StopWords"

folder_path2 = os.path.join(current_dir,stopword_folder)
print(folder_path2)
# Out:
# C:\Users\Amruta\Desktop\Blackcoffer NLP Project\StopWords

# %%
stopword_files = os.listdir(folder_path2)
stopword_files
# Out:
# ['StopWords_Auditor.txt',
#  'StopWords_Currencies.txt',
#  'StopWords_DatesandNumbers.txt',
#  'StopWords_Generic.txt',
#  'StopWords_GenericLong.txt',
#  'StopWords_Geographic.txt',
#  'StopWords_Names.txt']

# %%
stop_words = set()

for file in stopword_files:
    with open(os.path.join(folder_path2, file),'r',encoding='ISO-8859-1') as  file:
        
        words = word_tokenize(file.read())
        unique_words = {word.lower() for word in words if re.match(r'^[a-zA-Z]+$', word)}
        stop_words.update(unique_words)
print(len(stop_words))
stop_words
# Out:
# 12778
# {'dewey',
#  'callis',
#  'mariella',
#  'bobo',
#  'layton',
#  'messenger',
#  'carley',
#  'bourg',
#  'velasquez',
#  'pennie',
#  'menchaca',
#  'sheffield',
#  'eller',
#  'saudi',
#  'wylie',
#  'petterson',
#  'kastner',
#  'braswell',
#  'far',
#  'savage',
#  'zelaya',
#  'greco',
#  'barrier',
#  'neither',
#  'cockerham',
#  'celena',
#  'breeding',
#  'ned',
#  'mei',
#  'murrell',
#  'westbrooks',
#  'livia',
#  'ocean',
#  'kendrick',
#  'hecker',
#  'karina',
#  'weidner',
#  'paine',
#  'robison',
#  'mallett',
#  'cisco',
#  'estrada',
#  'herta',
#  'henson',
#  'christianson',
#  'jenise',
#  'harlow',
#  'especially',
#  'safford',
#  'pike',
#  'bowles',
#  'carrington',
#  'ferrer',
#  'bruns',
#  'qtr',
#  'jeffry',
#  'kandis',
#  'earls',
#  'bauman',
#  'marisol',
#  'myrtis',
#  'your',
#  'wimmer',
#  'edens',
#  'cox',
#  'caudle',
#  'giordano',
#  'newland',
#  'marc',
#  'charmain',
#  'vanuatu',
#  'matos',
#  'emiko',
#  'lucila',
#  'jazmin',
#  'vela',
#  'petra',
#  'dunne',
#  'kuna',
#  'cristopher',
#  'delfina',
#  'shavonda',
#  'calhoun',
#  'kyles',
#  'ciara',
#  'raguel',
#  'leahy',
#  'annually',
#  'sharpe',
#  'riedel',
#  'bojorquez',
#  'mariann',
#  'jolene',
#  'pettigrew',
#  'appling',
#  'marker',
#  'lyda',
#  'yasuko',
#  'christ',
#  'keisha',
#  'hartung',
#  'totten',
#  'eleanore',
#  'nakfa',
#  'posey',
#  'govan',
#  'goad',
#  'bosworth',
#  'gamboa',
#  'roberts',
#  'julienne',
#  'wallace',
#  'tiffanie',
#  'jacinda',
#  'keeling',
#  'bash',
#  'leota',
#  'eberhardt',
#  'alaina',
#  'arnett',
#  'daniele',
#  'parris',
#  'gass',
#  'adah',
#  'pollard',
#  'librada',
#  'grande',
#  'sharita',
#  'sal',
#  'wenger',
#  'marra',
#  'elza',
#  'palermo',
#  'tyrrell',
#  'claypool',
#  'contains',
#  'bob',
#  'latin',
#  'talia',
#  'lizabeth',
#  'flick',
#  'beebe',
#  'markita',
#  'newsom',
#  'carothers',
#  'everson',
#  'brittni',
#  'vidal',
#  'roseann',
#  'ellsworth',
#  'chen',
#  'haskins',
#  'smalley',
#  'leibowitz',
#  'mccann',
#  'mumford',
#  'alaniz',
#  'vicky',
#  'yancy',
#  'sherie',
#  'fong',
#  'compton',
#  'barron',
#  'deann',
#  'iowa',
#  'tharpe',
#  'whenever',
#  'spell',
#  'latonia',
#  'yuri',
#  'zhao',
#  'felipa',
#  'adkins',
#  'gallo',
#  'fenner',
#  'bixler',
#  'swope',
#  'espinal',
#  'kirchner',
#  'knutson',
#  'viera',
#  'reitz',
#  'buggs',
#  'hance',
#  'rochel',
#  'thibault',
#  'colley',
#  'rusty',
#  'lynnette',
#  'shaunte',
#  'worsham',
#  'xx',
#  'christeen',
#  'welborn',
#  'tetreault',
#  'schneider',
#  'billye',
#  'glenn',
#  'griffin',
#  'case',
#  'wyant',
#  'nicholls',
#  'switzer',
#  'slayton',
#  'beatriz',
#  'angelena',
#  'tabetha',
#  'jennifer',
#  'hai',
#  'max',
#  'andera',
#  'russia',
#  'wasson',
#  'argelia',
#  'schlueter',
#  'nu',
#  'thomasina',
#  'kellner',
#  'carmon',
#  'herschel',
#  'olinger',
#  'schick',
#  'seitz',
#  'cinthia',
#  'coronado',
#  'collazo',
#  'cosby',
#  'been',
#  'thai',
#  'marlyn',
#  'better',
#  'manor',
#  'sparrow',
#  'alaska',
#  'ridge',
#  'candi',
#  'cho',
#  'ewa',
#  'simon',
#  'aiello',
#  'charlsie',
#  'tilley',
#  'chad',
#  'keys',
#  'dehaven',
#  'chandra',
#  'kiesha',
#  'will',
#  'elizabeth',
#  'lillian',
#  'hoa',
#  'romelia',
#  'jerrica',
#  'candis',
#  'kyoko',
#  'boggess',
#  'travis',
#  'allow',
#  'wild',
#  'salina',
#  'rondeau',
#  'using',
#  'already',
#  'isiah',
#  'hector',
#  'wilmer',
#  'portia',
#  'troyer',
#  'deans',
#  'macdougall',
#  'durbin',
#  'fisk',
#  'seen',
#  'cranford',
#  'sweat',
#  'pickle',
#  'chick',
#  'kristine',
#  'jeramy',
#  'spears',
#  'josef',
#  'mcfarland',
#  'alysia',
#  'chaves',
#  'emmy',
#  'elsewhere',
#  'value',
#  'leann',
#  'buss',
#  'towne',
#  'others',
#  'castillo',
#  'torrie',
#  'fetter',
#  'tammi',
#  'helen',
#  'bruton',
#  'paradis',
#  'awilda',
#  'mejia',
#  'jamison',
#  'hibbard',
#  'june',
#  'meghann',
#  'kauffman',
#  'haddix',
#  'janella',
#  'jessica',
#  'zachary',
#  'hopper',
#  'mackey',
#  'doyle',
#  'beula',
#  'shirley',
#  'bean',
#  'brinda',
#  'hastings',
#  'tait',
#  'latterly',
#  'pitts',
#  'guertin',
#  'cyril',
#  'jimmie',
#  'gemma',
#  'randazzo',
#  'finnegan',
#  'denman',
#  'malave',
#  'duran',
#  'mancuso',
#  'dew',
#  'vergara',
#  'isaacs',
#  'dailey',
#  'hulse',
#  'almeta',
#  'pitcher',
#  'foster',
#  'frederic',
#  'kylee',
#  'hamlett',
#  'liza',
#  'almeda',
#  'melony',
#  'verde',
#  'lacombe',
#  'rickey',
#  'kinsey',
#  'zambrano',
#  'nada',
#  'sue',
#  'metcalf',
#  'lindgren',
#  'mamie',
#  'lara',
#  'bard',
#  'godoy',
#  'mattie',
#  'zofia',
#  'probably',
#  'clifton',
#  'lorenz',
#  'osorio',
#  'pennington',
#  'tisa',
#  'anybody',
#  'pippin',
#  'mccune',
#  'monnie',
#  'evette',
#  'hollis',
#  'ashcraft',
#  'seely',
#  'sheets',
#  'otha',
#  'sealy',
#  'mendoza',
#  'sanborn',
#  'johnna',
#  'justa',
#  'ethridge',
#  'schilling',
#  'himself',
#  'lavigne',
#  'boyd',
#  'tell',
#  'barbra',
#  'can',
#  'fannin',
#  'tameika',
#  'remington',
#  'bacon',
#  'natisha',
#  'green',
#  'loucks',
#  'whitmer',
#  'sharkey',
#  'madera',
#  'theressa',
#  'ashli',
#  'further',
#  'cardoza',
#  'trujillo',
#  'mcevoy',
#  'gosnell',
#  'ponce',
#  'wilhelmina',
#  'greiner',
#  'goode',
#  'nakesha',
#  'bryan',
#  'tennyson',
#  'aparicio',
#  'beverly',
#  'munro',
#  'kyser',
#  'stallworth',
#  'bivens',
#  'newport',
#  'szymanski',
#  'burford',
#  'jeanelle',
#  'royer',
#  'mitsue',
#  'benito',
#  'doreatha',
#  'riel',
#  'berndt',
#  'burgett',
#  'isabelle',
#  'winger',
#  'dessie',
#  'fortner',
#  'katie',
#  'warren',
#  'ocasio',
#  'mcabee',
#  'formerly',
#  'noone',
#  'montanez',
#  'mccabe',
#  'welch',
#  'nov',
#  'mack',
#  'nobles',
#  'roden',
#  'lats',
#  'jenna',
#  'blunt',
#  'witter',
#  'angulo',
#  'camara',
#  'lawhorn',
#  'mays',
#  'vesta',
#  'abrams',
#  'elicia',
#  'lakita',
#  'melanson',
#  'deidra',
#  'mechelle',
#  'elisa',
#  'robinett',
#  'willia',
#  'shanghai',
#  'vietnam',
#  'thornburg',
#  'micheal',
#  'duong',
#  'rue',
#  'macmillan',
#  'latoyia',
#  'adena',
#  'burkhardt',
#  'jacob',
#  'felicia',
#  'gwin',
#  'xvii',
#  'tawny',
#  'mortimer',
#  'evangeline',
#  'mcdonough',
#  'cavender',
#  'hannan',
#  'appleby',
#  'natividad',
#  'luigi',
#  'mclendon',
#  'utley',
#  'gillum',
#  'stephenie',
#  'janssen',
#  'koehler',
#  'necaise',
#  'vandenberg',
#  'jeanette',
#  'tennie',
#  'lucas',
#  'garfield',
#  'michal',
#  'kroll',
#  'tony',
#  's',
#  'trudeau',
#  'miyoko',
#  'mauro',
#  'harrington',
#  'guillermina',
#  'pam',
#  'sandler',
#  'lakia',
#  'jarod',
#  'franchesca',
#  'sara',
#  'dora',
#  'bauer',
#  'sanford',
#  'snapp',
#  'kraft',
#  'kiley',
#  'magee',
#  'pickering',
#  'dara',
#  'lisbeth',
#  'messina',
#  'buford',
#  'ricci',
#  'romeo',
#  'goldsmith',
#  'oden',
#  'corso',
#  'whitener',
#  'afghani',
#  'stacey',
#  'callaghan',
#  'kester',
#  'myers',
#  'oxford',
#  'donnie',
#  'bollinger',
#  'sharell',
#  'lanny',
#  'lavern',
#  'johnsen',
#  'garnet',
#  'hollar',
#  'tonie',
#  'wilke',
#  'at',
#  'herself',
#  'rodney',
#  'mcdade',
#  'mcnabb',
#  'sherill',
#  'boylan',
#  'kenton',
#  'wendolyn',
#  'vinson',
#  'jonelle',
#  'toussaint',
#  'krysta',
#  'kohn',
#  'zonia',
#  'hedrick',
#  'futrell',
#  'kean',
#  'moua',
#  'clarence',
#  'rod',
#  'annita',
#  'searcy',
#  'valentina',
#  'cleopatra',
#  'pinkerton',
#  'turk',
#  'dooley',
#  'bassett',
#  'tull',
#  'leonarda',
#  'swisher',
#  'steen',
#  'yager',
#  'malinda',
#  'leath',
#  'fifield',
#  'except',
#  'dovie',
#  'sabra',
#  'eunice',
#  'apr',
#  'bev',
#  'meacham',
#  'ashworth',
#  'roof',
#  'adelaida',
#  'appel',
#  'charlott',
#  'napper',
#  'birchfield',
#  'yoshiko',
#  'caryn',
#  'swift',
#  'brehm',
#  'dodge',
#  'khalilah',
#  'mcglynn',
#  'now',
#  'dillon',
#  'oquinn',
#  'wortham',
#  'jake',
#  'adriene',
#  'evers',
#  'willodean',
#  'lilia',
#  'tarrant',
#  'rosendo',
#  'samuels',
#  'klinger',
#  'carrera',
#  'nicolasa',
#  'sell',
#  'neubauer',
#  'carrier',
#  'nelia',
#  'lovella',
#  'bouton',
#  'watters',
#  'swanson',
#  'lipscomb',
#  'everything',
#  'baugher',
#  'bartley',
#  'swinton',
#  'elizondo',
#  'janae',
#  'carrell',
#  'clift',
#  'alcantar',
#  'anneliese',
#  'bly',
#  'q',
#  'yocum',
#  'alene',
#  'ingalls',
#  'anson',
#  'keene',
#  'mauritania',
#  'dyke',
#  'edington',
#  'ashly',
#  'lozada',
#  'deadra',
#  'jacquline',
#  'stoker',
#  'copper',
#  'goodnight',
#  'ingrid',
#  'haley',
#  'cristobal',
#  'elinore',
#  'april',
#  'keren',
#  'winters',
#  'gambrell',
#  'edmonds',
#  'flint',
#  'ashburn',
#  'nine',
#  'camacho',
#  'gottlieb',
#  'alisia',
#  'settle',
#  'maddox',
#  'criswell',
#  'blalock',
#  'venezuela',
#  'celina',
#  'janay',
#  'laughlin',
#  'sikora',
#  'nickerson',
#  'zelma',
#  'tiffani',
#  'verdell',
#  'petry',
#  'franke',
#  'fite',
#  'gilmore',
#  'gillespie',
#  'byron',
#  'hassie',
#  'necole',
#  'shutt',
#  'thorson',
#  'jolanda',
#  'carlie',
#  'ora',
#  'agueda',
#  'carr',
#  'dover',
#  'roddy',
#  'germaine',
#  'rosetta',
#  'seeming',
#  'packard',
#  'hammett',
#  'knapp',
#  'coulombe',
#  'dandridge',
#  'crespo',
#  'ute',
#  'melida',
#  'macpherson',
#  'casey',
#  'lacresha',
#  'baxter',
#  'stroud',
#  'salcedo',
#  'lackey',
#  'hahn',
#  'pease',
#  'christinia',
#  'henry',
#  'clements',
#  'schwartz',
#  'laine',
#  'kieth',
#  'bettina',
#  'terisa',
#  'montez',
#  'cordova',
#  'waltraud',
#  'ruvalcaba',
#  'dill',
#  'oh',
#  'graciela',
#  'connie',
#  'our',
#  'real',
#  'core',
#  'radcliff',
#  'pearl',
#  'genevieve',
#  'roxie',
#  'syreeta',
#  'loni',
#  'click',
#  'emil',
#  'doug',
#  'huynh',
#  'bradly',
#  'leclair',
#  'shanon',
#  'sharen',
#  'beside',
#  'honey',
#  'denney',
#  'saad',
#  'muriel',
#  'carmel',
#  'holland',
#  'crutcher',
#  'rowley',
#  'dorthy',
#  'dingle',
#  'michel',
#  'fannie',
#  'hobbs',
#  'saxton',
#  'erlene',
#  'milissa',
#  'canada',
#  'hinkley',
#  'candance',
#  'thirteen',
#  'roe',
#  'bachman',
#  'blanche',
#  'trammell',
#  'callie',
#  'backman',
#  'maxima',
#  'pritchard',
#  'rutherford',
#  'rial',
#  'marine',
#  'debby',
#  'bermuda',
#  'chastity',
#  'livingston',
#  'imelda',
#  'lazarus',
#  'grogan',
#  'wilton',
#  'robin',
#  'meredith',
#  'leonila',
#  'payton',
#  'burden',
#  'lawanna',
#  'lloyd',
#  'rosenberger',
#  'tong',
#  'kimura',
#  'carrion',
#  'ellis',
#  'desmarais',
#  'joanie',
#  'cecily',
#  'never',
#  'strother',
#  'sweden',
#  'leif',
#  'associated',
#  'kahn',
#  'ayako',
#  'hertha',
#  'verdie',
#  'trimble',
#  'elmore',
#  'feldman',
#  'bushman',
#  'coletta',
#  'ballard',
#  'rutledge',
#  'johns',
#  'lyndsey',
#  'yuen',
#  'meaghan',
#  'mayer',
#  'weekly',
#  'jerold',
#  'briley',
#  'tenge',
#  'guzman',
#  'tobin',
#  'covert',
#  'japanese',
#  'fuqua',
#  'man',
#  'tierney',
#  'mcmorris',
#  'lyman',
#  'solorio',
#  'boren',
#  'schoen',
#  'mccray',
#  'barker',
#  'carmichael',
#  'malorie',
#  'banister',
#  'malvina',
#  'wallin',
#  'felisha',
#  'shay',
#  'jackie',
#  'tyra',
#  'beggs',
#  'guerra',
#  'ona',
#  'infante',
#  'elam',
#  'duty',
#  'stillman',
#  'heard',
#  'johansen',
#  'ward',
#  'sau',
#  'mccutcheon',
#  'decosta',
#  'wanita',
#  'glinda',
#  'ford',
#  'hilma',
#  'nancie',
#  'garibay',
#  'weatherly',
#  'river',
#  'francisca',
#  'honaker',
#  'holston',
#  'stroman',
#  'wiles',
#  'beulah',
#  'liane',
#  'guest',
#  'hiedi',
#  'binder',
#  'grigg',
#  'usually',
#  'lekisha',
#  'middleton',
#  'fries',
#  'dukes',
#  'across',
#  'armenta',
#  'roundtree',
#  'enola',
#  'farwell',
#  'lomax',
#  'propst',
#  'deason',
#  'jeanne',
#  'carma',
#  'vallie',
#  'runion',
#  'nugent',
#  'gregoria',
#  'epifania',
#  'fritz',
#  'take',
#  'lind',
#  'eng',
#  'inell',
#  'rosanna',
#  'hoang',
#  'patrica',
#  'yours',
#  'laquanda',
#  'mcdonald',
#  'mercer',
#  'branson',
#  'ault',
#  'pruitt',
#  'moore',
#  'elida',
#  'simona',
#  'mistie',
#  'gaskins',
#  'stiltner',
#  'duval',
#  'cyrstal',
#  'pamila',
#  'wolfe',
#  'gee',
#  'diaz',
#  'tiesha',
#  'ardis',
#  'debroah',
#  'barros',
#  'ashanti',
#  'arenas',
#  'howerton',
#  'tennessee',
#  'charity',
#  'durden',
#  'burrow',
#  'etc',
#  'taylor',
#  'alfaro',
#  'ohio',
#  'come',
#  'ibarra',
#  'race',
#  'quimby',
#  'hortencia',
#  'casanova',
#  'corey',
#  'ralston',
#  'hammon',
#  'salem',
#  'cameron',
#  'deena',
#  'doreen',
#  'carmack',
#  'council',
#  'lottie',
#  'cedillo',
#  'wills',
#  'shalonda',
#  'blaisdell',
#  'boss',
#  'ghislaine',
#  'snook',
#  'louisa',
#  'melody',
#  'montiel',
#  'aline',
#  'myanmar',
#  'comeau',
#  'larochelle',
#  'shell',
#  'blanks',
#  'zora',
#  'worthington',
#  'sipe',
#  'nicolle',
#  'freese',
#  'anna',
#  'wendy',
#  'jerrie',
#  'irene',
#  'attaway',
#  'walling',
#  'marcelino',
#  'annamae',
#  'boles',
#  'greenwood',
#  'oconnor',
#  ...}

# %%
for keys, tokens in token_dict.items():
    filtered_words = token_dict[keys] 
    
    # Remove stopwords from the list of tokens
    filtered_words = [word for word in filtered_words if word not in stop_words]
    
    token_dict[keys] = filtered_words

for keys, tokens in token_dict.items():
    print(f"{keys} :",len(tokens))
token_dict
# Out:
# blackassign0001.txt : 428
# blackassign0002.txt : 616
# blackassign0003.txt : 572
# blackassign0004.txt : 550
# blackassign0005.txt : 307
# blackassign0006.txt : 941
# blackassign0007.txt : 592
# blackassign0008.txt : 426
# blackassign0009.txt : 532
# blackassign0010.txt : 1505
# blackassign0011.txt : 718
# blackassign0012.txt : 773
# blackassign0013.txt : 263
# blackassign0014.txt : 460
# blackassign0015.txt : 572
# blackassign0016.txt : 572
# blackassign0017.txt : 519
# blackassign0018.txt : 475
# blackassign0019.txt : 762
# blackassign0020.txt : 198
# blackassign0021.txt : 485
# blackassign0022.txt : 165
# blackassign0023.txt : 504
# blackassign0024.txt : 239
# blackassign0025.txt : 360
# blackassign0026.txt : 407
# blackassign0027.txt : 471
# blackassign0028.txt : 469
# blackassign0029.txt : 889
# blackassign0030.txt : 522
# blackassign0031.txt : 778
# blackassign0032.txt : 589
# blackassign0033.txt : 693
# blackassign0034.txt : 523
# blackassign0035.txt : 310
# blackassign0036.txt : 1
# blackassign0037.txt : 300
# blackassign0038.txt : 842
# blackassign0039.txt : 872
# blackassign0040.txt : 545
# blackassign0041.txt : 529
# blackassign0042.txt : 579
# blackassign0043.txt : 654
# blackassign0044.txt : 232
# blackassign0045.txt : 653
# blackassign0046.txt : 398
# blackassign0047.txt : 313
# blackassign0048.txt : 128
# blackassign0049.txt : 1
# blackassign0050.txt : 588
# blackassign0051.txt : 288
# blackassign0052.txt : 717
# blackassign0053.txt : 282
# blackassign0054.txt : 173
# blackassign0055.txt : 482
# blackassign0056.txt : 281
# blackassign0057.txt : 143
# blackassign0058.txt : 77
# blackassign0059.txt : 309
# blackassign0060.txt : 74
# blackassign0061.txt : 537
# blackassign0062.txt : 215
# blackassign0063.txt : 414
# blackassign0064.txt : 755
# blackassign0065.txt : 649
# blackassign0066.txt : 553
# blackassign0067.txt : 279
# blackassign0068.txt : 472
# blackassign0069.txt : 162
# blackassign0070.txt : 640
# blackassign0071.txt : 347
# blackassign0072.txt : 437
# blackassign0073.txt : 500
# blackassign0074.txt : 601
# blackassign0075.txt : 370
# blackassign0076.txt : 559
# blackassign0077.txt : 338
# blackassign0078.txt : 525
# blackassign0079.txt : 671
# blackassign0080.txt : 1249
# blackassign0081.txt : 696
# blackassign0082.txt : 743
# blackassign0083.txt : 58
# blackassign0084.txt : 386
# blackassign0085.txt : 632
# blackassign0086.txt : 696
# blackassign0087.txt : 440
# blackassign0088.txt : 736
# blackassign0089.txt : 392
# blackassign0090.txt : 487
# blackassign0091.txt : 426
# blackassign0092.txt : 521
# blackassign0093.txt : 61
# blackassign0094.txt : 471
# blackassign0095.txt : 262
# blackassign0096.txt : 500
# blackassign0097.txt : 375
# blackassign0098.txt : 183
# blackassign0099.txt : 231
# blackassign0100.txt : 453
# {'blackassign0001.txt': ['rising',
#   'impact',
#   'economy',
#   'environment',
#   'infrastructure',
#   'life',
#   'blackcoffer',
#   'insights',
#   'huge',
#   'development',
#   'dependence',
#   'people',
#   'technology',
#   'recent',
#   'years',
#   'development',
#   'chatgpt',
#   'recent',
#   'years',
#   'normal',
#   'thing',
#   'fully',
#   'dependent',
#   'technology',
#   'information',
#   'technology',
#   'developing',
#   'member',
#   'developing',
#   'rapidly',
#   'growing',
#   'base',
#   'grown',
#   'control',
#   'centres',
#   'information',
#   'technology',
#   'citiesnoida',
#   'uttar',
#   'pradesh',
#   'emerging',
#   'sector',
#   'companies',
#   'google',
#   'microsoft',
#   'ibm',
#   'infosys',
#   'set',
#   'companies',
#   'noida',
#   'market',
#   'base',
#   'billions',
#   'dollars',
#   'great',
#   'job',
#   'boosting',
#   'national',
#   'economy',
#   'establishment',
#   'software',
#   'companies',
#   'made',
#   'noida',
#   'information',
#   'technology',
#   'haryana',
#   'emerging',
#   'hub',
#   'companies',
#   'google',
#   'microsoft',
#   'ibm',
#   'infosys',
#   'set',
#   'companies',
#   'gurgaon',
#   'market',
#   'base',
#   'billions',
#   'dollars',
#   'great',
#   'job',
#   'boosting',
#   'national',
#   'called',
#   'hub',
#   'companies',
#   'google',
#   'microsoft',
#   'ibm',
#   'infosys',
#   'set',
#   'companies',
#   'bengaluru',
#   'market',
#   'base',
#   'billions',
#   'dollars',
#   'great',
#   'job',
#   'boosting',
#   'national',
#   'bengal',
#   'emerging',
#   'hub',
#   'kolkata',
#   'saltlake',
#   'sector',
#   'town',
#   'rajarhat',
#   'area',
#   'kolkata',
#   'hub',
#   'government',
#   'giving',
#   'software',
#   'companies',
#   'cost',
#   'set',
#   'companies',
#   'companies',
#   'google',
#   'microsoft',
#   'ibm',
#   'infosys',
#   'set',
#   'companies',
#   'kolkata',
#   'market',
#   'base',
#   'billions',
#   'dollars',
#   'great',
#   'job',
#   'boosting',
#   'national',
#   'economythere',
#   'huge',
#   'impact',
#   'rising',
#   'economy',
#   'effects',
#   'rising',
#   'greatly',
#   'boost',
#   'economy',
#   'create',
#   'huge',
#   'demand',
#   'raw',
#   'materials',
#   'products',
#   'huge',
#   'demand',
#   'people',
#   'supply',
#   'fulfilment',
#   'demand',
#   'highly',
#   'populous',
#   'demand',
#   'finished',
#   'products',
#   'develop',
#   'companies',
#   'fulfil',
#   'desires',
#   'people',
#   'populous',
#   'develop',
#   'companies',
#   'supply',
#   'finished',
#   'products',
#   'marketis',
#   'economic',
#   'agents',
#   'buyers',
#   'interact',
#   'populous',
#   'huge',
#   'market',
#   'companies',
#   'world',
#   'competition',
#   'market',
#   'increase',
#   'consumers',
#   'differentiated',
#   'products',
#   'market',
#   'run',
#   'smoothly',
#   'competitive',
#   'market',
#   'healthy',
#   'safely',
#   'assume',
#   'oligopoly',
#   'market',
#   'surely',
#   'tend',
#   'reach',
#   'perfectly',
#   'competitive',
#   'market',
#   'market',
#   'increases',
#   'revenue',
#   'generated',
#   'present',
#   'revenue',
#   'dollars',
#   'dollars',
#   'financial',
#   'companies',
#   'invest',
#   'leads',
#   'increase',
#   'market',
#   'turn',
#   'generates',
#   'revenue',
#   'expect',
#   'revenue',
#   'tend',
#   'reach',
#   'dollars',
#   'environmentthe',
#   'rising',
#   'create',
#   'huge',
#   'impact',
#   'environment',
#   'maximum',
#   'harmful',
#   'effects',
#   'impact',
#   'rising',
#   'environment',
#   'cutting',
#   'trees',
#   'huge',
#   'make',
#   'building',
#   'companies',
#   'great',
#   'harm',
#   'environment',
#   'cutting',
#   'trees',
#   'scale',
#   'mass',
#   'degradation',
#   'carbon',
#   'footprint',
#   'companies',
#   'generate',
#   'carbon',
#   'footprint',
#   'atmosphere',
#   'asian',
#   'including',
#   'carbon',
#   'footprint',
#   'sector',
#   'grows',
#   'generation',
#   'carbon',
#   'footprint',
#   'birds',
#   'cell',
#   'phone',
#   'mobile',
#   'towers',
#   'telecom',
#   'companies',
#   'caused',
#   'death',
#   'birds',
#   'caused',
#   'great',
#   'imbalance',
#   'ecosystem',
#   'number',
#   'sparrows',
#   'reduced',
#   'due',
#   'phenomenon',
#   'extinction',
#   'species',
#   'infrastructurethere',
#   'contributions',
#   'infrastructure',
#   'rising',
#   'excellent',
#   'transport',
#   'system',
#   'supply',
#   'raw',
#   'materials',
#   'delivery',
#   'finished',
#   'products',
#   'market',
#   'transportation',
#   'system',
#   'develops',
#   'area',
#   'excellent',
#   'transport',
#   'system',
#   'apublic',
#   'transport',
#   'system',
#   'public',
#   'transport',
#   'system',
#   'source',
#   'employment',
#   'huge',
#   'population',
#   'reside',
#   'areas',
#   'adequate',
#   'public',
#   'transport',
#   'systems',
#   'buses',
#   'taxis',
#   'improved',
#   'supply',
#   'huge',
#   'number',
#   'people',
#   'reside',
#   'adequate',
#   'water',
#   'supply',
#   'fulfil',
#   'people',
#   'industries',
#   'find',
#   'methods',
#   'water',
#   'supply',
#   'conservation',
#   'supply',
#   'lifeline',
#   'sector',
#   'electric',
#   'supply',
#   'machines',
#   'run',
#   'flourish',
#   'flourish',
#   'excellent',
#   'electric',
#   'supply',
#   'number',
#   'people',
#   'reside',
#   'proper',
#   'health',
#   'infrastructure',
#   'healthcare',
#   'facilities',
#   'people',
#   'growth',
#   'healthcare',
#   'system',
#   'improve',
#   'primary',
#   'proper',
#   'education',
#   'training',
#   'centres',
#   'fulfil',
#   'people',
#   'demands',
#   'growth',
#   'education',
#   'system',
#   'develop',
#   'education',
#   'lifewith',
#   'growth',
#   'people',
#   'jobs',
#   'earn',
#   'purchasing',
#   'people',
#   'increase',
#   'people',
#   'lead',
#   'lifestyle',
#   'buy',
#   'things',
#   'tastes',
#   'preferences',
#   'people',
#   'change',
#   'human',
#   'development',
#   'index',
#   'increase',
#   'people',
#   'buy',
#   'quality',
#   'food',
#   'quality',
#   'cars',
#   'food',
#   'automobile',
#   'industries',
#   'increase',
#   'huge',
#   'impact',
#   'life',
#   'insights',
#   'arka',
#   'mukhopadhyay',
#   'bengal',
#   'university',
#   'animal',
#   'fishery',
#   'sciences'],
#  'blackassign0002.txt': ['rising',
#   'impact',
#   'economy',
#   'environment',
#   'infrastructure',
#   'life',
#   'future',
#   'blackcoffer',
#   'insights',
#   'history',
#   'industrial',
#   'revolution',
#   'century',
#   'development',
#   'internet',
#   'technology',
#   'primary',
#   'societal',
#   'change',
#   'aided',
#   'turning',
#   'centers',
#   'provide',
#   'opportunities',
#   'improvements',
#   'quality',
#   'life',
#   'continues',
#   'play',
#   'crucial',
#   'role',
#   'altering',
#   'world',
#   'acting',
#   'engines',
#   'economic',
#   'growth',
#   'modernization',
#   'technologically',
#   'advanced',
#   'considerably',
#   'accelerating',
#   'trajectory',
#   'ofglobal',
#   'development',
#   'technology',
#   'revolutionary',
#   'effects',
#   'ushering',
#   'change',
#   'advancement',
#   'smetropolitan',
#   'centershave',
#   'embraced',
#   'technology',
#   'ways',
#   'transforming',
#   'fundamental',
#   'fabric',
#   'life',
#   'infrastructure',
#   'governance',
#   'world',
#   'rushes',
#   'digital',
#   'play',
#   'crucial',
#   'part',
#   'develop',
#   'worldwide',
#   'economic',
#   'powerhouse',
#   'world',
#   'economies',
#   'greatest',
#   'growth',
#   'rates',
#   'aims',
#   'reach',
#   'ingdpby',
#   'celebrate',
#   'years',
#   'independence',
#   'idea',
#   'technology',
#   'obvious',
#   'effects',
#   'progressively',
#   'implementing',
#   'technologies',
#   'build',
#   'effective',
#   'linked',
#   'landscapes',
#   'improve',
#   'quality',
#   'life',
#   'people',
#   'data',
#   'analytics',
#   'theinternet',
#   'things',
#   'iot',
#   'traffic',
#   'management',
#   'solutions',
#   'instance',
#   'improve',
#   'traffic',
#   'flow',
#   'lowering',
#   'congestion',
#   'air',
#   'pollution',
#   'garbage',
#   'collection',
#   'improves',
#   'waste',
#   'management',
#   'resulting',
#   'cleaner',
#   'healthier',
#   'world',
#   'economy',
#   'steps',
#   'crucial',
#   'relates',
#   'ongoing',
#   'urbanization',
#   'development',
#   'population',
#   'predicted',
#   'expanded',
#   'fourfold',
#   'population',
#   'world',
#   'predicted',
#   'population',
#   'share',
#   'adding',
#   'residents',
#   'centers',
#   'economic',
#   'growth',
#   'innovation',
#   'home',
#   'innovative',
#   'businesses',
#   'employment',
#   'important',
#   'institutions',
#   'kolkata',
#   'chennai',
#   'increased',
#   'productivity',
#   'routes',
#   'generally',
#   'asagglomeration',
#   'economies',
#   'permitting',
#   'contact',
#   'businesses',
#   'employees',
#   'theory',
#   'consequence',
#   'businesses',
#   'bigger',
#   'denser',
#   'productive',
#   'urbanization',
#   'significant',
#   'impact',
#   'rest',
#   'world',
#   'boasts',
#   'economy',
#   'world',
#   'period',
#   'exceeded',
#   'terms',
#   'economic',
#   'size',
#   'surpassed',
#   'claim',
#   'higher',
#   'people',
#   'living',
#   'urbanized',
#   'stunning',
#   'people',
#   'living',
#   'urbanized',
#   'advantages',
#   'disadvantages',
#   'including',
#   'financial',
#   'expenditures',
#   'growth',
#   'result',
#   'possibilities',
#   'higher',
#   'standard',
#   'living',
#   'presents',
#   'difficulties',
#   'issues',
#   'rapid',
#   'urbanization',
#   'potential',
#   'deplete',
#   'resources',
#   'harm',
#   'environment',
#   'worsensocioeconomicinequities',
#   'depending',
#   'problems',
#   'solved',
#   'urbanization',
#   'favorable',
#   'negative',
#   'half',
#   'world',
#   'population',
#   'living',
#   'urbanization',
#   'emerged',
#   'force',
#   'development',
#   'presents',
#   'fresh',
#   'difficulties',
#   'chances',
#   'reshaping',
#   'planet',
#   'life',
#   'unexpected',
#   'ways',
#   'future',
#   'whereartificial',
#   'intelligence',
#   'increasingly',
#   'pervasive',
#   'impact',
#   'parts',
#   'lives',
#   'ushered',
#   'shift',
#   'urbanization',
#   'improved',
#   'living',
#   'conditions',
#   'economic',
#   'opportunities',
#   'calls',
#   'careful',
#   'management',
#   'sustainable',
#   'practices',
#   'guarantee',
#   'prosperous',
#   'future',
#   'population',
#   'demography',
#   'contribute',
#   'significantly',
#   'growth',
#   'rapidly',
#   'rising',
#   'population',
#   'favor',
#   'expected',
#   'host',
#   'world',
#   'years',
#   'aback',
#   'gdp',
#   'growth',
#   'rate',
#   'predicted',
#   'top',
#   'charts',
#   'asian',
#   'bloc',
#   'primarily',
#   'controlled',
#   'bangalore',
#   'enormous',
#   'percent',
#   'gdp',
#   'growth',
#   'dhaka',
#   'bangalore',
#   'startup',
#   'culture',
#   'enormous',
#   'skill',
#   'set',
#   'bangalore',
#   'bethe',
#   'future',
#   'silicon',
#   'valleyof',
#   'entire',
#   'world',
#   'creates',
#   'tremendous',
#   'number',
#   'startups',
#   'potential',
#   'rank',
#   'world',
#   'urbanized',
#   'outpace',
#   'global',
#   'average',
#   'gdp',
#   'growth',
#   'rate',
#   'expected',
#   'sizeable',
#   'expand',
#   'modernize',
#   'meet',
#   'societal',
#   'demands',
#   'growth',
#   'attributed',
#   'migration',
#   'future',
#   'offspring',
#   'maintain',
#   'balance',
#   'environment',
#   'sustainable',
#   'growth',
#   'impacted',
#   'climate',
#   'change',
#   'areas',
#   'effects',
#   'climate',
#   'change',
#   'harm',
#   'environment',
#   'prolonged',
#   'heat',
#   'waves',
#   'irregular',
#   'rainfall',
#   'drought',
#   'heat',
#   'waves',
#   'disrupted',
#   'society',
#   'dealing',
#   'extreme',
#   'heat',
#   'waves',
#   'drying',
#   'making',
#   'impossible',
#   'produce',
#   'hydroelectricity',
#   'unusually',
#   'number',
#   'floods',
#   'districts',
#   'underwater',
#   'representing',
#   'loss',
#   'roughly',
#   'agrarian',
#   'pastoralist',
#   'types',
#   'society',
#   'heavily',
#   'rely',
#   'environment',
#   'severely',
#   'impacted',
#   'effects',
#   'migration',
#   'projected',
#   'rise',
#   'livelihoods',
#   'world',
#   'affected',
#   'climate',
#   'broader',
#   'prospects',
#   'regional',
#   'environments',
#   'likewise',
#   'impacted',
#   'urbanization',
#   'increases',
#   'amount',
#   'air',
#   'pollution',
#   'precipitation',
#   'frequency',
#   'days',
#   'thunderstorms',
#   'observed',
#   'areas',
#   'downwind',
#   'industrial',
#   'complexes',
#   'regions',
#   'produce',
#   'precipitation',
#   'water',
#   'filtration',
#   'lowers',
#   'water',
#   'tables',
#   'areas',
#   'consume',
#   'significantly',
#   'energy',
#   'rural',
#   'communities',
#   'heating',
#   'cooking',
#   'transportation',
#   'electricity',
#   'instance',
#   'today',
#   'metropolitan',
#   'populations',
#   'cars',
#   'rural',
#   'technology',
#   'healthcare',
#   'education',
#   'significant',
#   'extending',
#   'access',
#   'education',
#   'traditional',
#   'classrooms',
#   'online',
#   'education',
#   'platforms',
#   'aredemocratizing',
#   'learning',
#   'remote',
#   'places',
#   'reached',
#   'telemedicine',
#   'doctors',
#   'diagnose',
#   'patients',
#   'distance',
#   'healthcare',
#   'gaps',
#   'advancements',
#   'essential',
#   'varied',
#   'achieving',
#   'access',
#   'healthcare',
#   'education',
#   'historically',
#   'proven',
#   'effect',
#   'technology',
#   'job',
#   'trends',
#   'factor',
#   'account',
#   'technology',
#   'opens',
#   'possibilities',
#   'challenges',
#   'established',
#   'employment',
#   'positions',
#   'raising',
#   'concerns',
#   'job',
#   'displacement',
#   'skill',
#   'upgrading',
#   'ensure',
#   'left',
#   'wake',
#   'essential',
#   'strike',
#   'balance',
#   'technological',
#   'advancement',
#   'social',
#   'stimulates',
#   'economic',
#   'development',
#   'entrepreneurship',
#   'wider',
#   'audience',
#   'reached',
#   'enterprises',
#   'growth',
#   'digital',
#   'platforms',
#   'promoting',
#   'economic',
#   'inclusion',
#   'thegig',
#   'economyis',
#   'altering',
#   'established',
#   'labor',
#   'patterns',
#   'creating',
#   'employment',
#   'opportunities',
#   'result',
#   'platforms',
#   'tech',
#   'centers',
#   'bengaluru',
#   'hyderabad',
#   'pune',
#   'startups',
#   'thriving',
#   'fostering',
#   'innovation',
#   'variety',
#   'rapid',
#   'advancement',
#   'technology',
#   'creates',
#   'problems',
#   'worries',
#   'urbanization',
#   'technology',
#   'improvements',
#   'rise',
#   'problems',
#   'thedigital',
#   'divide',
#   'data',
#   'privacy',
#   'worries',
#   'technology',
#   'benefits',
#   'rural',
#   'populations',
#   'struggle',
#   'basic',
#   'digital',
#   'services',
#   'escalating',
#   'disparities',
#   'additionally',
#   'concerns',
#   'data',
#   'security',
#   'privacy',
#   'raised',
#   'growing',
#   'reliance',
#   'technology',
#   'protecting',
#   'personal',
#   'information',
#   'important',
#   'areas',
#   'life',
#   'conclusion',
#   'technology',
#   'permanently',
#   'changing',
#   'transforming',
#   'vibrant',
#   'connected',
#   'effective',
#   'hubs',
#   'due',
#   'technology',
#   'breakthroughs',
#   'education',
#   'healthcare',
#   'entrepreneurship',
#   'substantial',
#   'improvements',
#   'adjustments',
#   'obligations',
#   'digital',
#   'divide',
#   'safeguard',
#   'privacy',
#   'citizen',
#   'data',
#   'guarantee',
#   'advantages',
#   'technology',
#   'dispersed',
#   'fairly',
#   'policymakers',
#   'collaborate',
#   'ability',
#   'lead',
#   'innovation',
#   'progress',
#   'inclusivity',
#   'century',
#   'fully',
#   'realize',
#   'potential',
#   'overcome',
#   'insights',
#   'barenya',
#   'sarangi',
#   'siib',
#   'pune'],
#  'blackassign0003.txt': ['internet',
#   'demand',
#   'evolution',
#   'communication',
#   'impact',
#   'alternative',
#   'pathways',
#   'blackcoffer',
#   'insights',
#   'introductionin',
#   'span',
#   'decades',
#   'internet',
#   'undergone',
#   'astounding',
#   'transformation',
#   'integral',
#   'part',
#   'lives',
#   'approach',
#   'demand',
#   'internet',
#   'connectivity',
#   'continues',
#   'surge',
#   'promising',
#   'revolutionize',
#   'communicate',
#   'interact',
#   'world',
#   'transformed',
#   'limited',
#   'communication',
#   'tool',
#   'global',
#   'network',
#   'shapes',
#   'lives',
#   'hurtle',
#   'trajectory',
#   'internet',
#   'demand',
#   'profound',
#   'impact',
#   'communication',
#   'poised',
#   'reshape',
#   'foundations',
#   'connect',
#   'interact',
#   'article',
#   'delves',
#   'intricate',
#   'interplay',
#   'internet',
#   'demand',
#   'communication',
#   'dynamics',
#   'alternative',
#   'pathways',
#   'define',
#   'internet',
#   'unstoppable',
#   'risethe',
#   'proliferation',
#   'smartphones',
#   'internet',
#   'things',
#   'iot',
#   'increasing',
#   'reliance',
#   'digital',
#   'services',
#   'driven',
#   'exponential',
#   'increase',
#   'internet',
#   'demand',
#   'surge',
#   'fueled',
#   'growing',
#   'faster',
#   'data',
#   'speeds',
#   'seamless',
#   'connectivity',
#   'access',
#   'information',
#   'services',
#   'digital',
#   'divide',
#   'narrows',
#   'individuals',
#   'communities',
#   'dependent',
#   'internet',
#   'education',
#   'healthcare',
#   'commerce',
#   'social',
#   'interactions',
#   'exponential',
#   'growth',
#   'internet',
#   'demand',
#   'defining',
#   'digital',
#   'age',
#   'basic',
#   'web',
#   'browsing',
#   'streaming',
#   'content',
#   'remote',
#   'collaborations',
#   'demands',
#   'internet',
#   'infrastructure',
#   'surged',
#   'astronomically',
#   'demand',
#   'catalyzed',
#   'proliferation',
#   'devices',
#   'internet',
#   'things',
#   'iot',
#   'insatiable',
#   'appetite',
#   'seamless',
#   'communicationsby',
#   'impact',
#   'rising',
#   'internet',
#   'demand',
#   'communication',
#   'notable',
#   'transformation',
#   'occur',
#   'realm',
#   'connectivity',
#   'continued',
#   'development',
#   'technology',
#   'potentially',
#   'newer',
#   'innovations',
#   'enable',
#   'data',
#   'transfers',
#   'virtually',
#   'eliminating',
#   'lag',
#   'latency',
#   'redefine',
#   'remote',
#   'collaboration',
#   'gaming',
#   'experiences',
#   'communication',
#   'applications',
#   'surge',
#   'internet',
#   'demand',
#   'catalyze',
#   'evolution',
#   'virtual',
#   'augmented',
#   'reality',
#   'communication',
#   'technologies',
#   'enable',
#   'individuals',
#   'interact',
#   'physically',
#   'present',
#   'transcending',
#   'geographical',
#   'boundaries',
#   'enabling',
#   'immersive',
#   'experiences',
#   'teleconferencing',
#   'education',
#   'social',
#   'gatherings',
#   'engaging',
#   'interactive',
#   'internet',
#   'demand',
#   'continues',
#   'rise',
#   'realm',
#   'communication',
#   'set',
#   'monumental',
#   'transformation',
#   'connectivity',
#   'driven',
#   'advancements',
#   'render',
#   'buffering',
#   'lag',
#   'virtually',
#   'obsolete',
#   'revolutionize',
#   'virtual',
#   'experiences',
#   'remote',
#   'work',
#   'digital',
#   'entertainment',
#   'fostering',
#   'sense',
#   'immediacy',
#   'presence',
#   'previously',
#   'unimaginable',
#   'integration',
#   'augmented',
#   'virtual',
#   'reality',
#   'reshape',
#   'communication',
#   'dynamics',
#   'immersive',
#   'virtual',
#   'meetings',
#   'interactive',
#   'entertainment',
#   'experiences',
#   'physical',
#   'distances',
#   'offer',
#   'dimension',
#   'infrastructurehowever',
#   'exponential',
#   'increase',
#   'internet',
#   'demand',
#   'brings',
#   'set',
#   'challenges',
#   'existing',
#   'network',
#   'infrastructure',
#   'struggle',
#   'bandwidth',
#   'requirements',
#   'leading',
#   'congestion',
#   'reduced',
#   'quality',
#   'service',
#   'result',
#   'digital',
#   'divide',
#   'rural',
#   'areas',
#   'underserved',
#   'communities',
#   'influx',
#   'data',
#   'traffic',
#   'raises',
#   'concerns',
#   'data',
#   'privacy',
#   'security',
#   'protecting',
#   'sensitive',
#   'information',
#   'cyber',
#   'threats',
#   'ensuring',
#   'integrity',
#   'personal',
#   'data',
#   'paramount',
#   'striking',
#   'balance',
#   'seamless',
#   'connectivity',
#   'robust',
#   'security',
#   'measures',
#   'complex',
#   'hyperconnected',
#   'landscapethe',
#   'surge',
#   'internet',
#   'demand',
#   'promising',
#   'set',
#   'challenges',
#   'existing',
#   'network',
#   'infrastructure',
#   'struggle',
#   'accommodate',
#   'escalating',
#   'bandwidth',
#   'requirements',
#   'leading',
#   'congestion',
#   'inequitable',
#   'access',
#   'rural',
#   'areas',
#   'underserved',
#   'communities',
#   'face',
#   'connectivity',
#   'disparities',
#   'potentially',
#   'exacerbating',
#   'existing',
#   'digital',
#   'divides',
#   'influx',
#   'data',
#   'traffic',
#   'raises',
#   'concerns',
#   'data',
#   'privacy',
#   'security',
#   'breaches',
#   'responsible',
#   'emerging',
#   'technologies',
#   'hyperconnected',
#   'landscape',
#   'demands',
#   'robust',
#   'measures',
#   'protect',
#   'sensitive',
#   'information',
#   'ensure',
#   'ethical',
#   'alternativesas',
#   'demand',
#   'internet',
#   'connectivity',
#   'intensifies',
#   'alternative',
#   'communication',
#   'methods',
#   'emerging',
#   'potential',
#   'solutions',
#   'noteworthy',
#   'alternatives',
#   'decentralized',
#   'networks',
#   'mesh',
#   'networks',
#   'decentralized',
#   'networks',
#   'based',
#   'blockchain',
#   'technology',
#   'distribute',
#   'control',
#   'multiple',
#   'nodes',
#   'enhancing',
#   'security',
#   'reducing',
#   'risk',
#   'central',
#   'points',
#   'failure',
#   'mesh',
#   'networks',
#   'operate',
#   'connecting',
#   'devices',
#   'directly',
#   'creating',
#   'network',
#   'traditional',
#   'centralized',
#   'infrastructure',
#   'approach',
#   'prove',
#   'invaluable',
#   'areas',
#   'limited',
#   'connectivity',
#   'emergencies',
#   'conventional',
#   'networks',
#   'disrupted',
#   'face',
#   'challenges',
#   'alternative',
#   'pathways',
#   'emerging',
#   'shape',
#   'hyperconnected',
#   'future',
#   'decentralized',
#   'networks',
#   'underpinned',
#   'blockchain',
#   'technology',
#   'offer',
#   'promising',
#   'solution',
#   'distributing',
#   'control',
#   'network',
#   'nodes',
#   'systems',
#   'enhance',
#   'security',
#   'resilience',
#   'reducing',
#   'vulnerabilities',
#   'centralized',
#   'control',
#   'mesh',
#   'networks',
#   'alternative',
#   'challenge',
#   'conventional',
#   'communication',
#   'paradigm',
#   'establishing',
#   'direct',
#   'connections',
#   'networks',
#   'bypass',
#   'traditional',
#   'centralized',
#   'infrastructure',
#   'making',
#   'valuable',
#   'remote',
#   'forging',
#   'hyperconnected',
#   'path',
#   'aheadthe',
#   'holds',
#   'promise',
#   'world',
#   'surge',
#   'internet',
#   'demand',
#   'propelling',
#   'communication',
#   'impact',
#   'transformative',
#   'widespread',
#   'adoption',
#   'connectivity',
#   'integration',
#   'everyday',
#   'interactions',
#   'navigate',
#   'digital',
#   'frontier',
#   'crucial',
#   'address',
#   'challenges',
#   'strained',
#   'infrastructure',
#   'security',
#   'vulnerabilities',
#   'potential',
#   'inequalities',
#   'alternatives',
#   'decentralized',
#   'mesh',
#   'networks',
#   'showcase',
#   'capacity',
#   'innovate',
#   'adapt',
#   'face',
#   'growing',
#   'internet',
#   'demand',
#   'stride',
#   'striking',
#   'balance',
#   'connectivity',
#   'security',
#   'accessibility',
#   'shape',
#   'future',
#   'global',
#   'navigate',
#   'hyperconnected',
#   'future',
#   'stand',
#   'pivotal',
#   'juncture',
#   'choices',
#   'shape',
#   'world',
#   'inhabit',
#   'rise',
#   'internet',
#   'demand',
#   'transformative',
#   'impact',
#   'communication',
#   'opens',
#   'door',
#   'unprecedented',
#   'possibilities',
#   'challenges',
#   'posed',
#   'strained',
#   'infrastructure',
#   'security',
#   'concerns',
#   'underscore',
#   'innovative',
#   'alternative',
#   'pathways',
#   'decentralized',
#   'networks',
#   'mesh',
#   'networks',
#   'exemplify',
#   'capacity',
#   'adapt',
#   'innovate',
#   'choices',
#   'make',
#   'today',
#   'reverberate',
#   'defining',
#   'contours',
#   'world',
#   'connectivity',
#   'accessibility',
#   'security',
#   'set',
#   'sights',
#   'hyperconnected',
#   'future',
#   'embracing',
#   'technology',
#   'potential',
#   'upholding',
#   'ethical',
#   'values',
#   'creating',
#   'society',
#   'thrives',
#   'communication',
#   'journey',
#   'ahead',
#   'innovation',
#   'collaboration',
#   'responsible',
#   'stewardship',
#   'digital',
#   'landscape',
#   'collectively',
#   'insights',
#   'suhani',
#   'bhatt',
#   'vishwakarma',
#   'government',
#   'engineering',
#   'college'],
#  'blackassign0004.txt': ['rise',
#   'cybercrime',
#   'effect',
#   'upcoming',
#   'future',
#   'blackcoffer',
#   'insights',
#   'live',
#   'work',
#   'communicate',
#   'unquestionably',
#   'changed',
#   'result',
#   'rapid',
#   'evolution',
#   'technology',
#   'gain',
#   'digitization',
#   'leave',
#   'vulnerable',
#   'cybercrime',
#   'sinister',
#   'aspect',
#   'innovation',
#   'cybercrime',
#   'worrisome',
#   'issue',
#   'grown',
#   'impacts',
#   'expected',
#   'considerably',
#   'dangerous',
#   'article',
#   'examines',
#   'growing',
#   'problem',
#   'cybercrime',
#   'potentially',
#   'effects',
#   'affect',
#   'people',
#   'businesses',
#   'frequently',
#   'involves',
#   'illicit',
#   'online',
#   'behaviour',
#   'includes',
#   'variety',
#   'offences',
#   'hacking',
#   'identity',
#   'theft',
#   'phishing',
#   'ransomware',
#   'attacks',
#   'digital',
#   'revolution',
#   'industries',
#   'including',
#   'finance',
#   'healthcare',
#   'critical',
#   'infrastructure',
#   'unintentionally',
#   'cybercriminals',
#   'larger',
#   'attack',
#   'find',
#   'flaws',
#   'steal',
#   'sensitive',
#   'data',
#   'experts',
#   'cybercrime',
#   'increased',
#   'frequency',
#   'sophistication',
#   'cybercriminals',
#   'additional',
#   'opportunities',
#   'compromise',
#   'networks',
#   'steal',
#   'data',
#   'result',
#   'technology',
#   'artificial',
#   'intelligence',
#   'quantum',
#   'computing',
#   'internet',
#   'things',
#   'iot',
#   'complexity',
#   'predicted',
#   'reach',
#   'previously',
#   'heights',
#   'robust',
#   'defences',
#   'breached',
#   'cybercriminals',
#   'technology',
#   'artificial',
#   'intelligence',
#   'machine',
#   'learning',
#   'quantum',
#   'computing',
#   'attacks',
#   'greater',
#   'accuracy',
#   'adaptability',
#   'advances',
#   'impacts',
#   'cybercrime',
#   'felt',
#   'entire',
#   'world',
#   'economy',
#   'digital',
#   'sphere',
#   'economic',
#   'effects',
#   'cyberattacks',
#   'devastating',
#   'supply',
#   'networks',
#   'financial',
#   'systems',
#   'critical',
#   'infrastructure',
#   'susceptible',
#   'breaches',
#   'lead',
#   'generalised',
#   'panic',
#   'financial',
#   'instability',
#   'connection',
#   'domino',
#   'effects',
#   'subsequent',
#   'economic',
#   'downturns',
#   'economy',
#   'financial',
#   'disruption',
#   'economic',
#   'effects',
#   'cybercrime',
#   'expected',
#   'astonishing',
#   'spread',
#   'grows',
#   'trillions',
#   'dollars',
#   'revenue',
#   'lost',
#   'result',
#   'financial',
#   'disruption',
#   'brought',
#   'cyberattacks',
#   'organisations',
#   'governments',
#   'interconnection',
#   'world',
#   'financial',
#   'institutions',
#   'make',
#   'simpler',
#   'hackers',
#   'wreak',
#   'economic',
#   'havoc',
#   'crashing',
#   'markets',
#   'banking',
#   'networks',
#   'supply',
#   'theft',
#   'invasion',
#   'personal',
#   'privacy',
#   'hackers',
#   'advantage',
#   'people',
#   'digital',
#   'footprints',
#   'exposed',
#   'identity',
#   'theft',
#   'breaches',
#   'privacy',
#   'identity',
#   'theft',
#   'anticipated',
#   'sophisticated',
#   'thieves',
#   'obtain',
#   'personal',
#   'data',
#   'numerous',
#   'sources',
#   'machine',
#   'learning',
#   'sector',
#   'exposure',
#   'due',
#   'sensitivity',
#   'patient',
#   'data',
#   'vital',
#   'role',
#   'plays',
#   'society',
#   'healthcare',
#   'industry',
#   'emerged',
#   'top',
#   'target',
#   'hackers',
#   'integration',
#   'medical',
#   'devices',
#   'digital',
#   'systems',
#   'reveal',
#   'weaknesses',
#   'make',
#   'cybercriminals',
#   'alter',
#   'medical',
#   'records',
#   'steal',
#   'patient',
#   'treatments',
#   'compromise',
#   'personal',
#   'health',
#   'national',
#   'security',
#   'unprecedented',
#   'threats',
#   'national',
#   'security',
#   'posed',
#   'cyberattacks',
#   'vital',
#   'infrastructure',
#   'including',
#   'grids',
#   'transportation',
#   'networks',
#   'communication',
#   'networks',
#   'strikes',
#   'disastrous',
#   'effects',
#   'upsetting',
#   'entire',
#   'unleashing',
#   'unprecedented',
#   'level',
#   'turmoil',
#   'national',
#   'security',
#   'longer',
#   'limited',
#   'conventional',
#   'military',
#   'threats',
#   'digital',
#   'age',
#   'cyberwarfare',
#   'grown',
#   'greatly',
#   'embroiled',
#   'cyber',
#   'warfare',
#   'result',
#   'data',
#   'manipulation',
#   'espionage',
#   'virtual',
#   'sabotage',
#   'cyberattacks',
#   'potential',
#   'disrupt',
#   'political',
#   'landscapes',
#   'undermine',
#   'defence',
#   'systems',
#   'impair',
#   'military',
#   'critical',
#   'infrastructure',
#   'cyberattacks',
#   'vital',
#   'infrastructure',
#   'grids',
#   'transportation',
#   'networks',
#   'healthcare',
#   'institutions',
#   'increase',
#   'due',
#   'interconnectedness',
#   'internet',
#   'systems',
#   'vulnerable',
#   'prospective',
#   'hacks',
#   'entire',
#   'societies',
#   'assaults',
#   'jeopardise',
#   'crucial',
#   'services',
#   'healthcare',
#   'public',
#   'erosion',
#   'privacy',
#   'degradation',
#   'individual',
#   'privacy',
#   'worsens',
#   'technology',
#   'develops',
#   'complex',
#   'network',
#   'interconnected',
#   'gadgets',
#   'enable',
#   'levels',
#   'data',
#   'collection',
#   'surveillance',
#   'raising',
#   'questions',
#   'civil',
#   'liberties',
#   'individual',
#   'freedoms',
#   'governments',
#   'businesses',
#   'cybercriminals',
#   'make',
#   'circumstance',
#   'variety',
#   'reasons',
#   'including',
#   'social',
#   'engineering',
#   'relations',
#   'restructuring',
#   'national',
#   'prevalence',
#   'cybercrime',
#   'alter',
#   'global',
#   'relations',
#   'interfere',
#   'elections',
#   'steal',
#   'intellectual',
#   'property',
#   'engage',
#   'cyber',
#   'espionage',
#   'exacerbate',
#   'tense',
#   'situation',
#   'sowing',
#   'distrust',
#   'uncertainty',
#   'struggle',
#   'concerns',
#   'cyber',
#   'sovereignty',
#   'digital',
#   'security',
#   'diplomacy',
#   'transcend',
#   'traditional',
#   'channels',
#   'domain',
#   'cyber',
#   'government',
#   'prevent',
#   'cybercriminals',
#   'hold',
#   'accountable',
#   'governments',
#   'implement',
#   'strict',
#   'regulatory',
#   'structures',
#   'cyber',
#   'rules',
#   'encourage',
#   'responsible',
#   'behaviour',
#   'cyberspace',
#   'established',
#   'collaboration',
#   'diplomatic',
#   'countermeasures',
#   'fight',
#   'digital',
#   'security',
#   'intense',
#   'criminality',
#   'increases',
#   'creation',
#   'countermeasures',
#   'essential',
#   'protecting',
#   'sensitive',
#   'data',
#   'crucial',
#   'systems',
#   'businesses',
#   'governments',
#   'make',
#   'significant',
#   'investments',
#   'cybersecurity',
#   'research',
#   'threat',
#   'detection',
#   'preventative',
#   'defence',
#   'systems',
#   'robust',
#   'cybersecurity',
#   'frameworks',
#   'develop',
#   'result',
#   'merging',
#   'human',
#   'expertise',
#   'machine',
#   'effects',
#   'mental',
#   'health',
#   'costs',
#   'development',
#   'cybercrime',
#   'expected',
#   'significant',
#   'social',
#   'impact',
#   'people',
#   'personal',
#   'psychological',
#   'ongoing',
#   'risk',
#   'financial',
#   'loss',
#   'data',
#   'breaches',
#   'digital',
#   'manipulation',
#   'reduce',
#   'public',
#   'confidence',
#   'digital',
#   'systems',
#   'living',
#   'constantly',
#   'unstable',
#   'digital',
#   'environment',
#   'psychological',
#   'toll',
#   'heightens',
#   'stress',
#   'worry',
#   'lack',
#   'technology',
#   'development',
#   'cybercrime',
#   'probable',
#   'consequences',
#   'gloomy',
#   'perspective',
#   'difficulties',
#   'lie',
#   'ahead',
#   'future',
#   'technological',
#   'development',
#   'revolutionised',
#   'life',
#   'ushered',
#   'period',
#   'criminal',
#   'activities',
#   'governments',
#   'corporations',
#   'individuals',
#   'work',
#   'combat',
#   'risks',
#   'cybersecurity',
#   'measures',
#   'global',
#   'collaboration',
#   'responsible',
#   'technological',
#   'development',
#   'work',
#   'guarantee',
#   'digital',
#   'future',
#   'supports',
#   'principles',
#   'privacy',
#   'trust',
#   'creativity',
#   'recognising',
#   'scope',
#   'threat',
#   'investing',
#   'defence',
#   'systems',
#   'encouraging',
#   'culture',
#   'cyber',
#   'alertness',
#   'shadowy',
#   'side',
#   'digital',
#   'revolution',
#   'ongoing',
#   'symbolised',
#   'hashtags',
#   'securedigitalfuture',
#   'insights',
#   'aseem',
#   'jain',
#   'ajay',
#   'garg',
#   'engineering',
#   'college',
#   'ghaziabad'],
#  'blackassign0005.txt': ['platform',
#   'impact',
#   'entertainment',
#   'industry',
#   'future',
#   'blackcoffer',
#   'insights',
#   'poised',
#   'witness',
#   'continued',
#   'revolution',
#   'world',
#   'entertainment',
#   'driven',
#   'meteoric',
#   'rise',
#   'platforms',
#   'digital',
#   'content',
#   'hubs',
#   'reshaped',
#   'consume',
#   'media',
#   'today',
#   'impact',
#   'set',
#   'profound',
#   'coming',
#   'years',
#   'emergence',
#   'platforms',
#   'effects',
#   'entertainment',
#   'industry',
#   'huge',
#   'entertainment',
#   'landscape',
#   'undergone',
#   'seismic',
#   'shift',
#   'rise',
#   'platforms',
#   'influence',
#   'reshaped',
#   'industry',
#   'profound',
#   'ways',
#   'article',
#   'delves',
#   'trajectory',
#   'platforms',
#   'effects',
#   'entertainment',
#   'platforms',
#   'solidify',
#   'status',
#   'dominant',
#   'players',
#   'entertainment',
#   'realm',
#   'accessible',
#   'internet',
#   'connectivity',
#   'audiences',
#   'corners',
#   'globe',
#   'access',
#   'vast',
#   'array',
#   'content',
#   'transcending',
#   'geographical',
#   'platforms',
#   'democratized',
#   'content',
#   'creation',
#   'enabling',
#   'diverse',
#   'creators',
#   'showcase',
#   'work',
#   'lead',
#   'explosion',
#   'niche',
#   'content',
#   'catering',
#   'specific',
#   'interests',
#   'cultures',
#   'previously',
#   'lot',
#   'shift',
#   'consumption',
#   'habits',
#   'audiences',
#   'traditional',
#   'television',
#   'continue',
#   'lose',
#   'ground',
#   'consumers',
#   'opt',
#   'personalized',
#   'viewing',
#   'experiences',
#   'platforms',
#   'linear',
#   'programming',
#   'wane',
#   'audiences',
#   'favour',
#   'content',
#   'fits',
#   'schedules',
#   'platforms',
#   'hubs',
#   'original',
#   'content',
#   'production',
#   'exclusive',
#   'movies',
#   'series',
#   'documentaries',
#   'attract',
#   'talent',
#   'blurring',
#   'line',
#   'cinema',
#   'platforms',
#   'interactive',
#   'immersive',
#   'experience',
#   'audience',
#   'advancements',
#   'augmented',
#   'virtual',
#   'reality',
#   'platforms',
#   'offer',
#   'immersive',
#   'viewing',
#   'experiences',
#   'transforming',
#   'audiences',
#   'engage',
#   'content',
#   'give',
#   'insights',
#   'watched',
#   'thriller',
#   'web',
#   'series',
#   'recommending',
#   'trending',
#   'thriller',
#   'shows',
#   'streaming',
#   'platform',
#   'streaming',
#   'nature',
#   'platforms',
#   'enables',
#   'data',
#   'collection',
#   'inform',
#   'content',
#   'creation',
#   'viewer',
#   'preferences',
#   'trends',
#   'influence',
#   'types',
#   'content',
#   'produced',
#   'enhancing',
#   'user',
#   'rise',
#   'disrupt',
#   'traditional',
#   'advertising',
#   'models',
#   'advertisers',
#   'adapt',
#   'targeted',
#   'advertising',
#   'methods',
#   'challenging',
#   'commercial',
#   'break',
#   'format',
#   'mentioned',
#   'advertisements',
#   'platforms',
#   'subscription',
#   'advertisement',
#   'shot',
#   'platforms',
#   'impact',
#   'theatrical',
#   'releases',
#   'experience',
#   'movies',
#   'opting',
#   'simultaneous',
#   'release',
#   'distinction',
#   'cinema',
#   'streaming',
#   'premieres',
#   'blur',
#   'positive',
#   'covid',
#   'films',
#   'supposed',
#   'release',
#   'theatres',
#   'releases',
#   'platforms',
#   'boon',
#   'industry',
#   'increase',
#   'global',
#   'connectivity',
#   'platforms',
#   'cultural',
#   'gaps',
#   'allowing',
#   'content',
#   'regions',
#   'reach',
#   'global',
#   'audiences',
#   'exchange',
#   'cultural',
#   'perspectives',
#   'enrich',
#   'content',
#   'models',
#   'remain',
#   'prevalent',
#   'hybrid',
#   'models',
#   'emerge',
#   'combining',
#   'subscriptions',
#   'options',
#   'tiers',
#   'coexist',
#   'proliferation',
#   'platforms',
#   'necessitate',
#   'robust',
#   'regulations',
#   'ensure',
#   'content',
#   'quality',
#   'data',
#   'privacy',
#   'reshaping',
#   'industry',
#   'landscape',
#   'traditional',
#   'studios',
#   'networks',
#   'adapting',
#   'partnering',
#   'platforms',
#   'stay',
#   'relevant',
#   'result',
#   'industry',
#   'landscape',
#   'continue',
#   'journey',
#   'reign',
#   'platforms',
#   'entertainment',
#   'undeniable',
#   'revolutionized',
#   'consume',
#   'content',
#   'placing',
#   'choice',
#   'diversity',
#   'convenience',
#   'forefront',
#   'challenges',
#   'transformations',
#   'lie',
#   'ahead',
#   'fusion',
#   'technology',
#   'creativity',
#   'global',
#   'connectivity',
#   'promises',
#   'entertainment',
#   'caters',
#   'evolving',
#   'preferences',
#   'audiences',
#   'insights',
#   'prerna',
#   'kamat',
#   'amity',
#   'university',
#   'rajasthan'],
#  'blackassign0006.txt': ['rise',
#   'platform',
#   'impact',
#   'entertainment',
#   'industry',
#   'blackcoffer',
#   'insights',
#   'entertainment',
#   'giving',
#   'people',
#   'hawksentertainment',
#   'essence',
#   'captivating',
#   'delighting',
#   'people',
#   'whisking',
#   'mundane',
#   'world',
#   'imagination',
#   'emotion',
#   'forms',
#   'tales',
#   'told',
#   'ancient',
#   'campfires',
#   'dazzling',
#   'spectacles',
#   'modern',
#   'cinema',
#   'traditionally',
#   'relied',
#   'television',
#   'radio',
#   'theatres',
#   'satiate',
#   'thirst',
#   'entertainment',
#   'emerged',
#   'advent',
#   'platforms',
#   'deliver',
#   'wide',
#   'array',
#   'digital',
#   'content',
#   'directly',
#   'consumers',
#   'internet',
#   'transformingthe',
#   'consume',
#   'content',
#   'platforms',
#   'accessible',
#   'tap',
#   'screen',
#   'redefining',
#   'entertainment',
#   'landscape',
#   'impact',
#   'revolutionary',
#   'intriguing',
#   'project',
#   'future',
#   'evident',
#   'impact',
#   'platforms',
#   'entertainment',
#   'industry',
#   'profound',
#   'essay',
#   'explores',
#   'factors',
#   'contributing',
#   'rise',
#   'platforms',
#   'current',
#   'significance',
#   'potential',
#   'implications',
#   'content',
#   'creation',
#   'distribution',
#   'consumption',
#   'traditional',
#   'media',
#   'rise',
#   'platforms',
#   'historical',
#   'contextthe',
#   'landscape',
#   'entertainment',
#   'underwent',
#   'remarkable',
#   'transformation',
#   'rise',
#   'platforms',
#   'shift',
#   'traced',
#   'period',
#   'marked',
#   'inception',
#   'content',
#   'consumption',
#   'led',
#   'pioneering',
#   'companies',
#   'likenetflix',
#   'dared',
#   'venture',
#   'uncharted',
#   'territories',
#   'streaming',
#   'content',
#   'initial',
#   'stages',
#   'platforms',
#   'focused',
#   'modest',
#   'goal',
#   'providing',
#   'digital',
#   'reservoir',
#   'older',
#   'movies',
#   'andtelevision',
#   'innovative',
#   'approach',
#   'offered',
#   'departure',
#   'conventional',
#   'entertainment',
#   'delivery',
#   'methods',
#   'introducing',
#   'concept',
#   'viewing',
#   'longer',
#   'audiences',
#   'tethered',
#   'rigid',
#   'schedules',
#   'dictated',
#   'traditional',
#   'television',
#   'broadcasts',
#   'cinema',
#   'showtimes',
#   'viewers',
#   'delve',
#   'treasure',
#   'trove',
#   'content',
#   'convenience',
#   'ushering',
#   'anew',
#   'viewer',
#   'convenience',
#   'viewingwas',
#   'ripple',
#   'setting',
#   'stage',
#   'profound',
#   'transformation',
#   'internet',
#   'infrastructure',
#   'connectivity',
#   'improved',
#   'fertile',
#   'ground',
#   'created',
#   'platforms',
#   'flourish',
#   'thesteady',
#   'technology',
#   'consumer',
#   'preferences',
#   'began',
#   'shift',
#   'demanding',
#   'convenience',
#   'diversity',
#   'originality',
#   'content',
#   'demand',
#   'platforms',
#   'embarked',
#   'journey',
#   'reinvent',
#   'swiftly',
#   'evolved',
#   'mere',
#   'repositories',
#   'nostalgic',
#   'classics',
#   'becomingcreators',
#   'distributors',
#   'original',
#   'programming',
#   'strategic',
#   'pivot',
#   'marked',
#   'turning',
#   'point',
#   'shaking',
#   'foundations',
#   'oftraditional',
#   'broadcast',
#   'tv',
#   'programming',
#   'injected',
#   'fresh',
#   'life',
#   'realm',
#   'entertainment',
#   'captivating',
#   'audiences',
#   'narratives',
#   'previously',
#   'unheard',
#   'platforms',
#   'unleashed',
#   'creative',
#   'prowess',
#   'embraced',
#   'storytelling',
#   'diverse',
#   'forms',
#   'gripping',
#   'dramas',
#   'thrilling',
#   'mysteries',
#   'heartwarming',
#   'comedies',
#   'documentaries',
#   'creative',
#   'renaissance',
#   'shattered',
#   'monopoly',
#   'traditional',
#   'media',
#   'decades',
#   'offering',
#   'level',
#   'playing',
#   'established',
#   'emerging',
#   'expansion',
#   'offerings',
#   'wasn',
#   'quantitative',
#   'growth',
#   'represented',
#   'qualitative',
#   'leap',
#   'audiences',
#   'longer',
#   'limited',
#   'predetermined',
#   'menu',
#   'content',
#   'handed',
#   'reins',
#   'expansive',
#   'universe',
#   'choice',
#   'personalization',
#   'reigned',
#   'supreme',
#   'revolution',
#   'ignited',
#   'ripple',
#   'effect',
#   'entertainment',
#   'industry',
#   'influencing',
#   'content',
#   'creators',
#   'production',
#   'studios',
#   'influencing',
#   'stories',
#   'conceived',
#   'driving',
#   'rise',
#   'platformsfactors',
#   'driving',
#   'rise',
#   'personalization',
#   'platforms',
#   'offer',
#   'unparalleled',
#   'convenience',
#   'personalization',
#   'viewers',
#   'access',
#   'content',
#   'catering',
#   'schedules',
#   'preferences',
#   'ability',
#   'create',
#   'personalized',
#   'profiles',
#   'curated',
#   'recommendations',
#   'watchlists',
#   'created',
#   'tailored',
#   'engaging',
#   'viewing',
#   'variety',
#   'original',
#   'programming',
#   'platforms',
#   'invested',
#   'heavily',
#   'producing',
#   'original',
#   'content',
#   'ranging',
#   'tv',
#   'series',
#   'movies',
#   'documentaries',
#   'specials',
#   'commitment',
#   'diverse',
#   'compelling',
#   'content',
#   'attracted',
#   'broader',
#   'audience',
#   'positioned',
#   'platforms',
#   'formidable',
#   'competitors',
#   'entertainment',
#   'reach',
#   'accessibility',
#   'global',
#   'accessibility',
#   'platforms',
#   'broken',
#   'geographical',
#   'barriers',
#   'enabling',
#   'content',
#   'creators',
#   'reach',
#   'audiences',
#   'worldwide',
#   'limitations',
#   'traditional',
#   'distribution',
#   'channels',
#   'fostered',
#   'exchange',
#   'enriched',
#   'content',
#   'advancements',
#   'advancements',
#   'streaming',
#   'technology',
#   'including',
#   'improved',
#   'video',
#   'compression',
#   'algorithms',
#   'faster',
#   'internet',
#   'speeds',
#   'facilitated',
#   'seamless',
#   'content',
#   'delivery',
#   'reduced',
#   'buffering',
#   'issues',
#   'enhanced',
#   'user',
#   'experience',
#   'incentivizing',
#   'consumers',
#   'adopt',
#   'traditional',
#   'models',
#   'platforms',
#   'disrupted',
#   'traditional',
#   'media',
#   'models',
#   'offering',
#   'options',
#   'challenge',
#   'conventional',
#   'model',
#   'disruption',
#   'prompted',
#   'traditional',
#   'media',
#   'companies',
#   'adapt',
#   'create',
#   'streaming',
#   'services',
#   'intensifying',
#   'competition',
#   'current',
#   'significance',
#   'platformsas',
#   'present',
#   'platforms',
#   'significantly',
#   'transformed',
#   'entertainment',
#   'landscape',
#   'players',
#   'netflix',
#   'amazon',
#   'prime',
#   'video',
#   'hulu',
#   'amassed',
#   'massive',
#   'subscriber',
#   'bases',
#   'challenging',
#   'dominance',
#   'broadcast',
#   'television',
#   'ability',
#   'platforms',
#   'produce',
#   'critically',
#   'acclaimed',
#   'culturally',
#   'impactful',
#   'original',
#   'content',
#   'stranger',
#   'things',
#   'mandalorian',
#   'crown',
#   'solidified',
#   'popular',
#   'platforms',
#   'revolutionized',
#   'content',
#   'consumption',
#   'habits',
#   'consuming',
#   'multiple',
#   'episodes',
#   'tv',
#   'series',
#   'rapid',
#   'succession',
#   'cultural',
#   'phenomenon',
#   'enabled',
#   'release',
#   'entire',
#   'seasons',
#   'shift',
#   'viewing',
#   'behaviour',
#   'influenced',
#   'storytelling',
#   'techniques',
#   'narrative',
#   'structures',
#   'content',
#   'creators',
#   'aim',
#   'engage',
#   'audiences',
#   'extended',
#   'content',
#   'creation',
#   'distributionlooking',
#   'ahead',
#   'impact',
#   'platforms',
#   'content',
#   'creation',
#   'distribution',
#   'pronounced',
#   'ability',
#   'platforms',
#   'gather',
#   'vast',
#   'amounts',
#   'user',
#   'data',
#   'insights',
#   'enable',
#   'content',
#   'creators',
#   'make',
#   'informed',
#   'decisions',
#   'type',
#   'content',
#   'resonates',
#   'audiences',
#   'approach',
#   'lead',
#   'targeted',
#   'innovative',
#   'storytelling',
#   'resulting',
#   'diverse',
#   'content',
#   'caters',
#   'tastes',
#   'model',
#   'platforms',
#   'eliminates',
#   'traditional',
#   'distribution',
#   'channels',
#   'reducing',
#   'intermediaries',
#   'production',
#   'costs',
#   'empower',
#   'independent',
#   'filmmakers',
#   'creators',
#   'showcase',
#   'work',
#   'global',
#   'audience',
#   'democratizing',
#   'content',
#   'creation',
#   'process',
#   'fostering',
#   'creativity',
#   'dominance',
#   'platforms',
#   'pose',
#   'challenges',
#   'content',
#   'diversity',
#   'platforms',
#   'expanded',
#   'stories',
#   'told',
#   'risk',
#   'niche',
#   'genres',
#   'perspectives',
#   'overshadowed',
#   'pursuit',
#   'mass',
#   'appeal',
#   'content',
#   'algorithms',
#   'prioritize',
#   'popular',
#   'genres',
#   'limit',
#   'exposure',
#   'content',
#   'potentially',
#   'hindering',
#   'discovery',
#   'unique',
#   'consumer',
#   'behavior',
#   'expectationsthe',
#   'rise',
#   'platforms',
#   'fundamentally',
#   'shifted',
#   'consumer',
#   'behaviour',
#   'expectations',
#   'trend',
#   'continue',
#   'demand',
#   'instant',
#   'gratification',
#   'personalized',
#   'recommendations',
#   'seamless',
#   'viewing',
#   'experience',
#   'set',
#   'standard',
#   'industry',
#   'expect',
#   'consumers',
#   'expect',
#   'immersive',
#   'interactive',
#   'experiences',
#   'driven',
#   'advancements',
#   'virtual',
#   'reality',
#   'vr',
#   'augmented',
#   'reality',
#   'ar',
#   'concept',
#   'act',
#   'cancelling',
#   'traditional',
#   'satellite',
#   'tv',
#   'subscriptions',
#   'favour',
#   'platforms',
#   'projected',
#   'norm',
#   'households',
#   'transition',
#   'streaming',
#   'services',
#   'traditional',
#   'tv',
#   'ecosystem',
#   'undergo',
#   'profound',
#   'transformation',
#   'leading',
#   'advertising',
#   'models',
#   'revenue',
#   'streams',
#   'content',
#   'tailored',
#   'content',
#   'creation',
#   'platforms',
#   'catalyzed',
#   'revolution',
#   'content',
#   'creation',
#   'democratization',
#   'production',
#   'tools',
#   'distribution',
#   'channels',
#   'empower',
#   'diverse',
#   'creators',
#   'showcase',
#   'talents',
#   'global',
#   'stage',
#   'boundaries',
#   'storytelling',
#   'pushed',
#   'giving',
#   'rise',
#   'narratives',
#   'reflect',
#   'spectrum',
#   'cultures',
#   'perspectives',
#   'experiences',
#   'personalization',
#   'algorithms',
#   'refine',
#   'content',
#   'recommendations',
#   'ensuring',
#   'individual',
#   'entertainment',
#   'journey',
#   'unique',
#   'engaging',
#   'erosion',
#   'traditional',
#   'broadcast',
#   'tv',
#   'traditional',
#   'broadcast',
#   'tv',
#   'models',
#   'stalwarts',
#   'entertainment',
#   'shadows',
#   'dominance',
#   'platforms',
#   'relegate',
#   'scheduled',
#   'programming',
#   'nostalgia',
#   'audiences',
#   'demand',
#   'freedom',
#   'curate',
#   'viewing',
#   'schedules',
#   'live',
#   'streaming',
#   'interaction',
#   'gap',
#   'virtual',
#   'reality',
#   'providing',
#   'immersive',
#   'experiences',
#   'redefine',
#   'concept',
#   'appointment',
#   'globalization',
#   'content',
#   'boundaries',
#   'geography',
#   'blur',
#   'platforms',
#   'transcend',
#   'audiences',
#   'world',
#   'effortlessly',
#   'access',
#   'content',
#   'diverse',
#   'cultures',
#   'languages',
#   'genres',
#   'exchange',
#   'stories',
#   'ideas',
#   'understanding',
#   'appreciation',
#   'contributing',
#   'interconnected',
#   'global',
#   'immersive',
#   'experiences',
#   'integration',
#   'emerging',
#   'technologies',
#   'virtual',
#   'reality',
#   'vr',
#   'augmented',
#   'reality',
#   'ar',
#   'elevate',
#   'entertainment',
#   'heights',
#   'viewers',
#   'step',
#   'worlds',
#   'favourite',
#   'shows',
#   'movies',
#   'active',
#   'participants',
#   'storytelling',
#   'process',
# ...
#   'improving',
#   'lockdowns',
#   'lifted',
#   'fact',
#   'shunned',
#   'virus',
#   'term',
#   'impact',
#   'people',
#   'effects',
#   'felt',
#   'economically',
#   'physically',
#   've',
#   'reading',
#   'articles',
#   'impact',
#   'covid',
#   'economy',
#   'education',
#   'mental',
#   'health',
#   'aspect',
#   'topic',
#   'talked',
#   'impact',
#   'covid',
#   'office',
#   'space',
#   'industries',
#   'obvious',
#   'offices',
#   'start',
#   'functioning',
#   'covid',
#   'period',
#   'hasn',
#   'ended',
#   'social',
#   'distancing',
#   'offices',
#   'problem',
#   'lack',
#   'adequate',
#   'infrastructure',
#   'space',
#   'condition',
#   'industries',
#   'employees',
#   'companies',
#   'work',
#   'problems',
#   'obvious',
#   'people',
#   'thought',
#   'fact',
#   'people',
#   'fail',
#   'notice',
#   'understand',
#   'meaning',
#   'space',
#   'limited',
#   'infrastructural',
#   'space',
#   'measured',
#   'square',
#   'foot',
#   'square',
#   'meters',
#   'extends',
#   'metal',
#   'space',
#   'fact',
#   'space',
#   'minds',
#   'people',
#   'thoughts',
#   'left',
#   'big',
#   'scratch',
#   'car',
#   'repair',
#   'accident',
#   'repair',
#   'control',
#   'virus',
#   'unlike',
#   'car',
#   'require',
#   'amount',
#   'restored',
#   'stand',
#   'economic',
#   'stability',
#   'hit',
#   'reason',
#   'problem',
#   'earnings',
#   'employers',
#   'reduce',
#   'subsequently',
#   'lead',
#   'drop',
#   'salary',
#   'employees',
#   'employees',
#   'preferred',
#   'bosses',
#   'receive',
#   'raise',
#   'regularly',
#   'subjected',
#   'unfair',
#   'treatment',
#   'made',
#   'amount',
#   'work',
#   'tend',
#   'overlook',
#   'thin',
#   'line',
#   'exists',
#   'cooperation',
#   'competition',
#   'problem',
#   'doesn',
#   'arise',
#   'situation',
#   'employee',
#   'paid',
#   'arises',
#   'people',
#   'start',
#   'compare',
#   'earnings',
#   'benefits',
#   'today',
#   'world',
#   'people',
#   'top',
#   'priority',
#   'list',
#   'comparisons',
#   'play',
#   'important',
#   'role',
#   'performance',
#   'employees',
#   'exist',
#   'inequalities',
#   'partialities',
#   'companies',
#   'exist',
#   'sense',
#   'hatred',
#   'competition',
#   'employees',
#   'company',
#   'compete',
#   'position',
#   'raise',
#   'salary',
#   'beneficial',
#   'compel',
#   'employees',
#   'work',
#   'bring',
#   'huge',
#   'losses',
#   'run',
#   'fact',
#   'employees',
#   'end',
#   'unethical',
#   'acts',
#   'make',
#   'impression',
#   'comparisons',
#   'employees',
#   'happen',
#   'employee',
#   'ends',
#   'hated',
#   'employees',
#   'company',
#   'situation',
#   'arise',
#   'bluffing',
#   'pretending',
#   'employees',
#   'tend',
#   'show',
#   'work',
#   'hard',
#   'practiced',
#   'showing',
#   'working',
#   'chilling',
#   'rest',
#   'home',
#   'sits',
#   'office',
#   'fact',
#   'employees',
#   'lose',
#   'interest',
#   'working',
#   'sense',
#   'repeated',
#   'partialities',
#   'inequalities',
#   'show',
#   'quitting',
#   'jobs',
#   'performing',
#   'situations',
#   'arise',
#   'companies',
#   'offices',
#   'employees',
#   'compete',
#   'attention',
#   'resources',
#   'great',
#   'impact',
#   'company',
#   'functioning',
#   'happen',
#   'thing',
#   'lack',
#   'office',
#   'mental',
#   'space',
#   'space',
#   'minds',
#   'people',
#   'working',
#   'office',
#   'cooperation',
#   'teamwork',
#   'ignorance',
#   'fact',
#   'things',
#   'eventually',
#   'kind',
#   'industry',
#   'companies',
#   'affected',
#   'due',
#   'impact',
#   'covid',
#   'industry',
#   'offices',
#   'shortage',
#   'resources',
#   'income',
#   'people',
#   'maintenance',
#   'cost',
#   'infrastructure',
#   'rent',
#   'remain',
#   'employees',
#   'told',
#   'company',
#   'owners',
#   'exploit',
#   'resources',
#   'present',
#   'offices',
#   'fullest',
#   'compensate',
#   'losses',
#   'make',
#   'number',
#   'resources',
#   'competition',
#   'employees',
#   'companies',
#   'resources',
#   'benefits',
#   'situations',
#   'happen',
#   'occur',
#   'observe',
#   'scene',
#   'competition',
#   'personal',
#   'relations',
#   'employees',
#   'company',
#   'affected',
#   'due',
#   'comparison',
#   'competition',
#   'result',
#   'limited',
#   'mental',
#   'severe',
#   'impacts',
#   'office',
#   'mental',
#   'space',
#   'companies',
#   'people',
#   'people',
#   'thoughts',
#   'accepting',
#   'defeat',
#   'rejection',
#   'important',
#   'aspect',
#   'lives',
#   'observe',
#   'shoot',
#   'intensity',
#   'frequency',
#   'office',
#   'people',
#   'psychologists',
#   'repeated',
#   'rejection',
#   'unfair',
#   'treatment',
#   'thing',
#   'realize',
#   'important',
#   'start',
#   'preparing',
#   'expand',
#   'mental',
#   'space',
#   'competition',
#   'comparison',
#   'stay',
#   'affect',
#   'personal',
#   'relations',
#   'life',
#   'insights',
#   'archit',
#   'khandelwal',
#   'shishukunj',
#   'school',
#   'indore'],
#  'blackassign0098.txt': ['contribution',
#   'handicrafts',
#   'visual',
#   'arts',
#   'literature',
#   'economy',
#   'blackcoffer',
#   'insights',
#   'handicrafts',
#   'making',
#   'crafts',
#   'called',
#   'handicrafts',
#   'ancient',
#   'people',
#   'lived',
#   'colonies',
#   'called',
#   'tribals',
#   'make',
#   'utility',
#   'items',
#   'making',
#   'crafts',
#   'called',
#   'handicrafts',
#   'items',
#   'called',
#   'handicrafts',
#   'handicrafts',
#   'followspashmina',
#   'shawlsbidriware',
#   'metal',
#   'handicraftcane',
#   'bamboo',
#   'handicraftszardozichikankarithe',
#   'visual',
#   'arts',
#   'forms',
#   'painting',
#   'printmaking',
#   'sculpture',
#   'ceramics',
#   'photography',
#   'video',
#   'filmmaking',
#   'design',
#   'crafts',
#   'architecture',
#   'artistic',
#   'disciplines',
#   'performing',
#   'arts',
#   'conceptual',
#   'textile',
#   'arts',
#   'involve',
#   'aspects',
#   'visual',
#   'arts',
#   'arts',
#   'types',
#   'included',
#   'visual',
#   'arts',
#   'applied',
#   'arts',
#   'industrial',
#   'design',
#   'graphic',
#   'design',
#   'fashion',
#   'design',
#   'interior',
#   'design',
#   'decorative',
#   'handicrafts',
#   'economyindian',
#   'handicrafts',
#   'items',
#   'unique',
#   'impression',
#   'charm',
#   'immensely',
#   'big',
#   'industry',
#   'livelihood',
#   'lakh',
#   'weavers',
#   'handicrafts',
#   'environment',
#   'friendly',
#   'energy',
#   'handicraft',
#   'items',
#   'exported',
#   'generated',
#   'foreign',
#   'exchange',
#   'important',
#   'represents',
#   'culture',
#   'tradition',
#   'promotes',
#   'heritage',
#   'indigenous',
#   'materials',
#   'preserves',
#   'traditional',
#   'knowledge',
#   'days',
#   'handicraft',
#   'industry',
#   'plays',
#   'vital',
#   'role',
#   'rural',
#   'sector',
#   'liberal',
#   'trade',
#   'export',
#   'handloom',
#   'industry',
#   'facts',
#   'handicrafts',
#   'industrythe',
#   'handicraft',
#   'industry',
#   'showing',
#   'continuous',
#   'growth',
#   'rate',
#   'parts',
#   'industry',
#   'operate',
#   'rural',
#   'areas',
#   'potential',
#   'markets',
#   'exporters',
#   'tap',
#   'national',
#   'handicrafts',
#   'undertaken',
#   'national',
#   'applied',
#   'economic',
#   'research',
#   'handicrafts',
#   'produced',
#   'rs',
#   'industry',
#   'huge',
#   'employment',
#   'opportunities',
#   'artisans',
#   'include',
#   'women',
#   'people',
#   'belonging',
#   'backward',
#   'weaker',
#   'society',
#   'sources',
#   'income',
#   'handicraft',
#   'industry',
#   'industry',
#   'contribution',
#   'world',
#   'market',
#   'total',
#   'exports',
#   'crafts',
#   'items',
#   'rs',
#   'share',
#   'exports',
#   'blackcoffer',
#   'insights',
#   'harsh',
#   'pibm',
#   'pune'],
#  'blackassign0099.txt': ['impacting',
#   'payment',
#   'preferences',
#   'blackcoffer',
#   'insights',
#   'pay',
#   'make',
#   'online',
#   'payment',
#   'lockdown',
#   'observe',
#   'number',
#   'positive',
#   'surroundings',
#   'positive',
#   'change',
#   'online',
#   'mode',
#   'payment',
#   'amount',
#   'big',
#   'step',
#   'digital',
#   'economic',
#   'times',
#   'indians',
#   'started',
#   'online',
#   'mode',
#   'payment',
#   'tasks',
#   'mobile',
#   'phone',
#   'recharge',
#   'payments',
#   'buying',
#   'groceries',
#   'essential',
#   'tasks',
#   'making',
#   'online',
#   'payment',
#   'convenient',
#   'multiple',
#   'schemes',
#   'initiated',
#   'government',
#   'promote',
#   'online',
#   'payments',
#   'grahak',
#   'yojana',
#   'digi',
#   'dhan',
#   'vyapari',
#   'yojana',
#   'details',
#   'garhak',
#   'yojanaa',
#   'reward',
#   'rs',
#   'consumers',
#   'period',
#   'online',
#   'mode',
#   'payments',
#   'prizes',
#   'rs',
#   'lakh',
#   'rs',
#   'rs',
#   'types',
#   'online',
#   'transactions',
#   'included',
#   'digi',
#   'dhan',
#   'vyapariprizes',
#   'merchants',
#   'digital',
#   'rs',
#   'rs',
#   'provided',
#   'frequently',
#   'apps',
#   'consumers',
#   'market',
#   'share',
#   'apps',
#   'google',
#   'amazon',
#   'buyers',
#   'step',
#   'forward',
#   'making',
#   'online',
#   'payments',
#   'exploring',
#   'offers',
#   'discounts',
#   'started',
#   'online',
#   'shops',
#   'made',
#   'online',
#   'payment',
#   'mandatory',
#   'highly',
#   'contaminated',
#   'zones',
#   'buyer',
#   'advantage',
#   'home',
#   'deliveries',
#   'follow',
#   'social',
#   'distancing',
#   'add',
#   'advantage',
#   'buyers',
#   'kyc',
#   'necessity',
#   'make',
#   'increase',
#   'services',
#   'provided',
#   'banking',
#   'sectors',
#   'fm',
#   'nirmala',
#   'sitharaman',
#   'provided',
#   'directions',
#   'charge',
#   'withdrawals',
#   'atm',
#   'services',
#   'sending',
#   'receiving',
#   'blocking',
#   'cards',
#   'credit',
#   'payments',
#   'credit',
#   'pins',
#   'provided',
#   'options',
#   'paytm',
#   'open',
#   'investing',
#   'online',
#   'insurance',
#   'online',
#   'shopping',
#   'apps',
#   'amazon',
#   'offers',
#   'technologies',
#   'competition',
#   'online',
#   'payment',
#   'apps',
#   'providing',
#   'benefits',
#   'buyers',
#   'increase',
#   'reach',
#   'online',
#   'shops',
#   'online',
#   'payment',
#   'stands',
#   'guarantee',
#   'buyers',
#   'advantageous',
#   'position',
#   'digital',
#   'payment',
#   'market',
#   'provided',
#   'number',
#   'choices',
#   'choose',
#   'make',
#   'instant',
#   'payments',
#   'offers',
#   'sums',
#   'likeliness',
#   'digital',
#   'payment',
#   'market',
#   'digital',
#   'payment',
#   'brillant',
#   'future',
#   'statement',
#   'precaution',
#   'cure',
#   'follow',
#   'proven',
#   'fact',
#   'coronavirus',
#   'persist',
#   'paper',
#   'days',
#   'coronavirus',
#   'persist',
#   'paper',
#   'currency',
#   'days',
#   'important',
#   'avoid',
#   'usage',
#   'paper',
#   'revolution',
#   'poverty',
#   'population',
#   'start',
#   'online',
#   'mode',
#   'payment',
#   'literate',
#   'caught',
#   'insights',
#   'himanshi',
#   'kalota',
#   'shri',
#   'ram',
#   'college',
#   'commerce'],
#  'blackassign0100.txt': ['affect',
#   'world',
#   'work',
#   'blackcoffer',
#   'insights',
#   'business',
#   'prevent',
#   'transmission',
#   'financial',
#   'concerns',
#   'job',
#   'losses',
#   'human',
#   'impacts',
#   'virus',
#   'knowing',
#   'pandemic',
#   'play',
#   'affects',
#   'economic',
#   'physical',
#   'mental',
#   'fear',
#   'businesses',
#   'communities',
#   'regions',
#   'shown',
#   'altruistic',
#   'response',
#   'face',
#   'crisis',
#   'actions',
#   'preparing',
#   'decline',
#   'cases',
#   'epidemic',
#   'surpassed',
#   'deaths',
#   'virus',
#   'days',
#   'reach',
#   'confirmed',
#   'cases',
#   'worldwide',
#   'days',
#   'increase',
#   'reach',
#   'confirmed',
#   'cases',
#   'figure',
#   'human',
#   'consequencesin',
#   'recent',
#   'significant',
#   'economic',
#   'impact',
#   'coronavirus',
#   'financial',
#   'markets',
#   'vulnerable',
#   'industries',
#   'manufacturing',
#   'tourism',
#   'hospitality',
#   'travel',
#   'travel',
#   'tourism',
#   'account',
#   'global',
#   'gdp',
#   'jobs',
#   'risk',
#   'tourism',
#   'travel',
#   'hospitality',
#   'companies',
#   'closing',
#   'affects',
#   'smes',
#   'globally',
#   'turn',
#   'affects',
#   'people',
#   'typically',
#   'working',
#   'informal',
#   'environments',
#   'gig',
#   'economy',
#   'work',
#   'contracts',
#   'governments',
#   'announced',
#   'economic',
#   'measures',
#   'safeguard',
#   'jobs',
#   'guarantee',
#   'support',
#   'lack',
#   'clarity',
#   'measures',
#   'implemented',
#   'people',
#   'manage',
#   'loss',
#   'income',
#   'statistics',
#   'lie',
#   'human',
#   'costs',
#   'pandemic',
#   'deaths',
#   'friends',
#   'family',
#   'physical',
#   'effects',
#   'infection',
#   'mental',
#   'trauma',
#   'fear',
#   'faced',
#   'knowing',
#   'pandemic',
#   'play',
#   'affects',
#   'economic',
#   'physical',
#   'mental',
#   'backdrop',
#   'world',
#   'increasingly',
#   'anxious',
#   'unhappy',
#   'unknown',
#   'lead',
#   'feelings',
#   'panic',
#   'people',
#   'feel',
#   'denied',
#   'protection',
#   'treatment',
#   'run',
#   'necessities',
#   'lead',
#   'panic',
#   'stress',
#   'sense',
#   'lack',
#   'control',
#   'face',
#   'cases',
#   'lack',
#   'information',
#   'wrong',
#   'information',
#   'provided',
#   'inadvertently',
#   'maliciously',
#   'amplify',
#   'effects',
#   'huge',
#   'amount',
#   'misleading',
#   'information',
#   'circulating',
#   'online',
#   'fake',
#   'medical',
#   'information',
#   'speculation',
#   'government',
#   'responses',
#   'people',
#   'susceptible',
#   'social',
#   'media',
#   'posts',
#   'apparently',
#   'trustworthy',
#   'source',
#   'referred',
#   'uncle',
#   'possibly',
#   'amplified',
#   'spread',
#   'copypasta',
#   'posts',
#   'share',
#   'information',
#   'copying',
#   'pasting',
#   'make',
#   'original',
#   'source',
#   'opposed',
#   'posts',
#   'shared',
#   'retweeted',
#   'criminals',
#   'hackers',
#   'exploiting',
#   'situation',
#   'significant',
#   'rise',
#   'malicious',
#   'websites',
#   'domains',
#   'registered',
#   'hackers',
#   'selling',
#   'malware',
#   'hacking',
#   'tools',
#   'discount',
#   'codes',
#   'darknet',
#   'aimed',
#   'accessing',
#   'corporate',
#   'data',
#   'laptops',
#   'secure',
#   'office',
#   'distancing',
#   'lockdowns',
#   'prompted',
#   'altruistic',
#   'behaviors',
#   'part',
#   'sense',
#   'people',
#   'report',
#   'bored',
#   'concerned',
#   'putting',
#   'weight',
#   'discovered',
#   'slower',
#   'life',
#   'socializing',
#   'found',
#   'family',
#   'downside',
#   'social',
#   'lockdown',
#   'symptoms',
#   'traumatic',
#   'stress',
#   'confusion',
#   'anger',
#   'exacerbated',
#   'fear',
#   'infection',
#   'limited',
#   'access',
#   'supplies',
#   'necessities',
#   'inadequate',
#   'information',
#   'experience',
#   'economic',
#   'loss',
#   'stigma',
#   'stress',
#   'anxiety',
#   'lead',
#   'increased',
#   'alcohol',
#   'consumption',
#   'increase',
#   'domestic',
#   'family',
#   'jingzhou',
#   'town',
#   'wuhan',
#   'hubei',
#   'province',
#   'reports',
#   'domestic',
#   'violence',
#   'lockdown',
#   'triple',
#   'number',
#   'reported',
#   'actions',
#   'business',
#   'communityhealth',
#   'measures',
#   'priority',
#   'governments',
#   'business',
#   'society',
#   'important',
#   'businesses',
#   'show',
#   'solidarity',
#   'work',
#   'protect',
#   'staff',
#   'local',
#   'communities',
#   'customers',
#   'keeping',
#   'supply',
#   'chains',
#   'manufacturing',
#   'logistics',
#   'research',
#   'employer',
#   'trusted',
#   'government',
#   'media',
#   'updates',
#   'company',
#   'website',
#   'input',
#   'scientists',
#   'experts',
#   'recommended',
#   'counter',
#   'politicized',
#   'messages',
#   'media',
#   'governments',
#   'companies',
#   'capacity',
#   'businesses',
#   'employees',
#   'communities',
#   'important',
#   'companies',
#   'helping',
#   'schoolchildren',
#   'vulnerable',
#   'families',
#   'longer',
#   'school',
#   'meal',
#   'providing',
#   'public',
#   'health',
#   'messages',
#   'effective',
#   'handwashing',
#   'ceos',
#   'show',
#   'working',
#   'home',
#   'effective',
#   'advice',
#   'business',
#   'community',
#   'move',
#   'general',
#   'support',
#   'specific',
#   'actions',
#   'focus',
#   'access',
#   'critical',
#   'supplies',
#   'including',
#   'community',
#   'package',
#   'critical',
#   'items',
#   'list',
#   'items',
#   'items',
#   'locally',
#   'limited',
#   'missing',
#   'items',
#   'fall',
#   'categories',
#   'hygiene',
#   'chlorine',
#   'hth',
#   'alcohol',
#   'based',
#   'rub',
#   'liquid',
#   'soap',
#   'diagnostics',
#   'lab',
#   'screening',
#   'tests',
#   'lab',
#   'confirmation',
#   'tests',
#   'enzymes',
#   'rna',
#   'extraction',
#   'kits',
#   'ppe',
#   'gowns',
#   'scrubs',
#   'aprons',
#   'sterile',
#   'gloves',
#   'protective',
#   'goggles',
#   'face',
#   'masks',
#   'management',
#   'equipment',
#   'oxygen',
#   'concentrators',
#   'oxygen',
#   'delivery',
#   'systems',
#   'mechanical',
#   'action',
#   'work',
#   'manufacturers',
#   'create',
#   'capacity',
#   'organize',
#   'purchasing',
#   'guaranteed',
#   'access',
#   'poorer',
#   'resilient',
#   'public',
#   'health',
#   'systems',
#   'concept',
#   'create',
#   'global',
#   'security',
#   'stockpile',
#   'supplies',
#   'equipment',
#   'effort',
#   'emergency',
#   'financingaccess',
#   'increases',
#   'manufacturing',
#   'capacityaccess',
#   'national',
#   'supplier',
#   'stockpileswarehouses',
#   'distribution',
#   'capacityblackcoffer',
#   'insights',
#   'tiwari',
#   'gurukul',
#   'kangri',
#   'deemed',
#   'university',
#   'haridwar']}

# %% [markdown]
# ## 1.2 Positive & Negative words from master dictionary

# %%
master_dictionary_folder = "MasterDictionary"

folder_path3 = os.path.join(current_dir,master_dictionary_folder)
print(folder_path3,"\n")
print("files :",os.listdir(folder_path3))
# Out:
# C:\Users\Amruta\Desktop\Blackcoffer NLP Project\MasterDictionary
#
# files : ['negative-words.txt', 'positive-words.txt']

# %%
positive_words = []
negative_words = []

for files in os.listdir(folder_path3):
    if files =='positive-words.txt':
        with open(os.path.join(folder_path3,files),'r',encoding='ISO-8859-1') as f:
            positive_words.extend(f.read().splitlines())
    else:
        with open(os.path.join(folder_path3,files),'r',encoding='ISO-8859-1') as f:
            negative_words.extend(f.read().splitlines())

# %%
len(positive_words),len(negative_words)
# Out:
# (2006, 4783)

# %% [markdown]
# ## 1.3 Extracting Derived variables

# %%
positive_score_list = []
negative_score_list = []
polarity_score_list = []
subjectivity_score_list  = []

def variable_calculater(tokens):

    # Calculate positive and negative scores
    positive_score = sum(1 for word in tokens if word in positive_words)
    negative_score = sum(-1 for word in tokens if word in negative_words)*-1
    
    # Calculate polarity score
    polarity_score = (positive_score - negative_score) / (positive_score + negative_score + 0.000001)
    
    # Calculate subjectivity score
    subjectivity_score = (positive_score + negative_score) / (len(filtered_words) + 0.000001)
    
    # adding scores
    positive_score_list.append(positive_score)
    negative_score_list.append(negative_score)
    polarity_score_list.append(polarity_score)
    subjectivity_score_list.append(subjectivity_score)


for tokens in token_dict.values():
    variable_calculater(tokens)

# %%
len(positive_score_list),len(negative_score_list)
# Out:
# (100, 100)

# %%
len(polarity_score_list),len(subjectivity_score_list)
# Out:
# (100, 100)
